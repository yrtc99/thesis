# %%
import torch
import torch_geometric
from torch_geometric.data import Data
import os.path as osp
import torch.nn.functional as F
from torch_geometric.datasets import Reddit, AttributedGraphDataset, WebKB, WikipediaNetwork, Actor
import torch_geometric.transforms as T
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from typing import Union, Tuple, Optional
from torch import Tensor
from torch_geometric.typing import OptPairTensor, Adj, Size
from tqdm import tqdm
from collections import Counter
from dataset import Facebook100
from ogb.nodeproppred import PygNodePropPredDataset
import torch
import torch_geometric
from torch_geometric.data import Data
import os.path as osp
import os
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid, Reddit, AttributedGraphDataset,  WebKB, WikipediaNetwork, Actor, Flickr
from torch_geometric.nn.conv import sage_conv
import torch_geometric.transforms as T
import torch.nn as nn
# from torch_geometric.nn import SplineConv, GCNConv
from torch_geometric.nn import SplineConv, GATConv, SAGEConv
from torch_sparse.mul import mul
print(torch_geometric.__version__)
import numpy as np
import time
import sys
import logging
from torch.nn.utils import clip_grad_norm_
sys.path.append('./')
sys.path.append('./models')
from dataset import Facebook100
import random
import seaborn as sns
from torch_sparse import coalesce, matmul
import copy
import torch_sparse
# Out:
# 2.0.2

# %%
import os.path as osp
from typing import Callable, List, Optional

import numpy as np
import torch

from torch_geometric.data import InMemoryDataset, download_url
from torch_geometric.io import read_planetoid_data


class Planetoid(InMemoryDataset):
    r"""The citation network datasets "Cora", "CiteSeer" and "PubMed" from the
    `"Revisiting Semi-Supervised Learning with Graph Embeddings"
    <https://arxiv.org/abs/1603.08861>`_ paper.
    Nodes represent documents and edges represent citation links.
    Training, validation and test splits are given by binary masks.

    Args:
        root (string): Root directory where the dataset should be saved.
        name (string): The name of the dataset (:obj:`"Cora"`,
            :obj:`"CiteSeer"`, :obj:`"PubMed"`).
        split (string): The type of dataset split
            (:obj:`"public"`, :obj:`"full"`, :obj:`"geom-gcn"`,
            :obj:`"random"`).
            If set to :obj:`"public"`, the split will be the public fixed split
            from the `"Revisiting Semi-Supervised Learning with Graph
            Embeddings" <https://arxiv.org/abs/1603.08861>`_ paper.
            If set to :obj:`"full"`, all nodes except those in the validation
            and test sets will be used for training (as in the
            `"FastGCN: Fast Learning with Graph Convolutional Networks via
            Importance Sampling" <https://arxiv.org/abs/1801.10247>`_ paper).
            If set to :obj:`"geom-gcn"`, the 10 public fixed splits from the
            `"Geom-GCN: Geometric Graph Convolutional Networks"
            <https://openreview.net/forum?id=S1e2agrFvS>`_ paper are given.
            If set to :obj:`"random"`, train, validation, and test sets will be
            randomly generated, according to :obj:`num_train_per_class`,
            :obj:`num_val` and :obj:`num_test`. (default: :obj:`"public"`)
        num_train_per_class (int, optional): The number of training samples
            per class in case of :obj:`"random"` split. (default: :obj:`20`)
        num_val (int, optional): The number of validation samples in case of
            :obj:`"random"` split. (default: :obj:`500`)
        num_test (int, optional): The number of test samples in case of
            :obj:`"random"` split. (default: :obj:`1000`)
        transform (callable, optional): A function/transform that takes in an
            :obj:`torch_geometric.data.Data` object and returns a transformed
            version. The data object will be transformed before every access.
            (default: :obj:`None`)
        pre_transform (callable, optional): A function/transform that takes in
            an :obj:`torch_geometric.data.Data` object and returns a
            transformed version. The data object will be transformed before
            being saved to disk. (default: :obj:`None`)

    Stats:
        .. list-table::
            :widths: 10 10 10 10 10
            :header-rows: 1

            * - Name
              - #nodes
              - #edges
              - #features
              - #classes
            * - Cora
              - 2,708
              - 10,556
              - 1,433
              - 7
            * - CiteSeer
              - 3,327
              - 9,104
              - 3,703
              - 6
            * - PubMed
              - 19,717
              - 88,648
              - 500
              - 3
    """

    url = 'https://github.com/kimiyoung/planetoid/raw/master/data'
    geom_gcn_url = ('https://raw.githubusercontent.com/graphdml-uiuc-jlu/'
                    'geom-gcn/master')

    def __init__(self, root: str, name: str, split: str = "public",
                 num_train_per_class: int = 20, num_val: int = 500,
                 num_test: int = 1000, transform: Optional[Callable] = None,
                 pre_transform: Optional[Callable] = None):
        self.name = name

        self.split = split.lower()
        assert self.split in ['public', 'full', 'geom-gcn', 'random']

        super().__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

        if split == 'full':
            data = self.get(0)
            data.train_mask.fill_(True)
            data.train_mask[data.val_mask | data.test_mask] = False
            self.data, self.slices = self.collate([data])

        elif split == 'random':
            data = self.get(0)
            data.train_mask.fill_(False)
            for c in range(self.num_classes):
                idx = (data.y == c).nonzero(as_tuple=False).view(-1)
                idx = idx[torch.randperm(idx.size(0))[:num_train_per_class]]
                data.train_mask[idx] = True

            remaining = (~data.train_mask).nonzero(as_tuple=False).view(-1)
            remaining = remaining[torch.randperm(remaining.size(0))]

            data.val_mask.fill_(False)
            data.val_mask[remaining[:num_val]] = True

            data.test_mask.fill_(False)
            data.test_mask[remaining[num_val:num_val + num_test]] = True

            self.data, self.slices = self.collate([data])

    @property
    def raw_dir(self) -> str:
        if self.split == 'geom-gcn':
            return osp.join(self.root, self.name, 'geom-gcn', 'raw')
        return osp.join(self.root, self.name, 'raw')

    @property
    def processed_dir(self) -> str:
        if self.split == 'geom-gcn':
            return osp.join(self.root, self.name, 'geom-gcn', 'processed')
        return osp.join(self.root, self.name, 'processed')

    @property
    def raw_file_names(self) -> List[str]:
        names = ['x', 'tx', 'allx', 'y', 'ty', 'ally', 'graph', 'test.index']
        return [f'ind.{self.name.lower()}.{name}' for name in names]

    @property
    def processed_file_names(self) -> str:
        return 'data.pt'

    def download(self):
        for name in self.raw_file_names:
            download_url(f'{self.url}/{name}', self.raw_dir)
        if self.split == 'geom-gcn':
            for i in range(10):
                url = f'{self.geom_gcn_url}/splits/{self.name.lower()}'
                download_url(f'{url}_split_0.6_0.2_{i}.npz', self.raw_dir)

    def process(self):
        data = read_planetoid_data(self.raw_dir, self.name)

        if self.split == 'geom-gcn':
            train_masks, val_masks, test_masks = [], [], []
            for i in range(10):
                name = f'{self.name.lower()}_split_0.6_0.2_{i}.npz'
                splits = np.load(osp.join(self.raw_dir, name))
                train_masks.append(torch.from_numpy(splits['train_mask']))
                val_masks.append(torch.from_numpy(splits['val_mask']))
                test_masks.append(torch.from_numpy(splits['test_mask']))
            data.train_mask = torch.stack(train_masks, dim=1)
            data.val_mask = torch.stack(val_masks, dim=1)
            data.test_mask = torch.stack(test_masks, dim=1)

        data = data if self.pre_transform is None else self.pre_transform(data)
        torch.save(self.collate([data]), self.processed_paths[0])

    def __repr__(self) -> str:
        return f'{self.name}()'

# %%
def set_random_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    torch.cuda.manual_seed_all(seed)

# %%
data_split_seed = 0
set_random_seed(data_split_seed)
# Dataset = 'Cora'
# Dataset = 'PubMed'
Dataset = 'CiteSeer'
# Dataset = 'Cornell' # "Cornell", "Texas", "Wisconsin"
# Dataset = 'squirrel' # "chameleon", "crocodile", "squirrel"
# Dataset = 'Actor'
# Dataset = 'Reddit'
# Dataset = 'BlogCataLog'
# Dataset = 'ogbn-products'
# Dataset = 'Flickr'
# Dataset = 'Simmons81' # 'Simmons81', 'UF21', 'Caltech36', 'Northeastern19', 'Tulane29', 'Hamilton46', 'Howard90', 'GWU54', 'UGA50'
transform = T.Compose([
    T.RandomNodeSplit(num_val=1000, num_test=1500, num_train_per_class=20),
    T.TargetIndegree(),
])
path = osp.join('../data', Dataset)
# dataset = Planetoid(path, Dataset, transform=transform)
dataset = Planetoid(path, Dataset, split='public') # 'geom-gcn'
# dataset = AttributedGraphDataset(path, Dataset)
# dataset = WebKB(path, name=Dataset)
# dataset = WikipediaNetwork(path, Dataset)
# dataset = Actor(path)
# dataset = Flickr(path)

# dataset = Facebook100(path, Dataset, split='random', \
#     num_val=500, num_test=None, num_train_per_class=200, transform=None, to_onehot=True)

# dataset = Reddit(path)
# dataset = AttributedGraphDataset(path, Dataset, transform=transform)
data = dataset[0]
# dataset = PygNodePropPredDataset(name=Dataset, root=path)
# split_idx = dataset.get_idx_split()
# data = dataset[0]
# data.train_mask = torch.Tensor([False] * data.x.shape[0]).bool()
# data.val_mask = torch.Tensor([False] * data.x.shape[0]).bool()
# data.test_mask = torch.Tensor([False] * data.x.shape[0]).bool()
# data.train_mask[split_idx['train']] = True
# data.val_mask[split_idx['valid']] = True
# data.test_mask[split_idx['test']] = True

print(data)
split_idx = 0
if Dataset in ["Cornell", "Texas", "Wisconsin", "Actor", "chameleon", "squirrel"]:
# if Dataset in ["Cornell", "Texas", "Wisconsin", "Actor", "chameleon", "squirrel", "Cora", "PubMed", "CiteSeer"]:
    data.train_mask = data.train_mask[:, split_idx].bool()
    data.val_mask = data.val_mask[:, split_idx].bool()
    data.test_mask = data.test_mask[:, split_idx].bool()
print(data.train_mask.sum(), data.val_mask.sum(), data.test_mask.sum())
print(Counter(data.y.view(-1).numpy()))
# for cls_id in range(dataset.num_classes):
#     mask_cls = data.y == cls_id
#     print(cls_id, (data.train_mask * mask_cls).sum().item())
# Out:
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# tensor(120) tensor(500) tensor(1000)
# Counter({3: 701, 2: 668, 4: 596, 1: 590, 5: 508, 0: 264})

# %%
# plot node degree distribution
from torch_geometric.utils import add_self_loops, degree
x, edge_index = data.x, data.edge_index
adj = torch.sparse.LongTensor(data.edge_index.cpu(), torch.ones(data.edge_index.shape[1]), torch.Size((data.x.shape[0], data.x.shape[0])))
# adj
row, col = edge_index
deg = degree(col, x.size(0), dtype=x.dtype)
print('Mean_degree:{:.2f}, min_degree:{}, max_degree:{}, std:{:.2f}'.format(deg.mean(), deg.min().long(), deg.max().long(), deg.std()))
print('${:.2f}\pm {:.2f}$'.format(deg.mean(), deg.std()))
deg = deg[torch.where(deg <= 100)] # degree clip
df_deg = pd.DataFrame({'degree':deg})
sns.displot(df_deg, x='degree', binwidth=1)
from collections import Counter
cnt = Counter()
for d in deg:
    cnt[d.long().item()] += 1
plt.scatter(list(cnt.keys()), list(cnt.values()))
# plt.title('[{}]Mean_degree:{:.2f}, min_degree:{}, max_degree:{}'.format(Dataset, deg.mean(), deg.min().long(), deg.max().long()))
plt.show()
# Out:
# Mean_degree:2.74, min_degree:0, max_degree:99, std:3.38
# $2.74\pm 3.38$

# %%
import torch_sparse
from torch_sparse import matmul
x, edge_index = data.x, data.edge_index
row, col = edge_index
deg = degree(col, x.size(0), dtype=x.dtype)
adj_sp = torch_sparse.SparseTensor(row=edge_index[0], col=edge_index[1], value=torch.ones(edge_index.shape[1]).to(edge_index.device), sparse_sizes=(x.shape[0], x.shape[0]))
print(adj_sp)
edge_index_2rd = torch_sparse.matmul(adj_sp, adj_sp.to_dense())
edge_index_2rd = torch.nonzero(edge_index_2rd, as_tuple=False)
edge_index_2rd = edge_index_2rd.transpose(0, 1)
adj_sp_2rd = torch_sparse.SparseTensor(row=edge_index_2rd[0], col=edge_index_2rd[1], value=torch.ones(edge_index_2rd.shape[1]).to(edge_index.device), sparse_sizes=(x.shape[0], x.shape[0]))
print(adj_sp_2rd)
homo_ratio = (data.y[edge_index[0]] == data.y[edge_index[1]]).sum() / edge_index.shape[1]
homo_ratio_2rd = (data.y[edge_index_2rd[0]] == data.y[edge_index_2rd[1]]).sum() / edge_index_2rd.shape[1]
print('homophily ratio:', homo_ratio.item())
print('homophily ratio 2rd neibors:', homo_ratio_2rd.item())
# Out:
# SparseTensor(row=tensor([   0,    1,    1,  ..., 3324, 3325, 3326]),
#              col=tensor([ 628,  158,  486,  ..., 2820, 1643,   33]),
#              val=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#              size=(3327, 3327), nnz=9104, density=0.08%)
# SparseTensor(row=tensor([   0,    1,    1,  ..., 3326, 3326, 3326]),
#              col=tensor([   0,    1,   12,  ..., 3193, 3197, 3326]),
#              val=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#              size=(3327, 3327), nnz=44821, density=0.40%)
# homophily ratio: 0.7355008721351624
# homophily ratio 2rd neibors: 0.7647085189819336

# %%
# y_onehot = F.one_hot(data.y)

# # x_lbl = y_onehot
# x_lbl = torch.zeros_like(y_onehot)
# x_lbl[data.train_mask] = y_onehot[data.train_mask]

# x_lbl = x_lbl.float()

# # label distribution 1st-order
# lbl_dist = matmul(adj_sp, x_lbl, reduce='sum')
# norm = lbl_dist.norm(p=2, dim=1).view(-1, 1)
# norm = torch.matmul(norm, norm.T)
# norm[norm == 0] = 1e-8
# lbl_sim = torch.matmul(lbl_dist, lbl_dist.T) / norm
# print((lbl_sim > 0.99).sum(1).float().mean(), lbl_sim[0])
# # label distribution 2rd-order
# lbl_dist_2rd = matmul(adj_sp_2rd, x_lbl, reduce='sum')
# norm2 = lbl_dist_2rd.norm(p=2, dim=1).view(-1, 1)
# norm2 = torch.matmul(norm2, norm2.T) + 1e-8
# lbl_sim_2rd = torch.matmul(lbl_dist_2rd, lbl_dist_2rd.T) / norm2
# print((lbl_sim_2rd > 0.99).sum(1).float().mean(), lbl_sim_2rd[0])
# lbl_sim_merge = lbl_sim * lbl_sim_2rd
# print((lbl_sim_merge > 0.99).sum(1).float().mean(), lbl_sim_merge[0])
# lbl_sim[lbl_sim > 0].min(), lbl_sim[lbl_sim > 0].max(), lbl_sim[lbl_sim > 0].mean(), lbl_sim[(lbl_sim > 0) * (lbl_sim < 0.99)].mean()

# %%
# adj_lbl = torch.matmul(x_lbl, x_lbl.T)
# # adj_lbl = torch.matmul(y_onehot, y_onehot.T)
# adj_lbl -= torch.diag_embed(adj_lbl.diag())
# edge_index_lbl = torch.stack(adj_lbl.nonzero(as_tuple=True), dim=0)
# print(edge_index_lbl.shape)
# print((data.y[edge_index_lbl[0]] == data.y[edge_index_lbl[1]]).sum() / edge_index_lbl.shape[1])

# %%
def train_Sim(data, model, optimizer, clip_grad=False):
    model.train()
    optimizer.zero_grad()
    loss, recons_loss, emb_y_dist_diff = model(data)
    print('recons_loss:{:.4f} | emb_y_dist_diff:{:.4f}'.format(recons_loss.detach().item(), emb_y_dist_diff.detach().item()))
    loss.backward()
    if clip_grad:
        clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2, error_if_nonfinite=True)
    optimizer.step()
    return loss.detach().item()

def finetune_Sim(data, model, optimizer, clip_grad=False):
    model.train()
    optimizer.zero_grad()
    loss = model(data, finetune=True)
    # print('emb_y_dist_diff:{:.4f}'.format( loss.detach().item()))
    loss.backward()
    if clip_grad:
        clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2, error_if_nonfinite=True)
    optimizer.step()
    return loss.detach().item()


def train_AE(data, model, optimizer, clip_grad=False):
    model.train()
    optimizer.zero_grad()
    # loss = F.nll_loss(model(data)[data.train_mask], data.y[data.train_mask])
    x_encode, x_decode = model(data.x)
    # print(x_encode)
    loss = F.mse_loss(data.x, x_decode)
    loss.backward()
    if clip_grad:
        clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2, error_if_nonfinite=True)
    optimizer.step()
    return loss.detach().item()


# @torch.no_grad()
def test_AE(data, model, dataset_name):
    with torch.no_grad():
        model.eval()
        log_probs, accs = model(data), []
        for _, mask in data('train_mask', 'val_mask', 'test_mask'):
            pred = log_probs[mask].max(1)[1]
            acc = pred.eq(data.y[mask]).sum().item() / mask.sum().item()
            accs.append(acc)
        return accs

# %%
# AutoEncoder
class AutoEncoder(nn.Module):
    def __init__(self, in_size, emb_size=64):
        super(AutoEncoder, self).__init__()

        self.encoder = nn.Sequential(
            nn.Linear(in_size, 256),
            nn.Tanh(),
            nn.Linear(256, 128),
            nn.Tanh(),
            nn.Linear(128, emb_size),
        )
        self.decoder = nn.Sequential(
            nn.Linear(emb_size, 128),
            nn.Tanh(),
            nn.Linear(128, 256),
            nn.Tanh(),
            nn.Linear(256, in_size),
            # nn.ReLU(),
        )
        self.reset_parameters()
    def reset_parameters(self):
        for m in self.encoder:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0)
        for m in self.decoder:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0)
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return encoded, decoded

# %%
# Similiar Encoder
from torch_sparse import SparseTensor, set_diag
from torch_geometric.utils import remove_self_loops
class SimEncoder(nn.Module):
    def __init__(self, in_size, emb_size=64):
        super(SimEncoder, self).__init__()

        self.encoder_pre = nn.Sequential(
            nn.Linear(in_size, emb_size),
        )
        # self.encoder_pre = nn.Sequential(
        #     nn.Linear(in_size, 256),
        #     nn.Tanh(),
        #     nn.Linear(256, 128),
        #     nn.Tanh(),
        #     nn.Linear(128, emb_size),
        # )
        
        # self.encoder_post = nn.Sequential(
        #     nn.Linear(emb_size, 256),
        #     nn.Tanh(),
        #     nn.Linear(256, 128),
        # )
        self.encoder_post = nn.Sequential(
            nn.Linear(emb_size, emb_size),
        )
        # self.encoder_post = nn.Sequential(
        #     nn.Linear(in_size, in_size),
        # )
        self.x_sim = None
        self.adj_t_cache = None

        self.lbl_neb_mask = None
        self.lbl_sim = None

        self.reset_parameters()
    def reset_parameters(self):
        for m in self.encoder_pre:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0)
        for m in self.encoder_post:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight)
                nn.init.constant_(m.bias, 0)
    
    def moment_calculation(self, adj_t: SparseTensor,
                              x: Tensor,
                              moment: int = 3):
        mu = matmul(adj_t, x, reduce='mean')

        out = [mu]
        if moment > 1:
            if self.use_center_moment:
                sigma = matmul(adj_t, (x - mu).pow(2), reduce='mean')
            else:
                sigma = matmul(adj_t, (x).pow(2), reduce='mean')
            
            sigma[sigma == 0] = 1e-16
            sigma = sigma.sqrt()
            out.append(sigma)

            for order in range(3, moment+1):
                gamma = matmul(adj_t, x.pow(order), reduce='mean')
                mask_neg = None
                if torch.any(gamma == 0):
                    gamma[gamma == 0] = 1e-16
                if torch.any(gamma < 0):
                    mask_neg = gamma < 0
                    gamma[mask_neg] *= -1
                
                gamma = gamma.pow(1/order)
                if mask_neg != None:
                    gamma[mask_neg] *= -1
                out.append(gamma)
        # print(len(out), adj_t)
        return out

    def cal_similarity_batch(self, x, adj_t, batch_src, batch_tar, embedding=False, cat_self=False):
        # x = x - x.mean(dim=0, keepdim=True) # subtract center

        # x_dist = matmul(adj_t, x, reduce='sum')
        # x_dist = torch.cat(self.moment_calculation(adj_t, x_emb, moment=1), dim=-1)
        x_dist = torch.cat(self.moment_calculation(adj_t, x, moment=1), dim=-1)
        if embedding:
            x_dist = self.encoder_post(x_dist)
        
        # concat self
        if cat_self:
            x_dist = torch.cat([x, x_dist], dim=-1)
        # Decentralize
        x_dist -= x_dist.mean(dim=0, keepdim=True)

        x_dist_src = x_dist[batch_src]
        x_dist_tar = x_dist[batch_tar]
        norm1 = x_dist_src.norm(p=2, dim=1).view(-1, 1)
        norm2 = x_dist_tar.norm(p=2, dim=1).view(-1, 1)
        norm = torch.matmul(norm1, norm2.T) + 1e-8
        sim = torch.matmul(x_dist_src, x_dist_tar.T) / norm # n1, n2

        # # dot product
        # sim = torch.matmul(x_dist, x_dist.T)
        return sim
    
    def cal_similarity(self, x, adj_t, embedding=False, cat_self=False):
        # x = x - x.mean(dim=0, keepdim=True) # subtract center

        # x_dist = matmul(adj_t, x, reduce='sum')
        # x_dist = torch.cat(self.moment_calculation(adj_t, x_emb, moment=1), dim=-1)
        x_dist = torch.cat(self.moment_calculation(adj_t, x, moment=1), dim=-1)
        if embedding:
            x_dist = self.encoder_post(x_dist)
        
        # concat self
        if cat_self:
            x_dist = torch.cat([x, x_dist], dim=-1)

        x_dist -= x_dist.mean(dim=0, keepdim=True)
        
        norm = x_dist.norm(p=2, dim=1).view(-1, 1)
        norm = torch.matmul(norm, norm.T) + 1e-8
        sim = torch.matmul(x_dist, x_dist.T) / norm

        # # dot product
        # sim = torch.matmul(x_dist, x_dist.T)
        return sim
    
    def cal_emb_y_distance(self, emb_sim, y_sim, mask):
        # diff = (self.gather(emb_sim, mask, mask) - self.gather(y_sim, mask, mask)).pow(2)
        diff = (emb_sim - self.gather(y_sim, mask, mask, emb_sim.device)).pow(2)
        return diff
    
    def gather(self, mat, idx1, idx2, device=None):
        mat = mat[idx1, :]
        mat = mat[:, idx2]
        if device:
            mat = mat.to(device)
        return mat
    
    def forward(self, data, batch_src=None, batch_tar=None, finetune=False):
        x, edge_index = data.x, data.edge_index
        if  self.adj_t_cache == None:
            self.adj_t_cache = torch_sparse.SparseTensor(row=edge_index[0], col=edge_index[1], value=torch.ones(edge_index.shape[1]).to(edge_index.device), sparse_sizes=(x.shape[0], x.shape[0]))
        
        if self.lbl_sim is None or self.lbl_neb_mask is None:
            print('preparing label similarity matrix.')
            device = x.device
            self.adj_t_cache = self.adj_t_cache.cpu()
            self.prepare_lbl_sim(data.cpu())
            data = data.to(device)
            self.adj_t_cache = self.adj_t_cache.to(device)

            # self.lbl_sim = self.lbl_sim.to(device)
            self.lbl_neb_mask = self.lbl_neb_mask.to(device)
            
        if self.x_sim is None:
            print('preparing feature similarity matrix.')
            # self.x_sim = self.cal_similarity(x, self.adj_t_cache) # (N, N)
            device = x.device
            self.x_sim = self.cal_similarity(x.cpu(), self.adj_t_cache.cpu()) # (N, N)
            x = x.to(device)
            self.adj_t_cache = self.adj_t_cache.to(device)
            print(self.x_sim.device, self.lbl_sim.device, self.lbl_neb_mask.device)
        
        emb = self.encoder_pre(x)
        # emb = x
        
        # recons_loss = (emb_sim - self.x_sim).pow(2).mean().sqrt()
        if finetune:
            # emb_sim = self.cal_similarity(emb, self.adj_t_cache, embedding=True) # (n1,n2)
            emb_sim = self.cal_similarity_batch(emb, self.adj_t_cache, self.lbl_neb_mask, self.lbl_neb_mask, embedding=True) # (N,N)
            # emb_y_dist_diff = self.cal_emb_y_distance(emb_sim, self.lbl_sim, self.lbl_neb_mask)
            # emb_y_dist_diff = (self.gather(emb_sim, self.lbl_neb_mask, self.lbl_neb_mask) - self.gather(self.lbl_sim, self.lbl_neb_mask, self.lbl_neb_mask)).pow(2)
            emb_y_dist_diff = (emb_sim - self.gather(self.lbl_sim, self.lbl_neb_mask, self.lbl_neb_mask, emb_sim.device)).pow(2)
            loss = (emb_y_dist_diff.sum() / self.lbl_neb_mask.sum().float()).sqrt()
            # loss = (emb_y_dist_diff.sum() / self.lbl_neb_mask.sum().float().sqrt()).sqrt()
        else:
            # emb_sim = self.cal_similarity(emb, self.adj_t_cache, embedding=True) # (N,N)
            # recons_loss = (self.gather(emb_sim, batch_src, batch_tar) - self.gather(self.x_sim, batch_src, batch_tar, x.device)).pow(2)

            emb_sim = self.cal_similarity_batch(emb, self.adj_t_cache, batch_src, batch_tar, embedding=True) # (n1,n2)
            recons_loss = (emb_sim - self.gather(self.x_sim, batch_src, batch_tar, x.device)).pow(2)

            # loss = recons_loss.mean().sqrt() + (emb_y_dist_diff.sum() / self.lbl_neb_mask.sum()).sqrt()
            # loss = (recons_loss + emb_y_dist_diff).mean().sqrt()
            loss = recons_loss.mean().sqrt()
        # return loss, recons_loss.mean().sqrt(), (emb_y_dist_diff.sum() / self.lbl_neb_mask.sum().float().sqrt()).sqrt()
        return loss
        # return loss, recons_loss.mean().sqrt(), torch.zeros(1)

    def get_emb_sim(self, x, embedding=True, cat_self=False):
        emb = self.encoder_pre(x)
        # emb = x
        emb_sim = self.cal_similarity(emb, self.adj_t_cache, embedding=embedding, cat_self=cat_self)
        return emb_sim, emb
    
    def prepare_lbl_sim(self, data, thres_min_deg=3., thres_min_deg_ratio=0.8):
        N = data.num_nodes
        x, edge_index = data.x ,data.edge_index
        # lbl_sim
        edge_index = coalesce(edge_index, None, N, N)[0]
        _, col = edge_index
        mask_src_train = data.train_mask[data.edge_index[0]]
        deg_mask = degree(col[mask_src_train], x.size(0), dtype=x.dtype) # in degree, only count the src nodes in the training set.
        self.lbl_neb_mask = (deg_mask >= thres_min_deg)
        deg = degree(col, x.size(0), dtype=x.dtype)
        self.lbl_neb_mask_ratio = (deg_mask.float() / (1e-5 + deg.float())) > thres_min_deg_ratio
        self.lbl_neb_mask += self.lbl_neb_mask_ratio
        # self.lbl_neb_mask *= self.lbl_neb_mask_ratio
        print('candidate set size:', self.lbl_neb_mask.sum())
        # self.lbl_neb_mask = torch.matmul(self.lbl_neb_mask.float().unsqueeze(-1), self.lbl_neb_mask.float().unsqueeze(0)).bool() # (N, N)
        
        y_onehot = F.one_hot(data.y)
        # x_lbl = y_onehot
        x_lbl = torch.zeros_like(y_onehot)
        x_lbl[data.train_mask] = y_onehot[data.train_mask]
        x_lbl = x_lbl.float().to(edge_index.device)

        # label distribution 1st-order
        lbl_dist = matmul(self.adj_t_cache, x_lbl, reduce='sum')
        norm = lbl_dist.norm(p=2, dim=1).view(-1, 1)
        norm = torch.matmul(norm, norm.T) # (N, N)
        norm[norm == 0] = 1e-8
        lbl_sim = torch.matmul(lbl_dist, lbl_dist.T) / norm # (N, N)
        # print((lbl_sim > 0.99).sum(1).float().mean(), lbl_sim[0])
        
        # label distribution 2rd-order
        value = edge_index.new_ones((edge_index.size(1), ), dtype=torch.float)
        edge_index_2nd, value = torch_sparse.spspmm(edge_index, value, edge_index, value, N, N, N)
        value.fill_(0)
        edge_index_2nd, value = remove_self_loops(edge_index_2nd, value)
        adj_sp_2nd = torch_sparse.SparseTensor(row=edge_index_2nd[0], col=edge_index_2nd[1], value=torch.ones(edge_index_2nd.shape[1]).to(edge_index.device), sparse_sizes=(N, N))
        # lbl_dist_2nd = matmul(adj_sp_2rd.to(edge_index.device), x_lbl, reduce='sum')
        lbl_dist_2nd = matmul(adj_sp_2nd, x_lbl, reduce='sum')
        norm2 = lbl_dist_2nd.norm(p=2, dim=1).view(-1, 1)
        norm2 = torch.matmul(norm2, norm2.T) + 1e-8
        lbl_sim_2nd = torch.matmul(lbl_dist_2nd, lbl_dist_2nd.T) / norm2 # (N, N)
        # print((lbl_sim_2nd > 0.99).sum(1).float().mean(), lbl_sim_2nd[0])

        lbl_sim_merge = lbl_sim * lbl_sim_2nd # (N, N)
        # lbl_sim_merge = lbl_sim
        # print((lbl_sim_merge > 0.99).sum(1).float().mean(), lbl_sim_merge[0])
        self.lbl_sim = lbl_sim_merge
        # self.lbl_sim -= torch.diag_embed(self.lbl_sim.diag())

# %%
def train_Sim_batch(data, model, optimizer, batch_src, batch_tar, clip_grad=False):
    model.train()
    optimizer.zero_grad()
    loss = model(data, batch_src, batch_tar)
    # print('froward done.', loss.device)
    loss.backward()
    if clip_grad:
        clip_grad_norm_(model.parameters(), max_norm=20, norm_type=2, error_if_nonfinite=True)
    optimizer.step()
    # print('recons_loss:{:.4f} '.format(loss.detach().item()))
    return loss.detach().item()

# %%
idxs = torch.arange(data.num_nodes)
# bs = data.num_nodes
bs = [10000, 10000]
shuffle = [False, False]
src_idx_loader = torch.utils.data.DataLoader(idxs, batch_size=bs[0], shuffle=shuffle[0])
tar_idx_loader = torch.utils.data.DataLoader(idxs, batch_size=bs[1], shuffle=shuffle[1])

moments1 = []
attentions1 = []
moments2 = []
attentions2 = []


history_val = []
history_test = []
# for model_init_seed in range(10):
for model_init_seed in [0]:
    # model_init_seed = 2
    set_random_seed(model_init_seed)
    device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
    print(device)
    # model = AutoEncoder(in_size=data.x.shape[1], emb_size=64)
    model = SimEncoder(in_size=data.x.shape[1], emb_size=128)
    model = model.to(device)
    data = data.to(device)
    num_epoch = 100

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-3)

    best_acc = {
        'train': 0,
        'val': 0,
        'test': 0
    }

    for epoch in range(1, 1+num_epoch):
        t0 = time.time()
        # loss_train = train_Sim(data, model, optimizer)
        for batch_src in src_idx_loader:
            for batch_tar in tar_idx_loader:
                # print('src:[{}, {}] -> tar:[{}, {}]'.format(batch_src.min(), batch_src.max(), batch_tar.min(), batch_tar.max()))
                loss_train = train_Sim_batch(data, model, optimizer, batch_src, batch_tar)
        # eval_res = test(data, model, dataset_name=Dataset)
        log = 'Epoch: {:03d}, Reconstruction Loss:{:.4f} Time(s/epoch):{:.4f}'.format(epoch, loss_train, time.time() - t0)
        print(log)
    
    print('Begin finetuning...')
    num_epoch_finetune = 10
    for epoch in range(1, 1+num_epoch_finetune):
        t0 = time.time()
        loss_train = finetune_Sim(data, model, optimizer)
        # eval_res = test(data, model, dataset_name=Dataset)
        log = 'Epoch: {:03d}, Supervised Loss:{:.4f} Time(s/epoch):{:.4f}'.format(epoch, loss_train, time.time() - t0)
        print(log)
# Out:
# cuda:1
# preparing label similarity matrix.
# candidate set size: tensor(63)
# preparing feature similarity matrix.
# cpu cpu cuda:1
# Epoch: 001, Reconstruction Loss:0.1240 Time(s/epoch):0.2871
# Epoch: 002, Reconstruction Loss:0.1168 Time(s/epoch):0.0399
# Epoch: 003, Reconstruction Loss:0.1121 Time(s/epoch):0.0383
# Epoch: 004, Reconstruction Loss:0.1086 Time(s/epoch):0.0366
# Epoch: 005, Reconstruction Loss:0.1056 Time(s/epoch):0.0396
# Epoch: 006, Reconstruction Loss:0.1031 Time(s/epoch):0.0376
# Epoch: 007, Reconstruction Loss:0.1009 Time(s/epoch):0.0368
# Epoch: 008, Reconstruction Loss:0.0989 Time(s/epoch):0.0374
# Epoch: 009, Reconstruction Loss:0.0971 Time(s/epoch):0.0403
# Epoch: 010, Reconstruction Loss:0.0953 Time(s/epoch):0.0373
# Epoch: 011, Reconstruction Loss:0.0937 Time(s/epoch):0.0371
# Epoch: 012, Reconstruction Loss:0.0921 Time(s/epoch):0.0412
# Epoch: 013, Reconstruction Loss:0.0907 Time(s/epoch):0.0387
# Epoch: 014, Reconstruction Loss:0.0893 Time(s/epoch):0.0387
# Epoch: 015, Reconstruction Loss:0.0880 Time(s/epoch):0.0385
# Epoch: 016, Reconstruction Loss:0.0867 Time(s/epoch):0.0389
# Epoch: 017, Reconstruction Loss:0.0855 Time(s/epoch):0.0388
# Epoch: 018, Reconstruction Loss:0.0843 Time(s/epoch):0.1769
# Epoch: 019, Reconstruction Loss:0.0832 Time(s/epoch):0.0374
# Epoch: 020, Reconstruction Loss:0.0821 Time(s/epoch):0.0405
# Epoch: 021, Reconstruction Loss:0.0810 Time(s/epoch):0.0385
# Epoch: 022, Reconstruction Loss:0.0800 Time(s/epoch):0.0375
# Epoch: 023, Reconstruction Loss:0.0790 Time(s/epoch):0.0370
# Epoch: 024, Reconstruction Loss:0.0780 Time(s/epoch):0.0424
# Epoch: 025, Reconstruction Loss:0.0771 Time(s/epoch):0.0376
# Epoch: 026, Reconstruction Loss:0.0762 Time(s/epoch):0.0371
# Epoch: 027, Reconstruction Loss:0.0753 Time(s/epoch):0.0379
# Epoch: 028, Reconstruction Loss:0.0744 Time(s/epoch):0.0389
# Epoch: 029, Reconstruction Loss:0.0736 Time(s/epoch):0.0381
# Epoch: 030, Reconstruction Loss:0.0729 Time(s/epoch):0.0392
# Epoch: 031, Reconstruction Loss:0.0721 Time(s/epoch):0.0395
# Epoch: 032, Reconstruction Loss:0.0714 Time(s/epoch):0.0377
# Epoch: 033, Reconstruction Loss:0.0707 Time(s/epoch):0.0377
# Epoch: 034, Reconstruction Loss:0.0700 Time(s/epoch):0.0370
# Epoch: 035, Reconstruction Loss:0.0693 Time(s/epoch):0.0374
# Epoch: 036, Reconstruction Loss:0.0687 Time(s/epoch):0.0378
# Epoch: 037, Reconstruction Loss:0.0680 Time(s/epoch):0.0371
# Epoch: 038, Reconstruction Loss:0.0674 Time(s/epoch):0.0453
# Epoch: 039, Reconstruction Loss:0.0668 Time(s/epoch):0.0369
# Epoch: 040, Reconstruction Loss:0.0662 Time(s/epoch):0.0396
# Epoch: 041, Reconstruction Loss:0.0658 Time(s/epoch):0.0442
# Epoch: 042, Reconstruction Loss:0.0658 Time(s/epoch):0.0387
# Epoch: 043, Reconstruction Loss:0.0660 Time(s/epoch):0.0408
# Epoch: 044, Reconstruction Loss:0.0654 Time(s/epoch):0.0431
# Epoch: 045, Reconstruction Loss:0.0655 Time(s/epoch):0.0421
# Epoch: 046, Reconstruction Loss:0.0663 Time(s/epoch):0.0471
# Epoch: 047, Reconstruction Loss:0.0698 Time(s/epoch):0.0384
# Epoch: 048, Reconstruction Loss:0.0697 Time(s/epoch):0.0410
# Epoch: 049, Reconstruction Loss:0.0733 Time(s/epoch):0.0389
# Epoch: 050, Reconstruction Loss:0.0715 Time(s/epoch):0.0384
# Epoch: 051, Reconstruction Loss:0.0742 Time(s/epoch):0.0393
# Epoch: 052, Reconstruction Loss:0.0688 Time(s/epoch):0.0386
# Epoch: 053, Reconstruction Loss:0.0696 Time(s/epoch):0.1555
# Epoch: 054, Reconstruction Loss:0.0683 Time(s/epoch):0.0366
# Epoch: 055, Reconstruction Loss:0.0668 Time(s/epoch):0.0374
# Epoch: 056, Reconstruction Loss:0.0662 Time(s/epoch):0.0388
# Epoch: 057, Reconstruction Loss:0.0657 Time(s/epoch):0.0372
# Epoch: 058, Reconstruction Loss:0.0652 Time(s/epoch):0.0383
# Epoch: 059, Reconstruction Loss:0.0646 Time(s/epoch):0.0371
# Epoch: 060, Reconstruction Loss:0.0641 Time(s/epoch):0.0390
# Epoch: 061, Reconstruction Loss:0.0638 Time(s/epoch):0.0396
# Epoch: 062, Reconstruction Loss:0.0634 Time(s/epoch):0.0371
# Epoch: 063, Reconstruction Loss:0.0631 Time(s/epoch):0.0373
# Epoch: 064, Reconstruction Loss:0.0628 Time(s/epoch):0.0375
# Epoch: 065, Reconstruction Loss:0.0624 Time(s/epoch):0.0370
# Epoch: 066, Reconstruction Loss:0.0621 Time(s/epoch):0.0372
# Epoch: 067, Reconstruction Loss:0.0618 Time(s/epoch):0.0381
# Epoch: 068, Reconstruction Loss:0.0616 Time(s/epoch):0.0378
# Epoch: 069, Reconstruction Loss:0.0614 Time(s/epoch):0.0371
# Epoch: 070, Reconstruction Loss:0.0612 Time(s/epoch):0.0385
# Epoch: 071, Reconstruction Loss:0.0610 Time(s/epoch):0.0443
# Epoch: 072, Reconstruction Loss:0.0608 Time(s/epoch):0.0416
# Epoch: 073, Reconstruction Loss:0.0606 Time(s/epoch):0.0383
# Epoch: 074, Reconstruction Loss:0.0604 Time(s/epoch):0.0386
# Epoch: 075, Reconstruction Loss:0.0603 Time(s/epoch):0.0391
# Epoch: 076, Reconstruction Loss:0.0601 Time(s/epoch):0.0383
# Epoch: 077, Reconstruction Loss:0.0600 Time(s/epoch):0.0375
# Epoch: 078, Reconstruction Loss:0.0598 Time(s/epoch):0.0372
# Epoch: 079, Reconstruction Loss:0.0597 Time(s/epoch):0.0408
# Epoch: 080, Reconstruction Loss:0.0596 Time(s/epoch):0.0457
# Epoch: 081, Reconstruction Loss:0.0595 Time(s/epoch):0.0418
# Epoch: 082, Reconstruction Loss:0.0593 Time(s/epoch):0.0386
# Epoch: 083, Reconstruction Loss:0.0592 Time(s/epoch):0.0438
# Epoch: 084, Reconstruction Loss:0.0591 Time(s/epoch):0.0450
# Epoch: 085, Reconstruction Loss:0.0590 Time(s/epoch):0.0369
# Epoch: 086, Reconstruction Loss:0.0588 Time(s/epoch):0.0371
# Epoch: 087, Reconstruction Loss:0.0587 Time(s/epoch):0.0391
# Epoch: 088, Reconstruction Loss:0.0586 Time(s/epoch):0.0428
# Epoch: 089, Reconstruction Loss:0.0585 Time(s/epoch):0.0431
# Epoch: 090, Reconstruction Loss:0.0584 Time(s/epoch):0.0410
# Epoch: 091, Reconstruction Loss:0.0583 Time(s/epoch):0.0372
# Epoch: 092, Reconstruction Loss:0.0582 Time(s/epoch):0.0369
# Epoch: 093, Reconstruction Loss:0.0581 Time(s/epoch):0.0390
# Epoch: 094, Reconstruction Loss:0.0580 Time(s/epoch):0.0390
# Epoch: 095, Reconstruction Loss:0.0580 Time(s/epoch):0.0389
# Epoch: 096, Reconstruction Loss:0.0580 Time(s/epoch):0.0395
# Epoch: 097, Reconstruction Loss:0.0586 Time(s/epoch):0.0388
# Epoch: 098, Reconstruction Loss:0.0587 Time(s/epoch):0.0387
# Epoch: 099, Reconstruction Loss:0.0902 Time(s/epoch):0.0422
# Epoch: 100, Reconstruction Loss:0.2748 Time(s/epoch):0.0389
# Begin finetuning...
# Epoch: 001, Supervised Loss:1.6756 Time(s/epoch):0.0060
# Epoch: 002, Supervised Loss:2.2871 Time(s/epoch):0.0048
# Epoch: 003, Supervised Loss:1.7554 Time(s/epoch):0.0042
# Epoch: 004, Supervised Loss:1.6291 Time(s/epoch):0.0044
# Epoch: 005, Supervised Loss:1.5685 Time(s/epoch):0.0044
# Epoch: 006, Supervised Loss:1.5239 Time(s/epoch):0.0051
# Epoch: 007, Supervised Loss:1.4980 Time(s/epoch):0.0044
# Epoch: 008, Supervised Loss:1.4802 Time(s/epoch):0.0043
# Epoch: 009, Supervised Loss:1.4669 Time(s/epoch):0.0054
# Epoch: 010, Supervised Loss:1.4572 Time(s/epoch):0.0053

# %%
import scipy.sparse as sp
import networkx as nx
def normalize_sparse_adj(mx):
    """Row-normalize sparse matrix: symmetric normalized Laplacian"""
    rowsum = np.array(mx.sum(1))
    r_inv_sqrt = np.power(rowsum, -0.5).flatten()
    r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
    r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
    return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)

def normalize_features(mx):
    """Row-normalize sparse matrix"""
    rowsum = np.array(mx.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    mx = r_mat_inv.dot(mx)
    return mx

class GCNLayer(nn.Module):
    """
    Simple GCN layer, similar to https://arxiv.org/abs/1609.02907
    """

    def __init__(self, in_features, out_features, bias=False, batch_norm=False):
        super(GCNLayer, self).__init__()
        self.weight = torch.Tensor(in_features, out_features)
        self.weight = nn.Parameter(nn.init.xavier_uniform_(self.weight))
        if bias:
            self.bias = torch.Tensor(out_features)
            self.bias = nn.Parameter(nn.init.xavier_uniform_(self.bias))
        else:
            self.register_parameter('bias', None)

        self.bn = nn.BatchNorm1d(out_features) if batch_norm else None

    def forward(self, input, adj, batch_norm=True):
        support = torch.matmul(input, self.weight)
        output = torch.matmul(adj, support)

        if self.bias is not None:
            output = output + self.bias

        if self.bn is not None and batch_norm:
            output = self.compute_bn(output)

        return output

    def compute_bn(self, x):
        if len(x.shape) == 2:
            return self.bn(x)
        else:
            return self.bn(x.view(-1, x.size(-1))).view(x.size())


class GCN_idgl(nn.Module):
    def __init__(self, nfeat, nhid, nclass, graph_hops, dropout, batch_norm=False):
        super(GCN_idgl, self).__init__()
        self.dropout = dropout

        self.graph_encoders = nn.ModuleList()
        self.graph_encoders.append(GCNLayer(nfeat, nhid, batch_norm=batch_norm))

        for _ in range(graph_hops - 2):
            self.graph_encoders.append(GCNLayer(nhid, nhid, batch_norm=batch_norm))

        self.graph_encoders.append(GCNLayer(nhid, nclass, batch_norm=False))
        self.adj_cache = None


    def forward(self, data):
        if self.adj_cache is None:
            self.adj_cache = nx.adjacency_matrix(torch_geometric.utils.to_networkx(data))
            self.adj_cache = self.adj_cache + sp.eye(self.adj_cache.shape[0])
            self.adj_cache = normalize_sparse_adj(self.adj_cache)
            self.adj_cache = torch.Tensor(self.adj_cache.todense()).to(data.x.device)
        x = data.x
        adj = self.adj_cache
        x = torch.Tensor(normalize_features(data.x.cpu().numpy())).to(data.x.device) # feat norm
        x = F.dropout(x, 0.5, training=self.training) # dropout feature
        adj = F.dropout(self.adj_cache, 0.5, training=self.training)
        for i, encoder in enumerate(self.graph_encoders[:-1]):
            x = F.relu(encoder(x, adj))
            x = F.dropout(x, self.dropout, training=self.training)
        x = self.graph_encoders[-1](x, adj)
        return F.log_softmax(x, dim=-1)

# %%
# import functions for model training
import random
import time
import sys
sys.path.append('./models')
from model import *


device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

def train(data, model, optimizer, clip_grad=False):
    model.train()
    optimizer.zero_grad()
    loss = F.nll_loss(model(data)[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    return loss.detach().item()


# @torch.no_grad()
def test(data, model, dataset_name):
    with torch.no_grad():
        model.eval()
        log_probs, accs = model(data), []
        for _, mask in data('train_mask', 'val_mask', 'test_mask'):
            pred = log_probs[mask].max(1)[1]
            score = pred.eq(data.y[mask]).sum().item() / mask.sum().item() # acc
            # score = f1_score(data.y[mask].cpu().numpy(), pred.detach().cpu().numpy(), average='micro')
            accs.append(score)
        return accs

def main(data, save=True, repeat=3, num_epoch=200, gnn='GCN', seed=None):
    data = data.to(device)
    final_acc = {
            'train': [],
            'val': [],
            'test': []
        }
    for train_id in range(1, 1+repeat):
        print('repeat {}/{}'.format(train_id, repeat))
        

        # if Dataset in ["Cornell", "Texas", "Wisconsin", "Actor"]:
        #     data_split_seed = 0
        #     model_init_seed = train_id - 1
        #     # data_split_seed = int((train_id - 1) / 3)
        #     # model_init_seed = int((train_id - 1) % 3)
            
        #     data.train_mask = train_mask[:, data_split_seed]
        #     data.val_mask = val_mask[:, data_split_seed]
        #     data.test_mask = test_mask[:, data_split_seed]
        # else:
        data_split_seed = 0
        model_init_seed = train_id - 1
        if seed is not None:
            model_init_seed = 42

        set_random_seed(model_init_seed)

        num_layer = 2
        hidden = 64
        if gnn == 'MLP':
            model = MLP(dataset.num_features, dataset.num_classes, hidden=hidden)
        elif gnn == 'GCN':
            model = GCNNet(dataset, num_layer, hidden=hidden)
            # model = GCN_idgl(dataset.num_features, 64, dataset.num_classes, num_layer, dropout=0.5, batch_norm=False)
        elif gnn == 'GAT':
            model = GAT(dataset=dataset, hidden=hidden)
        elif gnn == 'GraphSAGE':
            model = GraphSAGE(dataset, num_layer, hidden=hidden)
        elif gnn == 'GATv2':
            model = GATv2(in_channels=dataset.num_features, hidden_channels=hidden, out_channels=dataset.num_classes, num_layers=num_layer, heads=1, dropout=0.5, att_dropout=0.5)
        else:
            raise NotImplementedError('Not Implemented Model:{}'.format(gnn))
        # model = myGATv2(in_channels=dataset.num_features, hidden_channels=hidden, out_channels=dataset.num_classes, num_layers=num_layer, heads=1, dropout=0.5, att_dropout=0.5)
        # 
        
        model = model.to(device)
        print(data)
        print(model)

        # data_split_seed = int((train_id - 1) / 3)
        # model_init_seed = int((train_id - 1) % 3)
        # set_random_seed(data_split_seed)
        print('auto fixed data split seed to {}, model init seed to {}'.format(data_split_seed, model_init_seed))

        print(data)
        print('[Dataset-{}] train_num:{}, val_num:{}, test_num:{}, class_num:{}'.format(dataset, data.train_mask.sum().item(), data.val_mask.sum().item(), data.test_mask.sum().item(), dataset.num_classes))

        # build optimizer
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-3)

        best_acc = {
            'train': 0,
            'val': 0,
            'test': 0,
            'loss': 666,
        }

        for epoch in range(1, 1+num_epoch):
            t0 = time.time()
                
            loss_train = train(data, model, optimizer)
            eval_res = test(data, model, dataset_name=Dataset)
            log = 'Epoch: {:03d}, Loss:{:.4f} Train: {:.4f}, Val:{:.4f}, Test: {:.4f}, Time(s/epoch):{:.4f}'.format(epoch, loss_train, *eval_res, time.time() - t0)
            print(log)
            if eval_res[1] > best_acc['val']:
            # if eval_res[1] > best_acc['val'] and loss_train < best_acc['loss']:
                best_acc['train'] = eval_res[0]
                best_acc['val'] = eval_res[1]
                best_acc['test'] = eval_res[2]
                best_acc['loss'] = loss_train
                if save:
                    torch.save(model.state_dict(), '../ckpt/model_best.ckpt')
            
        print('[Run-{} score] {}'.format(train_id, best_acc))
        final_acc['train'].append(best_acc['train'])
        final_acc['val'].append(best_acc['val'])
        final_acc['test'].append(best_acc['test'])
    best_test_run  = np.argmax(final_acc['test'])
    final_acc_avg = {}
    final_acc_std = {}
    for key in final_acc:
        best_acc[key] = max(final_acc[key])
        final_acc_avg[key] = np.mean(final_acc[key])
        final_acc_std[key] = np.std(final_acc[key])
    print('[Average Score] {} '.format(final_acc_avg)) 
    print('[std Score] {} '.format(final_acc_std))
    print('[Best Score] {}'.format(best_acc))
    print('[Best test run] {}'.format(best_test_run))

# %%
main(data, repeat=3, gnn='GCN')
# Out:
# repeat 1/3
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# GCNNet(
#   (convs): ModuleList(
#     (0): GCNConv(3703, 64)
#     (1): GCNConv(64, 6)
#   )
# )
# auto fixed data split seed to 0, model init seed to 0
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# [Dataset-CiteSeer()] train_num:120, val_num:500, test_num:1000, class_num:6
# Epoch: 001, Loss:1.7913 Train: 0.9083, Val:0.5340, Test: 0.5470, Time(s/epoch):0.0125
# Epoch: 002, Loss:1.4328 Train: 0.9583, Val:0.6380, Test: 0.6290, Time(s/epoch):0.0087
# Epoch: 003, Loss:1.0381 Train: 0.9500, Val:0.6600, Test: 0.6350, Time(s/epoch):0.0084
# Epoch: 004, Loss:0.7111 Train: 0.9500, Val:0.6780, Test: 0.6690, Time(s/epoch):0.0084
# Epoch: 005, Loss:0.4452 Train: 0.9750, Val:0.7000, Test: 0.6950, Time(s/epoch):0.0085
# Epoch: 006, Loss:0.2981 Train: 0.9750, Val:0.7020, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 007, Loss:0.2204 Train: 0.9833, Val:0.6920, Test: 0.6910, Time(s/epoch):0.0086
# Epoch: 008, Loss:0.1554 Train: 1.0000, Val:0.6880, Test: 0.6890, Time(s/epoch):0.0086
# Epoch: 009, Loss:0.1066 Train: 1.0000, Val:0.6860, Test: 0.6810, Time(s/epoch):0.0091
# Epoch: 010, Loss:0.0844 Train: 1.0000, Val:0.6800, Test: 0.6770, Time(s/epoch):0.0085
# Epoch: 011, Loss:0.0728 Train: 1.0000, Val:0.6860, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 012, Loss:0.0787 Train: 1.0000, Val:0.6880, Test: 0.6970, Time(s/epoch):0.0085
# Epoch: 013, Loss:0.0668 Train: 1.0000, Val:0.6860, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 014, Loss:0.0536 Train: 1.0000, Val:0.6920, Test: 0.6830, Time(s/epoch):0.0085
# Epoch: 015, Loss:0.0633 Train: 1.0000, Val:0.6900, Test: 0.6810, Time(s/epoch):0.0085
# Epoch: 016, Loss:0.0520 Train: 1.0000, Val:0.6920, Test: 0.6770, Time(s/epoch):0.0084
# Epoch: 017, Loss:0.0576 Train: 1.0000, Val:0.6960, Test: 0.6810, Time(s/epoch):0.0088
# Epoch: 018, Loss:0.0614 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 019, Loss:0.0595 Train: 1.0000, Val:0.6880, Test: 0.7020, Time(s/epoch):0.0085
# Epoch: 020, Loss:0.0732 Train: 1.0000, Val:0.6880, Test: 0.7050, Time(s/epoch):0.0085
# Epoch: 021, Loss:0.0709 Train: 1.0000, Val:0.6880, Test: 0.7010, Time(s/epoch):0.0088
# Epoch: 022, Loss:0.0869 Train: 1.0000, Val:0.6880, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 023, Loss:0.0911 Train: 1.0000, Val:0.6920, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 024, Loss:0.0856 Train: 1.0000, Val:0.6980, Test: 0.7030, Time(s/epoch):0.0084
# Epoch: 025, Loss:0.0938 Train: 1.0000, Val:0.7040, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 026, Loss:0.0930 Train: 1.0000, Val:0.7040, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 027, Loss:0.0867 Train: 1.0000, Val:0.6980, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 028, Loss:0.0914 Train: 1.0000, Val:0.6940, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 029, Loss:0.0923 Train: 1.0000, Val:0.6860, Test: 0.6920, Time(s/epoch):0.0083
# Epoch: 030, Loss:0.0850 Train: 1.0000, Val:0.6860, Test: 0.6880, Time(s/epoch):0.0094
# Epoch: 031, Loss:0.0783 Train: 1.0000, Val:0.6780, Test: 0.6900, Time(s/epoch):0.0088
# Epoch: 032, Loss:0.1007 Train: 1.0000, Val:0.6800, Test: 0.6870, Time(s/epoch):0.0082
# Epoch: 033, Loss:0.0829 Train: 1.0000, Val:0.6840, Test: 0.6940, Time(s/epoch):0.0087
# Epoch: 034, Loss:0.0844 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 035, Loss:0.0761 Train: 1.0000, Val:0.6980, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 036, Loss:0.0782 Train: 1.0000, Val:0.7060, Test: 0.6880, Time(s/epoch):0.0085
# Epoch: 037, Loss:0.0736 Train: 1.0000, Val:0.6920, Test: 0.6920, Time(s/epoch):0.0086
# Epoch: 038, Loss:0.0686 Train: 1.0000, Val:0.6980, Test: 0.6920, Time(s/epoch):0.0083
# Epoch: 039, Loss:0.0750 Train: 1.0000, Val:0.6960, Test: 0.7000, Time(s/epoch):0.0086
# Epoch: 040, Loss:0.0782 Train: 1.0000, Val:0.7040, Test: 0.7060, Time(s/epoch):0.0084
# Epoch: 041, Loss:0.0796 Train: 1.0000, Val:0.7060, Test: 0.6990, Time(s/epoch):0.0083
# Epoch: 042, Loss:0.0681 Train: 1.0000, Val:0.7040, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 043, Loss:0.0717 Train: 1.0000, Val:0.7040, Test: 0.6860, Time(s/epoch):0.0083
# Epoch: 044, Loss:0.0610 Train: 1.0000, Val:0.6920, Test: 0.6860, Time(s/epoch):0.0088
# Epoch: 045, Loss:0.0584 Train: 1.0000, Val:0.6880, Test: 0.6850, Time(s/epoch):0.0084
# Epoch: 046, Loss:0.0671 Train: 1.0000, Val:0.6860, Test: 0.6850, Time(s/epoch):0.0084
# Epoch: 047, Loss:0.0734 Train: 1.0000, Val:0.6840, Test: 0.6930, Time(s/epoch):0.0082
# Epoch: 048, Loss:0.0687 Train: 1.0000, Val:0.6840, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 049, Loss:0.0607 Train: 1.0000, Val:0.6900, Test: 0.6960, Time(s/epoch):0.0087
# Epoch: 050, Loss:0.0660 Train: 1.0000, Val:0.6860, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 051, Loss:0.0594 Train: 1.0000, Val:0.6900, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 052, Loss:0.0646 Train: 1.0000, Val:0.6920, Test: 0.6860, Time(s/epoch):0.0084
# Epoch: 053, Loss:0.0657 Train: 1.0000, Val:0.7020, Test: 0.6890, Time(s/epoch):0.0083
# Epoch: 054, Loss:0.0632 Train: 1.0000, Val:0.7020, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 055, Loss:0.0583 Train: 1.0000, Val:0.7020, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 056, Loss:0.0576 Train: 1.0000, Val:0.6920, Test: 0.7030, Time(s/epoch):0.0086
# Epoch: 057, Loss:0.0618 Train: 1.0000, Val:0.6700, Test: 0.6890, Time(s/epoch):0.0082
# Epoch: 058, Loss:0.0693 Train: 1.0000, Val:0.6760, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 059, Loss:0.0654 Train: 1.0000, Val:0.6920, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 060, Loss:0.0690 Train: 1.0000, Val:0.7060, Test: 0.7020, Time(s/epoch):0.0113
# Epoch: 061, Loss:0.0576 Train: 1.0000, Val:0.7060, Test: 0.6940, Time(s/epoch):0.0091
# Epoch: 062, Loss:0.0667 Train: 1.0000, Val:0.7060, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 063, Loss:0.0591 Train: 1.0000, Val:0.7100, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 064, Loss:0.0639 Train: 1.0000, Val:0.7020, Test: 0.6960, Time(s/epoch):0.0083
# Epoch: 065, Loss:0.0591 Train: 1.0000, Val:0.6920, Test: 0.6880, Time(s/epoch):0.0085
# Epoch: 066, Loss:0.0477 Train: 1.0000, Val:0.6800, Test: 0.6740, Time(s/epoch):0.0084
# Epoch: 067, Loss:0.0632 Train: 1.0000, Val:0.6860, Test: 0.6860, Time(s/epoch):0.0090
# Epoch: 068, Loss:0.0544 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0085
# Epoch: 069, Loss:0.0593 Train: 1.0000, Val:0.7080, Test: 0.6970, Time(s/epoch):0.0085
# Epoch: 070, Loss:0.0562 Train: 1.0000, Val:0.7060, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 071, Loss:0.0561 Train: 1.0000, Val:0.7020, Test: 0.7010, Time(s/epoch):0.0083
# Epoch: 072, Loss:0.0635 Train: 1.0000, Val:0.6980, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 073, Loss:0.0591 Train: 1.0000, Val:0.6980, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 074, Loss:0.0611 Train: 1.0000, Val:0.7000, Test: 0.6990, Time(s/epoch):0.0086
# Epoch: 075, Loss:0.0589 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 076, Loss:0.0640 Train: 1.0000, Val:0.6920, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 077, Loss:0.0599 Train: 1.0000, Val:0.6940, Test: 0.6940, Time(s/epoch):0.0083
# Epoch: 078, Loss:0.0604 Train: 1.0000, Val:0.6940, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 079, Loss:0.0666 Train: 1.0000, Val:0.6980, Test: 0.6840, Time(s/epoch):0.0087
# Epoch: 080, Loss:0.0660 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0082
# Epoch: 081, Loss:0.0611 Train: 1.0000, Val:0.6920, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 082, Loss:0.0643 Train: 1.0000, Val:0.6940, Test: 0.6930, Time(s/epoch):0.0153
# Epoch: 083, Loss:0.0630 Train: 1.0000, Val:0.7020, Test: 0.7010, Time(s/epoch):0.0087
# Epoch: 084, Loss:0.0679 Train: 1.0000, Val:0.6960, Test: 0.7010, Time(s/epoch):0.0083
# Epoch: 085, Loss:0.0578 Train: 1.0000, Val:0.6920, Test: 0.6970, Time(s/epoch):0.0092
# Epoch: 086, Loss:0.0548 Train: 1.0000, Val:0.6940, Test: 0.6870, Time(s/epoch):0.0087
# Epoch: 087, Loss:0.0711 Train: 1.0000, Val:0.7000, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 088, Loss:0.0602 Train: 1.0000, Val:0.7020, Test: 0.6990, Time(s/epoch):0.0082
# Epoch: 089, Loss:0.0555 Train: 1.0000, Val:0.7040, Test: 0.7000, Time(s/epoch):0.0109
# Epoch: 090, Loss:0.0622 Train: 1.0000, Val:0.6920, Test: 0.6990, Time(s/epoch):0.0144
# Epoch: 091, Loss:0.0587 Train: 1.0000, Val:0.6920, Test: 0.6830, Time(s/epoch):0.0106
# Epoch: 092, Loss:0.0567 Train: 1.0000, Val:0.6900, Test: 0.6740, Time(s/epoch):0.0083
# Epoch: 093, Loss:0.0645 Train: 1.0000, Val:0.6840, Test: 0.6830, Time(s/epoch):0.0084
# Epoch: 094, Loss:0.0528 Train: 1.0000, Val:0.6880, Test: 0.6940, Time(s/epoch):0.0083
# Epoch: 095, Loss:0.0603 Train: 1.0000, Val:0.7000, Test: 0.7030, Time(s/epoch):0.0083
# Epoch: 096, Loss:0.0572 Train: 1.0000, Val:0.6980, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 097, Loss:0.0559 Train: 1.0000, Val:0.6960, Test: 0.7050, Time(s/epoch):0.0082
# Epoch: 098, Loss:0.0594 Train: 1.0000, Val:0.6940, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 099, Loss:0.0588 Train: 1.0000, Val:0.6960, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 100, Loss:0.0679 Train: 1.0000, Val:0.6940, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 101, Loss:0.0622 Train: 1.0000, Val:0.6960, Test: 0.6980, Time(s/epoch):0.0086
# Epoch: 102, Loss:0.0580 Train: 1.0000, Val:0.6920, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 103, Loss:0.0601 Train: 1.0000, Val:0.6940, Test: 0.6960, Time(s/epoch):0.0083
# Epoch: 104, Loss:0.0595 Train: 1.0000, Val:0.6920, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 105, Loss:0.0563 Train: 1.0000, Val:0.6880, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 106, Loss:0.0604 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0083
# Epoch: 107, Loss:0.0495 Train: 1.0000, Val:0.6960, Test: 0.6950, Time(s/epoch):0.0086
# Epoch: 108, Loss:0.0597 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 109, Loss:0.0571 Train: 0.9917, Val:0.6940, Test: 0.7050, Time(s/epoch):0.0087
# Epoch: 110, Loss:0.0670 Train: 1.0000, Val:0.6920, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 111, Loss:0.0648 Train: 1.0000, Val:0.6840, Test: 0.7000, Time(s/epoch):0.0083
# Epoch: 112, Loss:0.0670 Train: 1.0000, Val:0.6860, Test: 0.7010, Time(s/epoch):0.0085
# Epoch: 113, Loss:0.0573 Train: 1.0000, Val:0.6780, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 114, Loss:0.0666 Train: 1.0000, Val:0.6800, Test: 0.6870, Time(s/epoch):0.0087
# Epoch: 115, Loss:0.0601 Train: 1.0000, Val:0.6860, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 116, Loss:0.0628 Train: 1.0000, Val:0.6900, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 117, Loss:0.0589 Train: 1.0000, Val:0.6940, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 118, Loss:0.0572 Train: 1.0000, Val:0.6980, Test: 0.6980, Time(s/epoch):0.0082
# Epoch: 119, Loss:0.0564 Train: 1.0000, Val:0.7020, Test: 0.6980, Time(s/epoch):0.0085
# Epoch: 120, Loss:0.0583 Train: 1.0000, Val:0.7000, Test: 0.7020, Time(s/epoch):0.0083
# Epoch: 121, Loss:0.0554 Train: 1.0000, Val:0.6880, Test: 0.6940, Time(s/epoch):0.0085
# Epoch: 122, Loss:0.0608 Train: 1.0000, Val:0.6940, Test: 0.6960, Time(s/epoch):0.0085
# Epoch: 123, Loss:0.0652 Train: 1.0000, Val:0.7080, Test: 0.6980, Time(s/epoch):0.0083
# Epoch: 124, Loss:0.0581 Train: 1.0000, Val:0.7020, Test: 0.7050, Time(s/epoch):0.0087
# Epoch: 125, Loss:0.0588 Train: 1.0000, Val:0.7020, Test: 0.7010, Time(s/epoch):0.0082
# Epoch: 126, Loss:0.0574 Train: 1.0000, Val:0.6880, Test: 0.6960, Time(s/epoch):0.0085
# Epoch: 127, Loss:0.0563 Train: 1.0000, Val:0.6800, Test: 0.6890, Time(s/epoch):0.0085
# Epoch: 128, Loss:0.0640 Train: 1.0000, Val:0.6780, Test: 0.6840, Time(s/epoch):0.0087
# Epoch: 129, Loss:0.0597 Train: 1.0000, Val:0.6820, Test: 0.6910, Time(s/epoch):0.0083
# Epoch: 130, Loss:0.0553 Train: 1.0000, Val:0.6880, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 131, Loss:0.0497 Train: 1.0000, Val:0.7000, Test: 0.6970, Time(s/epoch):0.0088
# Epoch: 132, Loss:0.0678 Train: 1.0000, Val:0.7040, Test: 0.7000, Time(s/epoch):0.0083
# Epoch: 133, Loss:0.0519 Train: 1.0000, Val:0.7000, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 134, Loss:0.0700 Train: 1.0000, Val:0.6960, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 135, Loss:0.0615 Train: 1.0000, Val:0.6840, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 136, Loss:0.0640 Train: 1.0000, Val:0.6960, Test: 0.6990, Time(s/epoch):0.0083
# Epoch: 137, Loss:0.0643 Train: 1.0000, Val:0.7060, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 138, Loss:0.0578 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0089
# Epoch: 139, Loss:0.0694 Train: 1.0000, Val:0.6960, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 140, Loss:0.0594 Train: 1.0000, Val:0.6920, Test: 0.6760, Time(s/epoch):0.0086
# Epoch: 141, Loss:0.0619 Train: 1.0000, Val:0.6860, Test: 0.6740, Time(s/epoch):0.0084
# Epoch: 142, Loss:0.0666 Train: 1.0000, Val:0.6820, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 143, Loss:0.0504 Train: 1.0000, Val:0.6860, Test: 0.6970, Time(s/epoch):0.0082
# Epoch: 144, Loss:0.0705 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0083
# Epoch: 145, Loss:0.0659 Train: 1.0000, Val:0.6900, Test: 0.7000, Time(s/epoch):0.0083
# Epoch: 146, Loss:0.0524 Train: 1.0000, Val:0.6840, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 147, Loss:0.0569 Train: 1.0000, Val:0.6820, Test: 0.6790, Time(s/epoch):0.0083
# Epoch: 148, Loss:0.0630 Train: 1.0000, Val:0.6800, Test: 0.6830, Time(s/epoch):0.0083
# Epoch: 149, Loss:0.0560 Train: 1.0000, Val:0.6800, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 150, Loss:0.0614 Train: 1.0000, Val:0.6880, Test: 0.6910, Time(s/epoch):0.0082
# Epoch: 151, Loss:0.0658 Train: 1.0000, Val:0.6920, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 152, Loss:0.0567 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 153, Loss:0.0578 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 154, Loss:0.0584 Train: 1.0000, Val:0.6940, Test: 0.6890, Time(s/epoch):0.0085
# Epoch: 155, Loss:0.0561 Train: 1.0000, Val:0.7060, Test: 0.6950, Time(s/epoch):0.0082
# Epoch: 156, Loss:0.0585 Train: 1.0000, Val:0.7000, Test: 0.6910, Time(s/epoch):0.0083
# Epoch: 157, Loss:0.0607 Train: 1.0000, Val:0.6940, Test: 0.6950, Time(s/epoch):0.0085
# Epoch: 158, Loss:0.0560 Train: 1.0000, Val:0.6940, Test: 0.6970, Time(s/epoch):0.0082
# Epoch: 159, Loss:0.0523 Train: 1.0000, Val:0.6980, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 160, Loss:0.0615 Train: 1.0000, Val:0.6940, Test: 0.7000, Time(s/epoch):0.0082
# Epoch: 161, Loss:0.0570 Train: 1.0000, Val:0.6920, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 162, Loss:0.0571 Train: 1.0000, Val:0.6900, Test: 0.6910, Time(s/epoch):0.0086
# Epoch: 163, Loss:0.0620 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 164, Loss:0.0614 Train: 1.0000, Val:0.7020, Test: 0.7030, Time(s/epoch):0.0084
# Epoch: 165, Loss:0.0594 Train: 1.0000, Val:0.7100, Test: 0.7080, Time(s/epoch):0.0084
# Epoch: 166, Loss:0.0641 Train: 1.0000, Val:0.6980, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 167, Loss:0.0603 Train: 1.0000, Val:0.6900, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 168, Loss:0.0593 Train: 1.0000, Val:0.6860, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 169, Loss:0.0675 Train: 1.0000, Val:0.6880, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 170, Loss:0.0643 Train: 1.0000, Val:0.7000, Test: 0.6980, Time(s/epoch):0.0083
# Epoch: 171, Loss:0.0616 Train: 1.0000, Val:0.7000, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 172, Loss:0.0497 Train: 0.9917, Val:0.6960, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 173, Loss:0.0763 Train: 1.0000, Val:0.7020, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 174, Loss:0.0617 Train: 1.0000, Val:0.7000, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 175, Loss:0.0556 Train: 0.9917, Val:0.6940, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 176, Loss:0.0654 Train: 1.0000, Val:0.7000, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 177, Loss:0.0670 Train: 1.0000, Val:0.6920, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 178, Loss:0.0540 Train: 1.0000, Val:0.6840, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 179, Loss:0.0547 Train: 1.0000, Val:0.6840, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 180, Loss:0.0594 Train: 1.0000, Val:0.6820, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 181, Loss:0.0558 Train: 1.0000, Val:0.6820, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 182, Loss:0.0606 Train: 1.0000, Val:0.6900, Test: 0.6830, Time(s/epoch):0.0083
# Epoch: 183, Loss:0.0677 Train: 1.0000, Val:0.7000, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 184, Loss:0.0602 Train: 1.0000, Val:0.6980, Test: 0.7030, Time(s/epoch):0.0084
# Epoch: 185, Loss:0.0614 Train: 1.0000, Val:0.7080, Test: 0.7060, Time(s/epoch):0.0084
# Epoch: 186, Loss:0.0621 Train: 1.0000, Val:0.6960, Test: 0.7020, Time(s/epoch):0.0086
# Epoch: 187, Loss:0.0571 Train: 1.0000, Val:0.6880, Test: 0.6960, Time(s/epoch):0.0090
# Epoch: 188, Loss:0.0476 Train: 1.0000, Val:0.6880, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 189, Loss:0.0625 Train: 1.0000, Val:0.6880, Test: 0.6900, Time(s/epoch):0.0083
# Epoch: 190, Loss:0.0703 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0086
# Epoch: 191, Loss:0.0616 Train: 1.0000, Val:0.6980, Test: 0.6910, Time(s/epoch):0.0082
# Epoch: 192, Loss:0.0587 Train: 1.0000, Val:0.6980, Test: 0.6890, Time(s/epoch):0.0082
# Epoch: 193, Loss:0.0584 Train: 1.0000, Val:0.7080, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 194, Loss:0.0652 Train: 1.0000, Val:0.7100, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 195, Loss:0.0647 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0082
# Epoch: 196, Loss:0.0585 Train: 1.0000, Val:0.6820, Test: 0.6840, Time(s/epoch):0.0083
# Epoch: 197, Loss:0.0558 Train: 1.0000, Val:0.6820, Test: 0.6800, Time(s/epoch):0.0086
# Epoch: 198, Loss:0.0710 Train: 1.0000, Val:0.6840, Test: 0.6930, Time(s/epoch):0.0087
# Epoch: 199, Loss:0.0569 Train: 1.0000, Val:0.6940, Test: 0.7000, Time(s/epoch):0.0090
# Epoch: 200, Loss:0.0605 Train: 1.0000, Val:0.7000, Test: 0.7020, Time(s/epoch):0.0085
# [Run-1 score] {'train': 1.0, 'val': 0.71, 'test': 0.698, 'loss': 0.059140775352716446}
# repeat 2/3
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# GCNNet(
#   (convs): ModuleList(
#     (0): GCNConv(3703, 64)
#     (1): GCNConv(64, 6)
#   )
# )
# auto fixed data split seed to 0, model init seed to 1
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# [Dataset-CiteSeer()] train_num:120, val_num:500, test_num:1000, class_num:6
# Epoch: 001, Loss:1.8042 Train: 0.8917, Val:0.5500, Test: 0.5370, Time(s/epoch):0.0086
# Epoch: 002, Loss:1.4569 Train: 0.9250, Val:0.6360, Test: 0.6240, Time(s/epoch):0.0084
# Epoch: 003, Loss:1.0869 Train: 0.9417, Val:0.6460, Test: 0.6330, Time(s/epoch):0.0084
# Epoch: 004, Loss:0.7360 Train: 0.9667, Val:0.6680, Test: 0.6490, Time(s/epoch):0.0084
# Epoch: 005, Loss:0.4630 Train: 0.9583, Val:0.6900, Test: 0.6770, Time(s/epoch):0.0084
# Epoch: 006, Loss:0.2935 Train: 0.9667, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 007, Loss:0.2005 Train: 0.9833, Val:0.6880, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 008, Loss:0.1490 Train: 0.9833, Val:0.6840, Test: 0.6960, Time(s/epoch):0.0085
# Epoch: 009, Loss:0.1209 Train: 0.9917, Val:0.6840, Test: 0.6860, Time(s/epoch):0.0089
# Epoch: 010, Loss:0.1049 Train: 1.0000, Val:0.6900, Test: 0.6950, Time(s/epoch):0.0085
# Epoch: 011, Loss:0.0756 Train: 1.0000, Val:0.6980, Test: 0.6970, Time(s/epoch):0.0085
# Epoch: 012, Loss:0.0755 Train: 0.9917, Val:0.6960, Test: 0.6980, Time(s/epoch):0.0085
# Epoch: 013, Loss:0.0783 Train: 0.9917, Val:0.6900, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 014, Loss:0.0700 Train: 1.0000, Val:0.6920, Test: 0.6960, Time(s/epoch):0.0085
# Epoch: 015, Loss:0.0754 Train: 0.9917, Val:0.6840, Test: 0.6890, Time(s/epoch):0.0083
# Epoch: 016, Loss:0.0589 Train: 0.9917, Val:0.6860, Test: 0.6850, Time(s/epoch):0.0085
# Epoch: 017, Loss:0.0642 Train: 0.9917, Val:0.6980, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 018, Loss:0.0659 Train: 0.9917, Val:0.6940, Test: 0.6890, Time(s/epoch):0.0085
# Epoch: 019, Loss:0.0655 Train: 1.0000, Val:0.7000, Test: 0.6940, Time(s/epoch):0.0088
# Epoch: 020, Loss:0.0790 Train: 1.0000, Val:0.6900, Test: 0.6920, Time(s/epoch):0.0086
# Epoch: 021, Loss:0.0756 Train: 1.0000, Val:0.6840, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 022, Loss:0.0743 Train: 1.0000, Val:0.6820, Test: 0.6860, Time(s/epoch):0.0085
# Epoch: 023, Loss:0.0779 Train: 1.0000, Val:0.6880, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 024, Loss:0.0819 Train: 0.9917, Val:0.6900, Test: 0.6790, Time(s/epoch):0.0083
# Epoch: 025, Loss:0.0967 Train: 1.0000, Val:0.6900, Test: 0.6760, Time(s/epoch):0.0084
# Epoch: 026, Loss:0.0971 Train: 1.0000, Val:0.6960, Test: 0.6840, Time(s/epoch):0.0085
# Epoch: 027, Loss:0.0950 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 028, Loss:0.0841 Train: 1.0000, Val:0.6980, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 029, Loss:0.0942 Train: 1.0000, Val:0.7020, Test: 0.7040, Time(s/epoch):0.0084
# Epoch: 030, Loss:0.0909 Train: 1.0000, Val:0.6960, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 031, Loss:0.0916 Train: 1.0000, Val:0.6960, Test: 0.6950, Time(s/epoch):0.0087
# Epoch: 032, Loss:0.0891 Train: 1.0000, Val:0.7000, Test: 0.6850, Time(s/epoch):0.0088
# Epoch: 033, Loss:0.0845 Train: 1.0000, Val:0.6940, Test: 0.6780, Time(s/epoch):0.0083
# Epoch: 034, Loss:0.0727 Train: 1.0000, Val:0.6940, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 035, Loss:0.0853 Train: 1.0000, Val:0.6900, Test: 0.6800, Time(s/epoch):0.0084
# Epoch: 036, Loss:0.0773 Train: 1.0000, Val:0.7020, Test: 0.6870, Time(s/epoch):0.0083
# Epoch: 037, Loss:0.0637 Train: 1.0000, Val:0.6980, Test: 0.6820, Time(s/epoch):0.0085
# Epoch: 038, Loss:0.0765 Train: 1.0000, Val:0.7020, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 039, Loss:0.0719 Train: 1.0000, Val:0.7020, Test: 0.6870, Time(s/epoch):0.0095
# Epoch: 040, Loss:0.0707 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 041, Loss:0.0670 Train: 1.0000, Val:0.6900, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 042, Loss:0.0743 Train: 1.0000, Val:0.6880, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 043, Loss:0.0712 Train: 1.0000, Val:0.6840, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 044, Loss:0.0596 Train: 1.0000, Val:0.6860, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 045, Loss:0.0698 Train: 1.0000, Val:0.6860, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 046, Loss:0.0704 Train: 1.0000, Val:0.6840, Test: 0.6750, Time(s/epoch):0.0085
# Epoch: 047, Loss:0.0684 Train: 1.0000, Val:0.6940, Test: 0.6790, Time(s/epoch):0.0083
# Epoch: 048, Loss:0.0675 Train: 1.0000, Val:0.7060, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 049, Loss:0.0634 Train: 1.0000, Val:0.6960, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 050, Loss:0.0701 Train: 1.0000, Val:0.6940, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 051, Loss:0.0790 Train: 1.0000, Val:0.7100, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 052, Loss:0.0674 Train: 1.0000, Val:0.7040, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 053, Loss:0.0666 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0086
# Epoch: 054, Loss:0.0641 Train: 1.0000, Val:0.6900, Test: 0.6840, Time(s/epoch):0.0089
# Epoch: 055, Loss:0.0581 Train: 1.0000, Val:0.6820, Test: 0.6700, Time(s/epoch):0.0086
# Epoch: 056, Loss:0.0752 Train: 1.0000, Val:0.6820, Test: 0.6720, Time(s/epoch):0.0085
# Epoch: 057, Loss:0.0510 Train: 1.0000, Val:0.6740, Test: 0.6720, Time(s/epoch):0.0084
# Epoch: 058, Loss:0.0645 Train: 1.0000, Val:0.6760, Test: 0.6820, Time(s/epoch):0.0085
# Epoch: 059, Loss:0.0678 Train: 1.0000, Val:0.6840, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 060, Loss:0.0670 Train: 1.0000, Val:0.6900, Test: 0.6930, Time(s/epoch):0.0083
# Epoch: 061, Loss:0.0578 Train: 1.0000, Val:0.6960, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 062, Loss:0.0706 Train: 1.0000, Val:0.6960, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 063, Loss:0.0616 Train: 1.0000, Val:0.6940, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 064, Loss:0.0724 Train: 1.0000, Val:0.6900, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 065, Loss:0.0616 Train: 1.0000, Val:0.6880, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 066, Loss:0.0544 Train: 1.0000, Val:0.6980, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 067, Loss:0.0630 Train: 1.0000, Val:0.7020, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 068, Loss:0.0577 Train: 1.0000, Val:0.7060, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 069, Loss:0.0579 Train: 1.0000, Val:0.6960, Test: 0.6900, Time(s/epoch):0.0091
# Epoch: 070, Loss:0.0555 Train: 1.0000, Val:0.6960, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 071, Loss:0.0687 Train: 1.0000, Val:0.7040, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 072, Loss:0.0529 Train: 1.0000, Val:0.7000, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 073, Loss:0.0554 Train: 1.0000, Val:0.7000, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 074, Loss:0.0673 Train: 1.0000, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 075, Loss:0.0560 Train: 1.0000, Val:0.6920, Test: 0.6940, Time(s/epoch):0.0083
# Epoch: 076, Loss:0.0701 Train: 1.0000, Val:0.6900, Test: 0.6860, Time(s/epoch):0.0084
# Epoch: 077, Loss:0.0654 Train: 1.0000, Val:0.7000, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 078, Loss:0.0690 Train: 1.0000, Val:0.6900, Test: 0.6970, Time(s/epoch):0.0086
# Epoch: 079, Loss:0.0630 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0085
# Epoch: 080, Loss:0.0726 Train: 1.0000, Val:0.7000, Test: 0.6960, Time(s/epoch):0.0085
# Epoch: 081, Loss:0.0586 Train: 1.0000, Val:0.6880, Test: 0.6960, Time(s/epoch):0.0083
# Epoch: 082, Loss:0.0584 Train: 1.0000, Val:0.6940, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 083, Loss:0.0558 Train: 1.0000, Val:0.6940, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 084, Loss:0.0645 Train: 1.0000, Val:0.6940, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 085, Loss:0.0656 Train: 1.0000, Val:0.6920, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 086, Loss:0.0561 Train: 1.0000, Val:0.6860, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 087, Loss:0.0541 Train: 1.0000, Val:0.6980, Test: 0.7040, Time(s/epoch):0.0083
# Epoch: 088, Loss:0.0593 Train: 1.0000, Val:0.6980, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 089, Loss:0.0660 Train: 1.0000, Val:0.6940, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 090, Loss:0.0599 Train: 1.0000, Val:0.7000, Test: 0.6960, Time(s/epoch):0.0083
# Epoch: 091, Loss:0.0591 Train: 1.0000, Val:0.7020, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 092, Loss:0.0568 Train: 1.0000, Val:0.6960, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 093, Loss:0.0591 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0083
# Epoch: 094, Loss:0.0562 Train: 1.0000, Val:0.6920, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 095, Loss:0.0581 Train: 1.0000, Val:0.6920, Test: 0.6990, Time(s/epoch):0.0086
# Epoch: 096, Loss:0.0668 Train: 1.0000, Val:0.6940, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 097, Loss:0.0660 Train: 1.0000, Val:0.6880, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 098, Loss:0.0527 Train: 1.0000, Val:0.6940, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 099, Loss:0.0553 Train: 1.0000, Val:0.7020, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 100, Loss:0.0559 Train: 1.0000, Val:0.7000, Test: 0.6970, Time(s/epoch):0.0086
# Epoch: 101, Loss:0.0525 Train: 1.0000, Val:0.6980, Test: 0.7050, Time(s/epoch):0.0084
# Epoch: 102, Loss:0.0596 Train: 1.0000, Val:0.7040, Test: 0.7060, Time(s/epoch):0.0088
# Epoch: 103, Loss:0.0666 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0085
# Epoch: 104, Loss:0.0543 Train: 1.0000, Val:0.6940, Test: 0.6930, Time(s/epoch):0.0086
# Epoch: 105, Loss:0.0545 Train: 1.0000, Val:0.6940, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 106, Loss:0.0610 Train: 1.0000, Val:0.6920, Test: 0.6890, Time(s/epoch):0.0086
# Epoch: 107, Loss:0.0600 Train: 1.0000, Val:0.6920, Test: 0.6880, Time(s/epoch):0.0083
# Epoch: 108, Loss:0.0595 Train: 1.0000, Val:0.6920, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 109, Loss:0.0585 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0090
# Epoch: 110, Loss:0.0655 Train: 1.0000, Val:0.6940, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 111, Loss:0.0603 Train: 1.0000, Val:0.7040, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 112, Loss:0.0550 Train: 1.0000, Val:0.7000, Test: 0.7020, Time(s/epoch):0.0082
# Epoch: 113, Loss:0.0657 Train: 1.0000, Val:0.6880, Test: 0.7020, Time(s/epoch):0.0087
# Epoch: 114, Loss:0.0524 Train: 1.0000, Val:0.6880, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 115, Loss:0.0617 Train: 1.0000, Val:0.6920, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 116, Loss:0.0634 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0087
# Epoch: 117, Loss:0.0636 Train: 1.0000, Val:0.6940, Test: 0.7040, Time(s/epoch):0.0082
# Epoch: 118, Loss:0.0542 Train: 1.0000, Val:0.7020, Test: 0.7040, Time(s/epoch):0.0085
# Epoch: 119, Loss:0.0496 Train: 1.0000, Val:0.7000, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 120, Loss:0.0684 Train: 1.0000, Val:0.6940, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 121, Loss:0.0727 Train: 1.0000, Val:0.6820, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 122, Loss:0.0614 Train: 1.0000, Val:0.6760, Test: 0.6860, Time(s/epoch):0.0089
# Epoch: 123, Loss:0.0576 Train: 1.0000, Val:0.6920, Test: 0.6920, Time(s/epoch):0.0153
# Epoch: 124, Loss:0.0661 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0105
# Epoch: 125, Loss:0.0602 Train: 1.0000, Val:0.6940, Test: 0.6990, Time(s/epoch):0.0105
# Epoch: 126, Loss:0.0691 Train: 1.0000, Val:0.6860, Test: 0.6970, Time(s/epoch):0.0136
# Epoch: 127, Loss:0.0632 Train: 1.0000, Val:0.6840, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 128, Loss:0.0702 Train: 1.0000, Val:0.6860, Test: 0.6930, Time(s/epoch):0.0090
# Epoch: 129, Loss:0.0564 Train: 1.0000, Val:0.6920, Test: 0.7030, Time(s/epoch):0.0088
# Epoch: 130, Loss:0.0652 Train: 1.0000, Val:0.7000, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 131, Loss:0.0567 Train: 1.0000, Val:0.6920, Test: 0.7000, Time(s/epoch):0.0096
# Epoch: 132, Loss:0.0510 Train: 1.0000, Val:0.6940, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 133, Loss:0.0568 Train: 1.0000, Val:0.6860, Test: 0.6920, Time(s/epoch):0.0087
# Epoch: 134, Loss:0.0563 Train: 1.0000, Val:0.6840, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 135, Loss:0.0573 Train: 1.0000, Val:0.6980, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 136, Loss:0.0589 Train: 1.0000, Val:0.7040, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 137, Loss:0.0744 Train: 1.0000, Val:0.7040, Test: 0.6920, Time(s/epoch):0.0089
# Epoch: 138, Loss:0.0643 Train: 1.0000, Val:0.7040, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 139, Loss:0.0508 Train: 1.0000, Val:0.6980, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 140, Loss:0.0576 Train: 1.0000, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 141, Loss:0.0700 Train: 1.0000, Val:0.6920, Test: 0.7000, Time(s/epoch):0.0086
# Epoch: 142, Loss:0.0684 Train: 1.0000, Val:0.6920, Test: 0.7030, Time(s/epoch):0.0098
# Epoch: 143, Loss:0.0625 Train: 1.0000, Val:0.6840, Test: 0.7040, Time(s/epoch):0.0084
# Epoch: 144, Loss:0.0530 Train: 1.0000, Val:0.6800, Test: 0.7010, Time(s/epoch):0.0087
# Epoch: 145, Loss:0.0587 Train: 1.0000, Val:0.6880, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 146, Loss:0.0489 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0092
# Epoch: 147, Loss:0.0597 Train: 1.0000, Val:0.6940, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 148, Loss:0.0603 Train: 1.0000, Val:0.6900, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 149, Loss:0.0522 Train: 1.0000, Val:0.6900, Test: 0.6860, Time(s/epoch):0.0085
# Epoch: 150, Loss:0.0597 Train: 1.0000, Val:0.6840, Test: 0.6830, Time(s/epoch):0.0083
# Epoch: 151, Loss:0.0667 Train: 1.0000, Val:0.6980, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 152, Loss:0.0642 Train: 1.0000, Val:0.6960, Test: 0.7040, Time(s/epoch):0.0084
# Epoch: 153, Loss:0.0614 Train: 1.0000, Val:0.6920, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 154, Loss:0.0642 Train: 1.0000, Val:0.6960, Test: 0.6970, Time(s/epoch):0.0082
# Epoch: 155, Loss:0.0576 Train: 1.0000, Val:0.6940, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 156, Loss:0.0557 Train: 1.0000, Val:0.6980, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 157, Loss:0.0616 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 158, Loss:0.0573 Train: 1.0000, Val:0.6880, Test: 0.6950, Time(s/epoch):0.0085
# Epoch: 159, Loss:0.0545 Train: 1.0000, Val:0.6960, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 160, Loss:0.0527 Train: 1.0000, Val:0.6920, Test: 0.7000, Time(s/epoch):0.0088
# Epoch: 161, Loss:0.0708 Train: 1.0000, Val:0.6900, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 162, Loss:0.0586 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 163, Loss:0.0685 Train: 1.0000, Val:0.6920, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 164, Loss:0.0527 Train: 1.0000, Val:0.7000, Test: 0.7000, Time(s/epoch):0.0082
# Epoch: 165, Loss:0.0589 Train: 1.0000, Val:0.7060, Test: 0.7010, Time(s/epoch):0.0083
# Epoch: 166, Loss:0.0584 Train: 1.0000, Val:0.6960, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 167, Loss:0.0653 Train: 1.0000, Val:0.7000, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 168, Loss:0.0584 Train: 1.0000, Val:0.6920, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 169, Loss:0.0614 Train: 1.0000, Val:0.6940, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 170, Loss:0.0531 Train: 1.0000, Val:0.6960, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 171, Loss:0.0616 Train: 1.0000, Val:0.6940, Test: 0.6880, Time(s/epoch):0.0082
# Epoch: 172, Loss:0.0608 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0086
# Epoch: 173, Loss:0.0527 Train: 1.0000, Val:0.6900, Test: 0.6870, Time(s/epoch):0.0083
# Epoch: 174, Loss:0.0668 Train: 1.0000, Val:0.6840, Test: 0.6800, Time(s/epoch):0.0083
# Epoch: 175, Loss:0.0662 Train: 1.0000, Val:0.6820, Test: 0.6880, Time(s/epoch):0.0083
# Epoch: 176, Loss:0.0625 Train: 1.0000, Val:0.6920, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 177, Loss:0.0663 Train: 1.0000, Val:0.7060, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 178, Loss:0.0500 Train: 1.0000, Val:0.7160, Test: 0.7050, Time(s/epoch):0.0084
# Epoch: 179, Loss:0.0676 Train: 1.0000, Val:0.7180, Test: 0.7020, Time(s/epoch):0.0083
# Epoch: 180, Loss:0.0592 Train: 1.0000, Val:0.6920, Test: 0.7030, Time(s/epoch):0.0083
# Epoch: 181, Loss:0.0605 Train: 1.0000, Val:0.6880, Test: 0.6860, Time(s/epoch):0.0088
# Epoch: 182, Loss:0.0624 Train: 1.0000, Val:0.6860, Test: 0.6780, Time(s/epoch):0.0085
# Epoch: 183, Loss:0.0644 Train: 1.0000, Val:0.6860, Test: 0.6850, Time(s/epoch):0.0083
# Epoch: 184, Loss:0.0482 Train: 1.0000, Val:0.6960, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 185, Loss:0.0618 Train: 1.0000, Val:0.7020, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 186, Loss:0.0588 Train: 1.0000, Val:0.7000, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 187, Loss:0.0602 Train: 1.0000, Val:0.6920, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 188, Loss:0.0514 Train: 1.0000, Val:0.6840, Test: 0.6860, Time(s/epoch):0.0084
# Epoch: 189, Loss:0.0696 Train: 1.0000, Val:0.6820, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 190, Loss:0.0750 Train: 1.0000, Val:0.7040, Test: 0.7030, Time(s/epoch):0.0083
# Epoch: 191, Loss:0.0613 Train: 1.0000, Val:0.7040, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 192, Loss:0.0682 Train: 1.0000, Val:0.7040, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 193, Loss:0.0796 Train: 1.0000, Val:0.6940, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 194, Loss:0.0547 Train: 1.0000, Val:0.6840, Test: 0.6850, Time(s/epoch):0.0082
# Epoch: 195, Loss:0.0485 Train: 1.0000, Val:0.6860, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 196, Loss:0.0608 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0086
# Epoch: 197, Loss:0.0619 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0085
# Epoch: 198, Loss:0.0607 Train: 1.0000, Val:0.6980, Test: 0.7000, Time(s/epoch):0.0085
# Epoch: 199, Loss:0.0538 Train: 1.0000, Val:0.7000, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 200, Loss:0.0606 Train: 1.0000, Val:0.6940, Test: 0.6790, Time(s/epoch):0.0084
# [Run-2 score] {'train': 1.0, 'val': 0.718, 'test': 0.702, 'loss': 0.0675509050488472}
# repeat 3/3
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# GCNNet(
#   (convs): ModuleList(
#     (0): GCNConv(3703, 64)
#     (1): GCNConv(64, 6)
#   )
# )
# auto fixed data split seed to 0, model init seed to 2
# Data(x=[3327, 3703], edge_index=[2, 9104], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# [Dataset-CiteSeer()] train_num:120, val_num:500, test_num:1000, class_num:6
# Epoch: 001, Loss:1.8076 Train: 0.9167, Val:0.5700, Test: 0.5330, Time(s/epoch):0.0084
# Epoch: 002, Loss:1.4617 Train: 0.9500, Val:0.6160, Test: 0.5910, Time(s/epoch):0.0087
# Epoch: 003, Loss:1.0628 Train: 0.9500, Val:0.6400, Test: 0.6270, Time(s/epoch):0.0083
# Epoch: 004, Loss:0.7220 Train: 0.9500, Val:0.6980, Test: 0.6800, Time(s/epoch):0.0083
# Epoch: 005, Loss:0.4799 Train: 0.9667, Val:0.7020, Test: 0.7010, Time(s/epoch):0.0083
# Epoch: 006, Loss:0.3062 Train: 0.9833, Val:0.7060, Test: 0.7020, Time(s/epoch):0.0083
# Epoch: 007, Loss:0.2105 Train: 0.9917, Val:0.7000, Test: 0.7000, Time(s/epoch):0.0083
# Epoch: 008, Loss:0.1645 Train: 0.9917, Val:0.6920, Test: 0.6870, Time(s/epoch):0.0082
# Epoch: 009, Loss:0.1092 Train: 1.0000, Val:0.6960, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 010, Loss:0.0871 Train: 1.0000, Val:0.7000, Test: 0.6840, Time(s/epoch):0.0086
# Epoch: 011, Loss:0.0824 Train: 1.0000, Val:0.7040, Test: 0.6800, Time(s/epoch):0.0083
# Epoch: 012, Loss:0.0681 Train: 1.0000, Val:0.6980, Test: 0.6720, Time(s/epoch):0.0084
# Epoch: 013, Loss:0.0740 Train: 1.0000, Val:0.6880, Test: 0.6760, Time(s/epoch):0.0084
# Epoch: 014, Loss:0.0571 Train: 1.0000, Val:0.6920, Test: 0.6810, Time(s/epoch):0.0083
# Epoch: 015, Loss:0.0548 Train: 1.0000, Val:0.6940, Test: 0.6860, Time(s/epoch):0.0087
# Epoch: 016, Loss:0.0530 Train: 1.0000, Val:0.6960, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 017, Loss:0.0607 Train: 1.0000, Val:0.6900, Test: 0.6920, Time(s/epoch):0.0095
# Epoch: 018, Loss:0.0590 Train: 1.0000, Val:0.6960, Test: 0.7010, Time(s/epoch):0.0092
# Epoch: 019, Loss:0.0586 Train: 1.0000, Val:0.6940, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 020, Loss:0.0689 Train: 1.0000, Val:0.6880, Test: 0.7030, Time(s/epoch):0.0084
# Epoch: 021, Loss:0.0639 Train: 1.0000, Val:0.6940, Test: 0.7030, Time(s/epoch):0.0084
# Epoch: 022, Loss:0.0704 Train: 1.0000, Val:0.6920, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 023, Loss:0.0744 Train: 1.0000, Val:0.6980, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 024, Loss:0.0822 Train: 1.0000, Val:0.6940, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 025, Loss:0.0995 Train: 1.0000, Val:0.6860, Test: 0.6790, Time(s/epoch):0.0084
# Epoch: 026, Loss:0.0774 Train: 1.0000, Val:0.6840, Test: 0.6830, Time(s/epoch):0.0084
# Epoch: 027, Loss:0.0885 Train: 1.0000, Val:0.6920, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 028, Loss:0.1049 Train: 1.0000, Val:0.6880, Test: 0.6890, Time(s/epoch):0.0100
# Epoch: 029, Loss:0.0999 Train: 1.0000, Val:0.6920, Test: 0.6920, Time(s/epoch):0.0160
# Epoch: 030, Loss:0.0920 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0086
# Epoch: 031, Loss:0.0880 Train: 1.0000, Val:0.6900, Test: 0.6930, Time(s/epoch):0.0083
# Epoch: 032, Loss:0.0880 Train: 1.0000, Val:0.6880, Test: 0.6930, Time(s/epoch):0.0086
# Epoch: 033, Loss:0.0925 Train: 1.0000, Val:0.6940, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 034, Loss:0.0786 Train: 1.0000, Val:0.6820, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 035, Loss:0.0788 Train: 1.0000, Val:0.6780, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 036, Loss:0.0752 Train: 1.0000, Val:0.6740, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 037, Loss:0.0722 Train: 1.0000, Val:0.6840, Test: 0.6860, Time(s/epoch):0.0086
# Epoch: 038, Loss:0.0819 Train: 1.0000, Val:0.6820, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 039, Loss:0.0674 Train: 1.0000, Val:0.6880, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 040, Loss:0.0646 Train: 1.0000, Val:0.6980, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 041, Loss:0.0658 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0084
# Epoch: 042, Loss:0.0645 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 043, Loss:0.0586 Train: 1.0000, Val:0.6940, Test: 0.6850, Time(s/epoch):0.0084
# Epoch: 044, Loss:0.0634 Train: 1.0000, Val:0.7020, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 045, Loss:0.0682 Train: 1.0000, Val:0.6920, Test: 0.6810, Time(s/epoch):0.0097
# Epoch: 046, Loss:0.0678 Train: 1.0000, Val:0.6780, Test: 0.6810, Time(s/epoch):0.0085
# Epoch: 047, Loss:0.0651 Train: 1.0000, Val:0.6880, Test: 0.6770, Time(s/epoch):0.0084
# Epoch: 048, Loss:0.0602 Train: 1.0000, Val:0.6880, Test: 0.6870, Time(s/epoch):0.0086
# Epoch: 049, Loss:0.0658 Train: 1.0000, Val:0.6920, Test: 0.6880, Time(s/epoch):0.0088
# Epoch: 050, Loss:0.0505 Train: 1.0000, Val:0.6880, Test: 0.6940, Time(s/epoch):0.0085
# Epoch: 051, Loss:0.0686 Train: 1.0000, Val:0.6960, Test: 0.6940, Time(s/epoch):0.0085
# Epoch: 052, Loss:0.0644 Train: 1.0000, Val:0.6940, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 053, Loss:0.0793 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 054, Loss:0.0731 Train: 1.0000, Val:0.6840, Test: 0.6970, Time(s/epoch):0.0085
# Epoch: 055, Loss:0.0590 Train: 1.0000, Val:0.6740, Test: 0.6940, Time(s/epoch):0.0085
# Epoch: 056, Loss:0.0642 Train: 1.0000, Val:0.6720, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 057, Loss:0.0614 Train: 1.0000, Val:0.6800, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 058, Loss:0.0536 Train: 1.0000, Val:0.6860, Test: 0.6890, Time(s/epoch):0.0085
# Epoch: 059, Loss:0.0600 Train: 1.0000, Val:0.6940, Test: 0.6900, Time(s/epoch):0.0096
# Epoch: 060, Loss:0.0727 Train: 1.0000, Val:0.6960, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 061, Loss:0.0527 Train: 1.0000, Val:0.6980, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 062, Loss:0.0690 Train: 1.0000, Val:0.6840, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 063, Loss:0.0565 Train: 1.0000, Val:0.6820, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 064, Loss:0.0599 Train: 1.0000, Val:0.6840, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 065, Loss:0.0590 Train: 1.0000, Val:0.6880, Test: 0.6930, Time(s/epoch):0.0087
# Epoch: 066, Loss:0.0614 Train: 1.0000, Val:0.6860, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 067, Loss:0.0572 Train: 1.0000, Val:0.6860, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 068, Loss:0.0572 Train: 1.0000, Val:0.6840, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 069, Loss:0.0654 Train: 1.0000, Val:0.6900, Test: 0.6960, Time(s/epoch):0.0085
# Epoch: 070, Loss:0.0610 Train: 1.0000, Val:0.6860, Test: 0.6980, Time(s/epoch):0.0082
# Epoch: 071, Loss:0.0578 Train: 1.0000, Val:0.6880, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 072, Loss:0.0621 Train: 1.0000, Val:0.6960, Test: 0.6960, Time(s/epoch):0.0086
# Epoch: 073, Loss:0.0664 Train: 1.0000, Val:0.7020, Test: 0.6930, Time(s/epoch):0.0097
# Epoch: 074, Loss:0.0567 Train: 1.0000, Val:0.6940, Test: 0.6870, Time(s/epoch):0.0085
# Epoch: 075, Loss:0.0470 Train: 1.0000, Val:0.6900, Test: 0.6850, Time(s/epoch):0.0084
# Epoch: 076, Loss:0.0614 Train: 1.0000, Val:0.6940, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 077, Loss:0.0571 Train: 1.0000, Val:0.6960, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 078, Loss:0.0634 Train: 1.0000, Val:0.6880, Test: 0.7040, Time(s/epoch):0.0084
# Epoch: 079, Loss:0.0538 Train: 1.0000, Val:0.7060, Test: 0.6980, Time(s/epoch):0.0083
# Epoch: 080, Loss:0.0614 Train: 1.0000, Val:0.6980, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 081, Loss:0.0587 Train: 1.0000, Val:0.7000, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 082, Loss:0.0607 Train: 1.0000, Val:0.6880, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 083, Loss:0.0565 Train: 1.0000, Val:0.6980, Test: 0.6790, Time(s/epoch):0.0086
# Epoch: 084, Loss:0.0695 Train: 1.0000, Val:0.6940, Test: 0.6970, Time(s/epoch):0.0086
# Epoch: 085, Loss:0.0657 Train: 1.0000, Val:0.6900, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 086, Loss:0.0529 Train: 1.0000, Val:0.6920, Test: 0.7040, Time(s/epoch):0.0084
# Epoch: 087, Loss:0.0565 Train: 0.9917, Val:0.6900, Test: 0.7000, Time(s/epoch):0.0098
# Epoch: 088, Loss:0.0672 Train: 1.0000, Val:0.6840, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 089, Loss:0.0707 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0088
# Epoch: 090, Loss:0.0608 Train: 1.0000, Val:0.6860, Test: 0.6810, Time(s/epoch):0.0087
# Epoch: 091, Loss:0.0609 Train: 1.0000, Val:0.6820, Test: 0.6880, Time(s/epoch):0.0083
# Epoch: 092, Loss:0.0486 Train: 1.0000, Val:0.6860, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 093, Loss:0.0460 Train: 1.0000, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0087
# Epoch: 094, Loss:0.0618 Train: 1.0000, Val:0.7000, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 095, Loss:0.0574 Train: 1.0000, Val:0.6940, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 096, Loss:0.0688 Train: 1.0000, Val:0.6960, Test: 0.6980, Time(s/epoch):0.0085
# Epoch: 097, Loss:0.0625 Train: 1.0000, Val:0.6960, Test: 0.6990, Time(s/epoch):0.0085
# Epoch: 098, Loss:0.0662 Train: 1.0000, Val:0.6960, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 099, Loss:0.0561 Train: 1.0000, Val:0.7020, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 100, Loss:0.0580 Train: 1.0000, Val:0.6960, Test: 0.7020, Time(s/epoch):0.0093
# Epoch: 101, Loss:0.0470 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0097
# Epoch: 102, Loss:0.0640 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 103, Loss:0.0571 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 104, Loss:0.0580 Train: 1.0000, Val:0.6900, Test: 0.6860, Time(s/epoch):0.0084
# Epoch: 105, Loss:0.0558 Train: 1.0000, Val:0.6940, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 106, Loss:0.0518 Train: 1.0000, Val:0.6960, Test: 0.6870, Time(s/epoch):0.0083
# Epoch: 107, Loss:0.0592 Train: 1.0000, Val:0.6960, Test: 0.6930, Time(s/epoch):0.0084
# Epoch: 108, Loss:0.0606 Train: 1.0000, Val:0.6980, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 109, Loss:0.0599 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 110, Loss:0.0620 Train: 1.0000, Val:0.6740, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 111, Loss:0.0613 Train: 1.0000, Val:0.6900, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 112, Loss:0.0569 Train: 1.0000, Val:0.6860, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 113, Loss:0.0591 Train: 1.0000, Val:0.6840, Test: 0.6980, Time(s/epoch):0.0088
# Epoch: 114, Loss:0.0606 Train: 1.0000, Val:0.6820, Test: 0.7010, Time(s/epoch):0.0085
# Epoch: 115, Loss:0.0602 Train: 1.0000, Val:0.6940, Test: 0.7030, Time(s/epoch):0.0098
# Epoch: 116, Loss:0.0572 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 117, Loss:0.0645 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 118, Loss:0.0652 Train: 1.0000, Val:0.6840, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 119, Loss:0.0649 Train: 1.0000, Val:0.6920, Test: 0.6920, Time(s/epoch):0.0083
# Epoch: 120, Loss:0.0578 Train: 1.0000, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0083
# Epoch: 121, Loss:0.0547 Train: 1.0000, Val:0.7000, Test: 0.7010, Time(s/epoch):0.0082
# Epoch: 122, Loss:0.0566 Train: 1.0000, Val:0.7020, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 123, Loss:0.0584 Train: 1.0000, Val:0.6960, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 124, Loss:0.0632 Train: 1.0000, Val:0.7000, Test: 0.6940, Time(s/epoch):0.0082
# Epoch: 125, Loss:0.0657 Train: 1.0000, Val:0.7020, Test: 0.6980, Time(s/epoch):0.0082
# Epoch: 126, Loss:0.0629 Train: 1.0000, Val:0.7040, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 127, Loss:0.0582 Train: 1.0000, Val:0.7040, Test: 0.6980, Time(s/epoch):0.0083
# Epoch: 128, Loss:0.0612 Train: 1.0000, Val:0.6960, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 129, Loss:0.0669 Train: 1.0000, Val:0.6800, Test: 0.6820, Time(s/epoch):0.0097
# Epoch: 130, Loss:0.0645 Train: 1.0000, Val:0.6800, Test: 0.6720, Time(s/epoch):0.0083
# Epoch: 131, Loss:0.0645 Train: 1.0000, Val:0.6820, Test: 0.6710, Time(s/epoch):0.0082
# Epoch: 132, Loss:0.0672 Train: 1.0000, Val:0.6900, Test: 0.6850, Time(s/epoch):0.0087
# Epoch: 133, Loss:0.0569 Train: 1.0000, Val:0.6960, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 134, Loss:0.0569 Train: 1.0000, Val:0.7040, Test: 0.7040, Time(s/epoch):0.0085
# Epoch: 135, Loss:0.0623 Train: 1.0000, Val:0.6960, Test: 0.7020, Time(s/epoch):0.0085
# Epoch: 136, Loss:0.0564 Train: 1.0000, Val:0.6900, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 137, Loss:0.0636 Train: 1.0000, Val:0.6840, Test: 0.6960, Time(s/epoch):0.0088
# Epoch: 138, Loss:0.0600 Train: 1.0000, Val:0.6860, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 139, Loss:0.0560 Train: 1.0000, Val:0.7000, Test: 0.7020, Time(s/epoch):0.0084
# Epoch: 140, Loss:0.0509 Train: 1.0000, Val:0.6960, Test: 0.6960, Time(s/epoch):0.0084
# Epoch: 141, Loss:0.0579 Train: 1.0000, Val:0.6960, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 142, Loss:0.0675 Train: 1.0000, Val:0.6960, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 143, Loss:0.0624 Train: 1.0000, Val:0.6960, Test: 0.6970, Time(s/epoch):0.0098
# Epoch: 144, Loss:0.0596 Train: 1.0000, Val:0.6840, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 145, Loss:0.0522 Train: 1.0000, Val:0.6820, Test: 0.6890, Time(s/epoch):0.0084
# Epoch: 146, Loss:0.0628 Train: 1.0000, Val:0.6840, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 147, Loss:0.0667 Train: 1.0000, Val:0.6900, Test: 0.6920, Time(s/epoch):0.0085
# Epoch: 148, Loss:0.0653 Train: 1.0000, Val:0.6980, Test: 0.6970, Time(s/epoch):0.0087
# Epoch: 149, Loss:0.0627 Train: 1.0000, Val:0.6920, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 150, Loss:0.0474 Train: 1.0000, Val:0.6880, Test: 0.6910, Time(s/epoch):0.0085
# Epoch: 151, Loss:0.0598 Train: 1.0000, Val:0.6840, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 152, Loss:0.0609 Train: 1.0000, Val:0.6880, Test: 0.6830, Time(s/epoch):0.0084
# Epoch: 153, Loss:0.0512 Train: 1.0000, Val:0.6880, Test: 0.6830, Time(s/epoch):0.0086
# Epoch: 154, Loss:0.0658 Train: 1.0000, Val:0.6880, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 155, Loss:0.0594 Train: 1.0000, Val:0.7040, Test: 0.6970, Time(s/epoch):0.0085
# Epoch: 156, Loss:0.0549 Train: 1.0000, Val:0.7140, Test: 0.7090, Time(s/epoch):0.0082
# Epoch: 157, Loss:0.0591 Train: 1.0000, Val:0.7140, Test: 0.7050, Time(s/epoch):0.0086
# Epoch: 158, Loss:0.0612 Train: 1.0000, Val:0.7080, Test: 0.7000, Time(s/epoch):0.0085
# Epoch: 159, Loss:0.0643 Train: 1.0000, Val:0.7020, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 160, Loss:0.0568 Train: 1.0000, Val:0.6960, Test: 0.6960, Time(s/epoch):0.0089
# Epoch: 161, Loss:0.0596 Train: 1.0000, Val:0.6880, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 162, Loss:0.0618 Train: 1.0000, Val:0.6860, Test: 0.6850, Time(s/epoch):0.0085
# Epoch: 163, Loss:0.0617 Train: 1.0000, Val:0.6840, Test: 0.6800, Time(s/epoch):0.0084
# Epoch: 164, Loss:0.0658 Train: 1.0000, Val:0.6960, Test: 0.6840, Time(s/epoch):0.0087
# Epoch: 165, Loss:0.0616 Train: 1.0000, Val:0.7040, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 166, Loss:0.0569 Train: 1.0000, Val:0.7140, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 167, Loss:0.0558 Train: 1.0000, Val:0.7040, Test: 0.7070, Time(s/epoch):0.0085
# Epoch: 168, Loss:0.0536 Train: 1.0000, Val:0.6940, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 169, Loss:0.0574 Train: 1.0000, Val:0.6860, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 170, Loss:0.0644 Train: 1.0000, Val:0.6740, Test: 0.6830, Time(s/epoch):0.0084
# Epoch: 171, Loss:0.0611 Train: 1.0000, Val:0.6760, Test: 0.6840, Time(s/epoch):0.0103
# Epoch: 172, Loss:0.0594 Train: 1.0000, Val:0.6780, Test: 0.6820, Time(s/epoch):0.0085
# Epoch: 173, Loss:0.0561 Train: 1.0000, Val:0.6840, Test: 0.6790, Time(s/epoch):0.0084
# Epoch: 174, Loss:0.0538 Train: 1.0000, Val:0.6920, Test: 0.6830, Time(s/epoch):0.0086
# Epoch: 175, Loss:0.0531 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 176, Loss:0.0551 Train: 1.0000, Val:0.6960, Test: 0.6900, Time(s/epoch):0.0084
# Epoch: 177, Loss:0.0578 Train: 1.0000, Val:0.6960, Test: 0.6940, Time(s/epoch):0.0084
# Epoch: 178, Loss:0.0607 Train: 1.0000, Val:0.7040, Test: 0.7060, Time(s/epoch):0.0084
# Epoch: 179, Loss:0.0568 Train: 1.0000, Val:0.6980, Test: 0.6990, Time(s/epoch):0.0084
# Epoch: 180, Loss:0.0580 Train: 1.0000, Val:0.7060, Test: 0.6980, Time(s/epoch):0.0083
# Epoch: 181, Loss:0.0641 Train: 1.0000, Val:0.6900, Test: 0.6930, Time(s/epoch):0.0085
# Epoch: 182, Loss:0.0572 Train: 1.0000, Val:0.6940, Test: 0.6940, Time(s/epoch):0.0089
# Epoch: 183, Loss:0.0582 Train: 1.0000, Val:0.6840, Test: 0.6820, Time(s/epoch):0.0088
# Epoch: 184, Loss:0.0556 Train: 1.0000, Val:0.6820, Test: 0.6820, Time(s/epoch):0.0099
# Epoch: 185, Loss:0.0707 Train: 1.0000, Val:0.6920, Test: 0.6900, Time(s/epoch):0.0086
# Epoch: 186, Loss:0.0653 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0085
# Epoch: 187, Loss:0.0554 Train: 1.0000, Val:0.7020, Test: 0.7030, Time(s/epoch):0.0087
# Epoch: 188, Loss:0.0625 Train: 1.0000, Val:0.7060, Test: 0.6990, Time(s/epoch):0.0083
# Epoch: 189, Loss:0.0634 Train: 1.0000, Val:0.6940, Test: 0.6960, Time(s/epoch):0.0083
# Epoch: 190, Loss:0.0568 Train: 1.0000, Val:0.6940, Test: 0.6850, Time(s/epoch):0.0085
# Epoch: 191, Loss:0.0527 Train: 1.0000, Val:0.7000, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 192, Loss:0.0651 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0083
# Epoch: 193, Loss:0.0572 Train: 1.0000, Val:0.6920, Test: 0.7000, Time(s/epoch):0.0084
# Epoch: 194, Loss:0.0705 Train: 1.0000, Val:0.6940, Test: 0.6940, Time(s/epoch):0.0083
# Epoch: 195, Loss:0.0643 Train: 1.0000, Val:0.6940, Test: 0.6880, Time(s/epoch):0.0084
# Epoch: 196, Loss:0.0580 Train: 1.0000, Val:0.6860, Test: 0.6750, Time(s/epoch):0.0083
# Epoch: 197, Loss:0.0706 Train: 1.0000, Val:0.6820, Test: 0.6850, Time(s/epoch):0.0089
# Epoch: 198, Loss:0.0537 Train: 1.0000, Val:0.6880, Test: 0.6930, Time(s/epoch):0.0114
# Epoch: 199, Loss:0.0521 Train: 1.0000, Val:0.6900, Test: 0.6940, Time(s/epoch):0.0093
# Epoch: 200, Loss:0.0575 Train: 1.0000, Val:0.6960, Test: 0.7000, Time(s/epoch):0.0083
# [Run-3 score] {'train': 1.0, 'val': 0.714, 'test': 0.709, 'loss': 0.054914891719818115}
# [Average Score] {'train': 1.0, 'val': 0.714, 'test': 0.703}
# [std Score] {'train': 0.0, 'val': 0.0032659863237109073, 'test': 0.004546060565661956}
# [Best Score] {'train': 1.0, 'val': 0.718, 'test': 0.709, 'loss': 0.054914891719818115}
# [Best test run] 2

# %% [markdown]
# Step 1: Adding Edges according to the embedding distribution similairty

# %%
# model.adj_t_cache = model.adj_t_cache.to(torch.device('cpu'))
# model = model.to(torch.device('cpu'))
# # data = data.to(device)

# %%
with torch.no_grad():
    model.eval()
    loss = model(data, finetune=True)
    print('loss:', loss)
    emb_sim, emb = model.get_emb_sim(data.x, embedding=True, cat_self=False)
print(emb_sim, '\n', model.x_sim)
# with torch.no_grad():
#     model.eval()
#     emb_sim = model.cal_similarity(emb, model.adj_t_cache)
# emb_sim
# Out:
# loss: tensor(1.4502, device='cuda:1')
# tensor([[ 1.0000,  0.2148,  0.0788,  ...,  0.3449, -0.0342, -0.0158],
#         [ 0.2148,  1.0000,  0.1338,  ..., -0.0388,  0.2095,  0.2173],
#         [ 0.0788,  0.1338,  1.0000,  ..., -0.0739, -0.1287,  0.3868],
#         ...,
#         [ 0.3449, -0.0388, -0.0739,  ...,  1.0000, -0.0224,  0.1048],
#         [-0.0342,  0.2095, -0.1287,  ..., -0.0224,  1.0000, -0.0164],
#         [-0.0158,  0.2173,  0.3868,  ...,  0.1048, -0.0164,  1.0000]],
#        device='cuda:1')
#  tensor([[ 1.0000, -0.0016, -0.0270,  ..., -0.0240, -0.0130, -0.0427],
#         [-0.0016,  1.0000, -0.0546,  ..., -0.0165,  0.0044, -0.0209],
#         [-0.0270, -0.0546,  1.0000,  ..., -0.0222, -0.0339,  0.0687],
#         ...,
#         [-0.0240, -0.0165, -0.0222,  ...,  1.0000, -0.0013,  0.0081],
#         [-0.0130,  0.0044, -0.0339,  ..., -0.0013,  1.0000, -0.0477],
#         [-0.0427, -0.0209,  0.0687,  ...,  0.0081, -0.0477,  1.0000]])

# %%
# feat_sim = model.x_sim.cpu()
feat_sim = emb_sim.cpu()
# feat_sim = lbl_sim
feat_sim -= torch.diag_embed(feat_sim.diag())

# # applied mask_node_deg with thres_min_deg
# feat_sim = feat_sim[mask_node_deg, :]
# feat_sim[:, mask_node_deg] = -1

print((feat_sim > 0.99).sum(1).float().mean(), feat_sim[0])
k = 8
# thres_lower_sim = 0.96 # 0.94 best for GCN, 0.95, 0.96 best for GAT
thres_lower_sim = np.quantile(feat_sim.view(-1).numpy(), q=1 - 1.1 * data.num_edges / feat_sim.view(-1).shape[0])
print(thres_lower_sim, data.num_edges)
topk_lbl_sim = feat_sim.topk(k=k, dim=1, largest=True, sorted=False)
# topk_lbl_sim = (lbl_sim_2rd - torch.diag_embed(lbl_sim_2rd.diag())).topk(k=k, dim=1, largest=True, sorted=False)
# topk_lbl_sim = (lbl_sim_merge - torch.diag_embed(lbl_sim_merge.diag())).topk(k=k, dim=1, largest=True, sorted=False)

row = torch.stack([torch.arange(0, x.shape[0]) for _ in range(k)], dim=-1).view(-1).to(x.device)
# row = torch.stack([torch.arange(0, x.shape[0])[mask_node_deg] for _ in range(k)], dim=-1).view(-1).to(x.device)

col = topk_lbl_sim.indices.view(-1)
assert row.shape == col.shape
edge_index_topk_lbl_dist = torch.stack((row, col), dim=0).long()
edge_index_topk_lbl_dist = edge_index_topk_lbl_dist[:, topk_lbl_sim.values.view(-1) >= thres_lower_sim]
edge_index_topk_lbl_dist.shape

# edge_index_topk_lbl_dist = torch.stack(torch.where(lbl_sim > 0.99), dim=0)
# edge_index_topk_lbl_dist.shape
# Out:
# tensor(1.0135) tensor([ 0.0000,  0.2148,  0.0788,  ...,  0.3449, -0.0342, -0.0158])
# 0.8463431000709534 9104
# torch.Size([2, 6292])

# %% [markdown]
# Step 2: Pruning edges from original graph according to the embedding distributional similarity

# %%
# prunning on the original graph
thres_quantile = 0.5
feat_sim = emb_sim.cpu()
mask_prunning = feat_sim[edge_index[0], edge_index[1]]
print('thres:', np.quantile(mask_prunning.cpu().numpy(), q=thres_quantile), mask_prunning.mean())
# mask_prunning = mask_prunning > np.quantile(mask_prunning.cpu().numpy(), q=thres_quantile)
mask_prunning = mask_prunning > 0.
# print(mask_prunning.sum() / mask_prunning.shape[0], '#' * 20)
edge_index_prunning = edge_index[:, mask_prunning]
print('Prune {} edges from {} to {}'.format(mask_prunning.shape[0] - mask_prunning.sum(), edge_index.shape, edge_index_prunning.shape))
# Out:
# thres: 0.6629112362861633 tensor(0.6232)
# Prune 110 edges from torch.Size([2, 9104]) to torch.Size([2, 8994])

# %%
# replace with label-distributional-graph
import copy
from torch_sparse import coalesce
data_modi = copy.deepcopy(data).to(device)
# data_modi.edge_index = edge_index_topk_lbl_dist.to(device)
# data_modi.edge_index = torch.stack((torch.arange(x.shape[0]), torch.arange(x.shape[0])), dim=0).to(device)
edge_index_merge = coalesce(torch.cat((edge_index, edge_index_topk_lbl_dist), dim=-1), None, data.num_nodes, data.num_nodes)[0]
# edge_index_merge = coalesce(torch.cat((edge_index_prunning, edge_index_topk_lbl_dist), dim=-1), None, data.num_nodes, data.num_nodes)[0]
# edge_index_merge = edge_index_prunning
# edge_index_merge = edge_index_lbl.to(device)
# edge_index_merge = coalesce(torch.cat((edge_index, edge_index_lbl), dim=-1), None, data.num_nodes, data.num_nodes)[0]
data_modi.edge_index = edge_index_merge.to(device)
print(data_modi)
# Out:
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])

# %%
print('added_edges_ratio_in_train_set:', (data.train_mask[edge_index_topk_lbl_dist[0]] * data.train_mask[edge_index_topk_lbl_dist[1]]).sum().item() / edge_index_topk_lbl_dist.shape[1])
print('added_edges_homo_ratio:', (data.y[edge_index_topk_lbl_dist[0]] == data.y[edge_index_topk_lbl_dist[1]]).sum().item() / edge_index_topk_lbl_dist.shape[1])
# Out:
# added_edges_ratio_in_train_set: 0.001589319771137953
# added_edges_homo_ratio: 0.7566751430387794

# %%
print((data.y[data.edge_index[0]] == data.y[data.edge_index[1]]).sum() / data.edge_index.shape[1])
print((data.y[data_modi.edge_index[0]] == data.y[data_modi.edge_index[1]]).sum() / data_modi.edge_index.shape[1])
# Out:
# tensor(0.7355, device='cuda:1')
# tensor(0.7332, device='cuda:1')

# %%
# main(data_modi, save=False, repeat=1, gnn='GCN', seed=0)
main(data_modi, save=False, repeat=3, gnn='GraphSAGE')
# Out:
# repeat 1/3
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# GraphSAGE(
#   (convs): ModuleList(
#     (0): SAGEConv(3703, 64)
#     (1): SAGEConv(64, 6)
#   )
# )
# auto fixed data split seed to 0, model init seed to 0
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# [Dataset-CiteSeer()] train_num:120, val_num:500, test_num:1000, class_num:6
# Epoch: 001, Loss:1.7973 Train: 0.9750, Val:0.4980, Test: 0.4760, Time(s/epoch):0.0090
# Epoch: 002, Loss:1.4097 Train: 1.0000, Val:0.5860, Test: 0.5590, Time(s/epoch):0.0083
# Epoch: 003, Loss:0.8846 Train: 1.0000, Val:0.6440, Test: 0.6140, Time(s/epoch):0.0085
# Epoch: 004, Loss:0.4634 Train: 1.0000, Val:0.6800, Test: 0.6790, Time(s/epoch):0.0082
# Epoch: 005, Loss:0.1919 Train: 1.0000, Val:0.6820, Test: 0.6860, Time(s/epoch):0.0084
# Epoch: 006, Loss:0.0991 Train: 1.0000, Val:0.7040, Test: 0.6840, Time(s/epoch):0.0084
# Epoch: 007, Loss:0.0513 Train: 1.0000, Val:0.7060, Test: 0.6820, Time(s/epoch):0.0084
# Epoch: 008, Loss:0.0405 Train: 1.0000, Val:0.6980, Test: 0.6990, Time(s/epoch):0.0102
# Epoch: 009, Loss:0.0171 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 010, Loss:0.0143 Train: 1.0000, Val:0.7100, Test: 0.6970, Time(s/epoch):0.0084
# Epoch: 011, Loss:0.0115 Train: 1.0000, Val:0.7100, Test: 0.6980, Time(s/epoch):0.0084
# Epoch: 012, Loss:0.0251 Train: 1.0000, Val:0.7140, Test: 0.6870, Time(s/epoch):0.0084
# Epoch: 013, Loss:0.0241 Train: 1.0000, Val:0.7120, Test: 0.6910, Time(s/epoch):0.0084
# Epoch: 014, Loss:0.0153 Train: 1.0000, Val:0.7180, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 015, Loss:0.0413 Train: 1.0000, Val:0.7280, Test: 0.7100, Time(s/epoch):0.0084
# Epoch: 016, Loss:0.0125 Train: 1.0000, Val:0.7140, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 017, Loss:0.0116 Train: 1.0000, Val:0.7020, Test: 0.6950, Time(s/epoch):0.0084
# Epoch: 018, Loss:0.0183 Train: 1.0000, Val:0.6760, Test: 0.6780, Time(s/epoch):0.0083
# Epoch: 019, Loss:0.0353 Train: 1.0000, Val:0.6800, Test: 0.6900, Time(s/epoch):0.0085
# Epoch: 020, Loss:0.0361 Train: 1.0000, Val:0.7060, Test: 0.7040, Time(s/epoch):0.0084
# Epoch: 021, Loss:0.0388 Train: 1.0000, Val:0.7000, Test: 0.6930, Time(s/epoch):0.0083
# Epoch: 022, Loss:0.0344 Train: 1.0000, Val:0.6920, Test: 0.6760, Time(s/epoch):0.0084
# Epoch: 023, Loss:0.0331 Train: 1.0000, Val:0.6940, Test: 0.6690, Time(s/epoch):0.0084
# Epoch: 024, Loss:0.0366 Train: 1.0000, Val:0.6920, Test: 0.6730, Time(s/epoch):0.0084
# Epoch: 025, Loss:0.0472 Train: 1.0000, Val:0.6940, Test: 0.6760, Time(s/epoch):0.0094
# Epoch: 026, Loss:0.0418 Train: 1.0000, Val:0.7000, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 027, Loss:0.0357 Train: 1.0000, Val:0.7000, Test: 0.6800, Time(s/epoch):0.0084
# Epoch: 028, Loss:0.0408 Train: 1.0000, Val:0.7040, Test: 0.6810, Time(s/epoch):0.0083
# Epoch: 029, Loss:0.0401 Train: 1.0000, Val:0.7080, Test: 0.6940, Time(s/epoch):0.0085
# Epoch: 030, Loss:0.0410 Train: 1.0000, Val:0.7200, Test: 0.7000, Time(s/epoch):0.0083
# Epoch: 031, Loss:0.0402 Train: 1.0000, Val:0.7260, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 032, Loss:0.0387 Train: 1.0000, Val:0.7160, Test: 0.7080, Time(s/epoch):0.0082
# Epoch: 033, Loss:0.0374 Train: 1.0000, Val:0.7100, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 034, Loss:0.0306 Train: 1.0000, Val:0.7080, Test: 0.6910, Time(s/epoch):0.0081
# Epoch: 035, Loss:0.0346 Train: 1.0000, Val:0.7080, Test: 0.6910, Time(s/epoch):0.0081
# Epoch: 036, Loss:0.0284 Train: 1.0000, Val:0.7120, Test: 0.6860, Time(s/epoch):0.0080
# Epoch: 037, Loss:0.0281 Train: 1.0000, Val:0.7200, Test: 0.6890, Time(s/epoch):0.0080
# Epoch: 038, Loss:0.0330 Train: 1.0000, Val:0.7140, Test: 0.7000, Time(s/epoch):0.0079
# Epoch: 039, Loss:0.0267 Train: 1.0000, Val:0.7200, Test: 0.7000, Time(s/epoch):0.0081
# Epoch: 040, Loss:0.0241 Train: 1.0000, Val:0.7220, Test: 0.6970, Time(s/epoch):0.0080
# Epoch: 041, Loss:0.0281 Train: 1.0000, Val:0.7220, Test: 0.6950, Time(s/epoch):0.0101
# Epoch: 042, Loss:0.0305 Train: 1.0000, Val:0.7100, Test: 0.6910, Time(s/epoch):0.0086
# Epoch: 043, Loss:0.0281 Train: 1.0000, Val:0.6980, Test: 0.7000, Time(s/epoch):0.0081
# Epoch: 044, Loss:0.0247 Train: 1.0000, Val:0.6960, Test: 0.7020, Time(s/epoch):0.0081
# Epoch: 045, Loss:0.0278 Train: 1.0000, Val:0.6980, Test: 0.7040, Time(s/epoch):0.0080
# Epoch: 046, Loss:0.0329 Train: 1.0000, Val:0.7060, Test: 0.7110, Time(s/epoch):0.0083
# Epoch: 047, Loss:0.0269 Train: 1.0000, Val:0.7140, Test: 0.7070, Time(s/epoch):0.0084
# Epoch: 048, Loss:0.0375 Train: 1.0000, Val:0.7080, Test: 0.7070, Time(s/epoch):0.0083
# Epoch: 049, Loss:0.0317 Train: 1.0000, Val:0.7160, Test: 0.7010, Time(s/epoch):0.0081
# Epoch: 050, Loss:0.0264 Train: 1.0000, Val:0.7040, Test: 0.6920, Time(s/epoch):0.0083
# Epoch: 051, Loss:0.0344 Train: 1.0000, Val:0.7080, Test: 0.6900, Time(s/epoch):0.0081
# Epoch: 052, Loss:0.0293 Train: 1.0000, Val:0.7120, Test: 0.6970, Time(s/epoch):0.0081
# Epoch: 053, Loss:0.0236 Train: 1.0000, Val:0.7100, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 054, Loss:0.0253 Train: 1.0000, Val:0.7120, Test: 0.7010, Time(s/epoch):0.0082
# Epoch: 055, Loss:0.0211 Train: 1.0000, Val:0.7040, Test: 0.7040, Time(s/epoch):0.0079
# Epoch: 056, Loss:0.0236 Train: 1.0000, Val:0.7100, Test: 0.7110, Time(s/epoch):0.0084
# Epoch: 057, Loss:0.0258 Train: 1.0000, Val:0.7140, Test: 0.7140, Time(s/epoch):0.0081
# Epoch: 058, Loss:0.0242 Train: 1.0000, Val:0.7120, Test: 0.7070, Time(s/epoch):0.0088
# Epoch: 059, Loss:0.0240 Train: 1.0000, Val:0.7140, Test: 0.7020, Time(s/epoch):0.0082
# Epoch: 060, Loss:0.0245 Train: 1.0000, Val:0.7120, Test: 0.7070, Time(s/epoch):0.0083
# Epoch: 061, Loss:0.0255 Train: 1.0000, Val:0.7120, Test: 0.7140, Time(s/epoch):0.0085
# Epoch: 062, Loss:0.0254 Train: 1.0000, Val:0.7160, Test: 0.7230, Time(s/epoch):0.0084
# Epoch: 063, Loss:0.0191 Train: 1.0000, Val:0.7280, Test: 0.7180, Time(s/epoch):0.0082
# Epoch: 064, Loss:0.0239 Train: 1.0000, Val:0.7260, Test: 0.7150, Time(s/epoch):0.0082
# Epoch: 065, Loss:0.0281 Train: 1.0000, Val:0.7220, Test: 0.7160, Time(s/epoch):0.0081
# Epoch: 066, Loss:0.0292 Train: 1.0000, Val:0.7160, Test: 0.7060, Time(s/epoch):0.0082
# Epoch: 067, Loss:0.0238 Train: 1.0000, Val:0.7140, Test: 0.6940, Time(s/epoch):0.0081
# Epoch: 068, Loss:0.0256 Train: 1.0000, Val:0.7140, Test: 0.6970, Time(s/epoch):0.0080
# Epoch: 069, Loss:0.0232 Train: 1.0000, Val:0.7160, Test: 0.7010, Time(s/epoch):0.0081
# Epoch: 070, Loss:0.0253 Train: 1.0000, Val:0.7160, Test: 0.7160, Time(s/epoch):0.0083
# Epoch: 071, Loss:0.0263 Train: 1.0000, Val:0.7200, Test: 0.7160, Time(s/epoch):0.0080
# Epoch: 072, Loss:0.0290 Train: 1.0000, Val:0.7140, Test: 0.7210, Time(s/epoch):0.0080
# Epoch: 073, Loss:0.0239 Train: 1.0000, Val:0.7100, Test: 0.7180, Time(s/epoch):0.0084
# Epoch: 074, Loss:0.0283 Train: 1.0000, Val:0.7080, Test: 0.7100, Time(s/epoch):0.0093
# Epoch: 075, Loss:0.0266 Train: 1.0000, Val:0.7140, Test: 0.7020, Time(s/epoch):0.0083
# Epoch: 076, Loss:0.0265 Train: 1.0000, Val:0.7100, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 077, Loss:0.0279 Train: 1.0000, Val:0.7100, Test: 0.7000, Time(s/epoch):0.0080
# Epoch: 078, Loss:0.0219 Train: 1.0000, Val:0.7080, Test: 0.7040, Time(s/epoch):0.0079
# Epoch: 079, Loss:0.0334 Train: 1.0000, Val:0.7120, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 080, Loss:0.0244 Train: 1.0000, Val:0.7160, Test: 0.7190, Time(s/epoch):0.0080
# Epoch: 081, Loss:0.0226 Train: 1.0000, Val:0.6940, Test: 0.7160, Time(s/epoch):0.0083
# Epoch: 082, Loss:0.0253 Train: 1.0000, Val:0.6960, Test: 0.7080, Time(s/epoch):0.0082
# Epoch: 083, Loss:0.0294 Train: 1.0000, Val:0.7080, Test: 0.7000, Time(s/epoch):0.0082
# Epoch: 084, Loss:0.0284 Train: 1.0000, Val:0.7080, Test: 0.6980, Time(s/epoch):0.0080
# Epoch: 085, Loss:0.0210 Train: 1.0000, Val:0.7060, Test: 0.6960, Time(s/epoch):0.0082
# Epoch: 086, Loss:0.0254 Train: 1.0000, Val:0.7120, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 087, Loss:0.0253 Train: 1.0000, Val:0.7280, Test: 0.7130, Time(s/epoch):0.0080
# Epoch: 088, Loss:0.0270 Train: 1.0000, Val:0.7120, Test: 0.7230, Time(s/epoch):0.0096
# Epoch: 089, Loss:0.0163 Train: 1.0000, Val:0.7000, Test: 0.7240, Time(s/epoch):0.0082
# Epoch: 090, Loss:0.0266 Train: 1.0000, Val:0.6980, Test: 0.7270, Time(s/epoch):0.0080
# Epoch: 091, Loss:0.0234 Train: 1.0000, Val:0.6880, Test: 0.7150, Time(s/epoch):0.0083
# Epoch: 092, Loss:0.0205 Train: 1.0000, Val:0.6860, Test: 0.7030, Time(s/epoch):0.0079
# Epoch: 093, Loss:0.0252 Train: 1.0000, Val:0.7000, Test: 0.6950, Time(s/epoch):0.0080
# Epoch: 094, Loss:0.0255 Train: 1.0000, Val:0.7080, Test: 0.6900, Time(s/epoch):0.0143
# Epoch: 095, Loss:0.0268 Train: 1.0000, Val:0.7220, Test: 0.6930, Time(s/epoch):0.0082
# Epoch: 096, Loss:0.0211 Train: 1.0000, Val:0.7300, Test: 0.7030, Time(s/epoch):0.0092
# Epoch: 097, Loss:0.0229 Train: 1.0000, Val:0.7280, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 098, Loss:0.0338 Train: 1.0000, Val:0.7140, Test: 0.7250, Time(s/epoch):0.0081
# Epoch: 099, Loss:0.0234 Train: 1.0000, Val:0.6960, Test: 0.7190, Time(s/epoch):0.0081
# Epoch: 100, Loss:0.0221 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0079
# Epoch: 101, Loss:0.0271 Train: 1.0000, Val:0.6880, Test: 0.6920, Time(s/epoch):0.0079
# Epoch: 102, Loss:0.0260 Train: 1.0000, Val:0.7080, Test: 0.6960, Time(s/epoch):0.0079
# Epoch: 103, Loss:0.0286 Train: 1.0000, Val:0.7180, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 104, Loss:0.0308 Train: 1.0000, Val:0.7060, Test: 0.7010, Time(s/epoch):0.0079
# Epoch: 105, Loss:0.0240 Train: 1.0000, Val:0.6980, Test: 0.7010, Time(s/epoch):0.0094
# Epoch: 106, Loss:0.0291 Train: 1.0000, Val:0.6980, Test: 0.6960, Time(s/epoch):0.0081
# Epoch: 107, Loss:0.0218 Train: 1.0000, Val:0.7060, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 108, Loss:0.0365 Train: 1.0000, Val:0.7100, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 109, Loss:0.0249 Train: 1.0000, Val:0.7000, Test: 0.6940, Time(s/epoch):0.0080
# Epoch: 110, Loss:0.0196 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0080
# Epoch: 111, Loss:0.0237 Train: 1.0000, Val:0.7060, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 112, Loss:0.0261 Train: 1.0000, Val:0.6980, Test: 0.7110, Time(s/epoch):0.0081
# Epoch: 113, Loss:0.0227 Train: 1.0000, Val:0.7020, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 114, Loss:0.0241 Train: 1.0000, Val:0.6980, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 115, Loss:0.0243 Train: 1.0000, Val:0.7060, Test: 0.7120, Time(s/epoch):0.0079
# Epoch: 116, Loss:0.0178 Train: 1.0000, Val:0.7020, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 117, Loss:0.0250 Train: 1.0000, Val:0.6920, Test: 0.7160, Time(s/epoch):0.0083
# Epoch: 118, Loss:0.0250 Train: 1.0000, Val:0.6840, Test: 0.6990, Time(s/epoch):0.0079
# Epoch: 119, Loss:0.0247 Train: 1.0000, Val:0.6860, Test: 0.6960, Time(s/epoch):0.0080
# Epoch: 120, Loss:0.0198 Train: 1.0000, Val:0.6900, Test: 0.7100, Time(s/epoch):0.0079
# Epoch: 121, Loss:0.0238 Train: 1.0000, Val:0.7140, Test: 0.7140, Time(s/epoch):0.0085
# Epoch: 122, Loss:0.0275 Train: 1.0000, Val:0.7140, Test: 0.7130, Time(s/epoch):0.0095
# Epoch: 123, Loss:0.0274 Train: 1.0000, Val:0.7200, Test: 0.7140, Time(s/epoch):0.0081
# Epoch: 124, Loss:0.0281 Train: 1.0000, Val:0.7100, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 125, Loss:0.0227 Train: 1.0000, Val:0.7020, Test: 0.7150, Time(s/epoch):0.0080
# Epoch: 126, Loss:0.0252 Train: 1.0000, Val:0.7060, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 127, Loss:0.0254 Train: 1.0000, Val:0.6980, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 128, Loss:0.0317 Train: 1.0000, Val:0.7140, Test: 0.7120, Time(s/epoch):0.0080
# Epoch: 129, Loss:0.0252 Train: 1.0000, Val:0.7120, Test: 0.7140, Time(s/epoch):0.0079
# Epoch: 130, Loss:0.0250 Train: 1.0000, Val:0.7040, Test: 0.7150, Time(s/epoch):0.0079
# Epoch: 131, Loss:0.0331 Train: 1.0000, Val:0.7040, Test: 0.7090, Time(s/epoch):0.0081
# Epoch: 132, Loss:0.0255 Train: 1.0000, Val:0.6960, Test: 0.7000, Time(s/epoch):0.0082
# Epoch: 133, Loss:0.0233 Train: 1.0000, Val:0.6980, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 134, Loss:0.0268 Train: 1.0000, Val:0.7080, Test: 0.7110, Time(s/epoch):0.0079
# Epoch: 135, Loss:0.0213 Train: 1.0000, Val:0.7080, Test: 0.7010, Time(s/epoch):0.0079
# Epoch: 136, Loss:0.0288 Train: 1.0000, Val:0.7000, Test: 0.7060, Time(s/epoch):0.0081
# Epoch: 137, Loss:0.0268 Train: 1.0000, Val:0.7000, Test: 0.7090, Time(s/epoch):0.0081
# Epoch: 138, Loss:0.0290 Train: 1.0000, Val:0.7020, Test: 0.7120, Time(s/epoch):0.0094
# Epoch: 139, Loss:0.0258 Train: 1.0000, Val:0.6980, Test: 0.7040, Time(s/epoch):0.0104
# Epoch: 140, Loss:0.0338 Train: 1.0000, Val:0.6960, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 141, Loss:0.0254 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 142, Loss:0.0303 Train: 1.0000, Val:0.6860, Test: 0.6940, Time(s/epoch):0.0079
# Epoch: 143, Loss:0.0299 Train: 1.0000, Val:0.6920, Test: 0.6850, Time(s/epoch):0.0079
# Epoch: 144, Loss:0.0228 Train: 1.0000, Val:0.6900, Test: 0.6810, Time(s/epoch):0.0086
# Epoch: 145, Loss:0.0185 Train: 1.0000, Val:0.7000, Test: 0.6900, Time(s/epoch):0.0092
# Epoch: 146, Loss:0.0219 Train: 1.0000, Val:0.7060, Test: 0.7110, Time(s/epoch):0.0091
# Epoch: 147, Loss:0.0301 Train: 1.0000, Val:0.7160, Test: 0.7110, Time(s/epoch):0.0088
# Epoch: 148, Loss:0.0203 Train: 1.0000, Val:0.7180, Test: 0.7200, Time(s/epoch):0.0089
# Epoch: 149, Loss:0.0233 Train: 1.0000, Val:0.7220, Test: 0.7190, Time(s/epoch):0.0089
# Epoch: 150, Loss:0.0236 Train: 1.0000, Val:0.7120, Test: 0.7060, Time(s/epoch):0.0094
# Epoch: 151, Loss:0.0237 Train: 1.0000, Val:0.7080, Test: 0.7010, Time(s/epoch):0.0108
# Epoch: 152, Loss:0.0228 Train: 1.0000, Val:0.7060, Test: 0.7040, Time(s/epoch):0.0090
# Epoch: 153, Loss:0.0267 Train: 1.0000, Val:0.7000, Test: 0.7030, Time(s/epoch):0.0089
# Epoch: 154, Loss:0.0267 Train: 1.0000, Val:0.7020, Test: 0.7080, Time(s/epoch):0.0089
# Epoch: 155, Loss:0.0221 Train: 1.0000, Val:0.7100, Test: 0.7050, Time(s/epoch):0.0088
# Epoch: 156, Loss:0.0203 Train: 1.0000, Val:0.7180, Test: 0.7180, Time(s/epoch):0.0089
# Epoch: 157, Loss:0.0296 Train: 1.0000, Val:0.7280, Test: 0.7190, Time(s/epoch):0.0090
# Epoch: 158, Loss:0.0324 Train: 1.0000, Val:0.7160, Test: 0.7160, Time(s/epoch):0.0089
# Epoch: 159, Loss:0.0254 Train: 1.0000, Val:0.7160, Test: 0.7120, Time(s/epoch):0.0092
# Epoch: 160, Loss:0.0246 Train: 1.0000, Val:0.7020, Test: 0.7100, Time(s/epoch):0.0088
# Epoch: 161, Loss:0.0283 Train: 1.0000, Val:0.6960, Test: 0.7110, Time(s/epoch):0.0090
# Epoch: 162, Loss:0.0261 Train: 1.0000, Val:0.6940, Test: 0.7130, Time(s/epoch):0.0089
# Epoch: 163, Loss:0.0224 Train: 1.0000, Val:0.7100, Test: 0.7130, Time(s/epoch):0.0091
# Epoch: 164, Loss:0.0282 Train: 1.0000, Val:0.7240, Test: 0.7100, Time(s/epoch):0.0089
# Epoch: 165, Loss:0.0302 Train: 1.0000, Val:0.7280, Test: 0.7000, Time(s/epoch):0.0089
# Epoch: 166, Loss:0.0191 Train: 1.0000, Val:0.7300, Test: 0.6960, Time(s/epoch):0.0088
# Epoch: 167, Loss:0.0226 Train: 1.0000, Val:0.7220, Test: 0.7100, Time(s/epoch):0.0112
# Epoch: 168, Loss:0.0282 Train: 1.0000, Val:0.7120, Test: 0.7190, Time(s/epoch):0.0083
# Epoch: 169, Loss:0.0251 Train: 1.0000, Val:0.7100, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 170, Loss:0.0235 Train: 1.0000, Val:0.7020, Test: 0.7040, Time(s/epoch):0.0080
# Epoch: 171, Loss:0.0457 Train: 1.0000, Val:0.7200, Test: 0.7180, Time(s/epoch):0.0081
# Epoch: 172, Loss:0.0279 Train: 1.0000, Val:0.7180, Test: 0.7100, Time(s/epoch):0.0079
# Epoch: 173, Loss:0.0344 Train: 1.0000, Val:0.7080, Test: 0.6810, Time(s/epoch):0.0080
# Epoch: 174, Loss:0.0341 Train: 1.0000, Val:0.7180, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 175, Loss:0.0246 Train: 1.0000, Val:0.7100, Test: 0.7100, Time(s/epoch):0.0081
# Epoch: 176, Loss:0.0191 Train: 1.0000, Val:0.6900, Test: 0.7040, Time(s/epoch):0.0079
# Epoch: 177, Loss:0.0248 Train: 1.0000, Val:0.6760, Test: 0.6970, Time(s/epoch):0.0081
# Epoch: 178, Loss:0.0254 Train: 1.0000, Val:0.6760, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 179, Loss:0.0348 Train: 1.0000, Val:0.6940, Test: 0.7140, Time(s/epoch):0.0081
# Epoch: 180, Loss:0.0237 Train: 1.0000, Val:0.7120, Test: 0.7130, Time(s/epoch):0.0080
# Epoch: 181, Loss:0.0168 Train: 1.0000, Val:0.7060, Test: 0.7000, Time(s/epoch):0.0081
# Epoch: 182, Loss:0.0236 Train: 1.0000, Val:0.6960, Test: 0.6910, Time(s/epoch):0.0080
# Epoch: 183, Loss:0.0246 Train: 1.0000, Val:0.7000, Test: 0.6810, Time(s/epoch):0.0106
# Epoch: 184, Loss:0.0276 Train: 1.0000, Val:0.7160, Test: 0.6950, Time(s/epoch):0.0087
# Epoch: 185, Loss:0.0294 Train: 1.0000, Val:0.7000, Test: 0.7000, Time(s/epoch):0.0081
# Epoch: 186, Loss:0.0205 Train: 1.0000, Val:0.6900, Test: 0.7110, Time(s/epoch):0.0079
# Epoch: 187, Loss:0.0347 Train: 1.0000, Val:0.6980, Test: 0.7230, Time(s/epoch):0.0079
# Epoch: 188, Loss:0.0290 Train: 1.0000, Val:0.7100, Test: 0.7160, Time(s/epoch):0.0079
# Epoch: 189, Loss:0.0220 Train: 1.0000, Val:0.6920, Test: 0.7000, Time(s/epoch):0.0079
# Epoch: 190, Loss:0.0295 Train: 1.0000, Val:0.6980, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 191, Loss:0.0263 Train: 1.0000, Val:0.6980, Test: 0.6870, Time(s/epoch):0.0080
# Epoch: 192, Loss:0.0229 Train: 1.0000, Val:0.7020, Test: 0.6820, Time(s/epoch):0.0081
# Epoch: 193, Loss:0.0247 Train: 1.0000, Val:0.7000, Test: 0.6960, Time(s/epoch):0.0081
# Epoch: 194, Loss:0.0254 Train: 1.0000, Val:0.6960, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 195, Loss:0.0227 Train: 1.0000, Val:0.6920, Test: 0.7140, Time(s/epoch):0.0080
# Epoch: 196, Loss:0.0262 Train: 1.0000, Val:0.7100, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 197, Loss:0.0284 Train: 1.0000, Val:0.7040, Test: 0.7160, Time(s/epoch):0.0084
# Epoch: 198, Loss:0.0441 Train: 1.0000, Val:0.7020, Test: 0.7100, Time(s/epoch):0.0081
# Epoch: 199, Loss:0.0228 Train: 1.0000, Val:0.6860, Test: 0.6770, Time(s/epoch):0.0081
# Epoch: 200, Loss:0.0387 Train: 1.0000, Val:0.6680, Test: 0.6560, Time(s/epoch):0.0081
# [Run-1 score] {'train': 1.0, 'val': 0.73, 'test': 0.703, 'loss': 0.02105005457997322}
# repeat 2/3
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# GraphSAGE(
#   (convs): ModuleList(
#     (0): SAGEConv(3703, 64)
#     (1): SAGEConv(64, 6)
#   )
# )
# auto fixed data split seed to 0, model init seed to 1
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# [Dataset-CiteSeer()] train_num:120, val_num:500, test_num:1000, class_num:6
# Epoch: 001, Loss:1.7935 Train: 0.9417, Val:0.4260, Test: 0.4710, Time(s/epoch):0.0100
# Epoch: 002, Loss:1.3798 Train: 0.9833, Val:0.6840, Test: 0.6760, Time(s/epoch):0.0080
# Epoch: 003, Loss:0.8269 Train: 0.9833, Val:0.7120, Test: 0.6860, Time(s/epoch):0.0082
# Epoch: 004, Loss:0.3924 Train: 1.0000, Val:0.7080, Test: 0.6890, Time(s/epoch):0.0081
# Epoch: 005, Loss:0.1531 Train: 1.0000, Val:0.6960, Test: 0.6760, Time(s/epoch):0.0078
# Epoch: 006, Loss:0.0915 Train: 1.0000, Val:0.6820, Test: 0.6640, Time(s/epoch):0.0083
# Epoch: 007, Loss:0.0422 Train: 1.0000, Val:0.6740, Test: 0.6580, Time(s/epoch):0.0079
# Epoch: 008, Loss:0.0386 Train: 1.0000, Val:0.6860, Test: 0.6710, Time(s/epoch):0.0082
# Epoch: 009, Loss:0.0115 Train: 1.0000, Val:0.6880, Test: 0.6750, Time(s/epoch):0.0081
# Epoch: 010, Loss:0.0133 Train: 1.0000, Val:0.6940, Test: 0.6770, Time(s/epoch):0.0085
# Epoch: 011, Loss:0.0115 Train: 1.0000, Val:0.7000, Test: 0.6820, Time(s/epoch):0.0081
# Epoch: 012, Loss:0.0082 Train: 1.0000, Val:0.7080, Test: 0.6840, Time(s/epoch):0.0081
# Epoch: 013, Loss:0.0067 Train: 1.0000, Val:0.7040, Test: 0.6860, Time(s/epoch):0.0078
# Epoch: 014, Loss:0.0119 Train: 1.0000, Val:0.6940, Test: 0.6860, Time(s/epoch):0.0080
# Epoch: 015, Loss:0.0108 Train: 1.0000, Val:0.6840, Test: 0.6910, Time(s/epoch):0.0083
# Epoch: 016, Loss:0.0142 Train: 1.0000, Val:0.6920, Test: 0.6880, Time(s/epoch):0.0083
# Epoch: 017, Loss:0.0173 Train: 1.0000, Val:0.6920, Test: 0.6830, Time(s/epoch):0.0080
# Epoch: 018, Loss:0.0171 Train: 1.0000, Val:0.6940, Test: 0.6770, Time(s/epoch):0.0080
# Epoch: 019, Loss:0.0234 Train: 1.0000, Val:0.7040, Test: 0.6960, Time(s/epoch):0.0081
# Epoch: 020, Loss:0.0371 Train: 1.0000, Val:0.7140, Test: 0.6990, Time(s/epoch):0.0079
# Epoch: 021, Loss:0.0364 Train: 1.0000, Val:0.7100, Test: 0.7100, Time(s/epoch):0.0079
# Epoch: 022, Loss:0.0333 Train: 1.0000, Val:0.7140, Test: 0.7170, Time(s/epoch):0.0081
# Epoch: 023, Loss:0.0323 Train: 1.0000, Val:0.7140, Test: 0.7180, Time(s/epoch):0.0083
# Epoch: 024, Loss:0.0382 Train: 1.0000, Val:0.7100, Test: 0.7090, Time(s/epoch):0.0081
# Epoch: 025, Loss:0.0353 Train: 1.0000, Val:0.7180, Test: 0.7000, Time(s/epoch):0.0080
# Epoch: 026, Loss:0.0271 Train: 1.0000, Val:0.7040, Test: 0.6860, Time(s/epoch):0.0081
# Epoch: 027, Loss:0.0446 Train: 1.0000, Val:0.6900, Test: 0.6740, Time(s/epoch):0.0080
# Epoch: 028, Loss:0.0398 Train: 1.0000, Val:0.6940, Test: 0.6790, Time(s/epoch):0.0098
# Epoch: 029, Loss:0.0425 Train: 1.0000, Val:0.7020, Test: 0.6930, Time(s/epoch):0.0081
# Epoch: 030, Loss:0.0351 Train: 1.0000, Val:0.7160, Test: 0.6990, Time(s/epoch):0.0078
# Epoch: 031, Loss:0.0422 Train: 1.0000, Val:0.7140, Test: 0.7050, Time(s/epoch):0.0079
# Epoch: 032, Loss:0.0366 Train: 1.0000, Val:0.7180, Test: 0.7080, Time(s/epoch):0.0083
# Epoch: 033, Loss:0.0395 Train: 1.0000, Val:0.7160, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 034, Loss:0.0300 Train: 1.0000, Val:0.7060, Test: 0.6980, Time(s/epoch):0.0079
# Epoch: 035, Loss:0.0276 Train: 1.0000, Val:0.7060, Test: 0.6970, Time(s/epoch):0.0083
# Epoch: 036, Loss:0.0296 Train: 1.0000, Val:0.7160, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 037, Loss:0.0202 Train: 1.0000, Val:0.7240, Test: 0.7070, Time(s/epoch):0.0083
# Epoch: 038, Loss:0.0275 Train: 1.0000, Val:0.7100, Test: 0.7010, Time(s/epoch):0.0089
# Epoch: 039, Loss:0.0299 Train: 1.0000, Val:0.7060, Test: 0.6970, Time(s/epoch):0.0079
# Epoch: 040, Loss:0.0262 Train: 1.0000, Val:0.7040, Test: 0.6960, Time(s/epoch):0.0080
# Epoch: 041, Loss:0.0245 Train: 1.0000, Val:0.7040, Test: 0.6970, Time(s/epoch):0.0081
# Epoch: 042, Loss:0.0229 Train: 1.0000, Val:0.7100, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 043, Loss:0.0253 Train: 1.0000, Val:0.7020, Test: 0.6950, Time(s/epoch):0.0081
# Epoch: 044, Loss:0.0339 Train: 1.0000, Val:0.7100, Test: 0.7030, Time(s/epoch):0.0081
# Epoch: 045, Loss:0.0249 Train: 1.0000, Val:0.7160, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 046, Loss:0.0353 Train: 1.0000, Val:0.7160, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 047, Loss:0.0201 Train: 1.0000, Val:0.7180, Test: 0.7020, Time(s/epoch):0.0085
# Epoch: 048, Loss:0.0324 Train: 1.0000, Val:0.7240, Test: 0.6970, Time(s/epoch):0.0080
# Epoch: 049, Loss:0.0320 Train: 1.0000, Val:0.7220, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 050, Loss:0.0257 Train: 1.0000, Val:0.7100, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 051, Loss:0.0267 Train: 1.0000, Val:0.7040, Test: 0.7150, Time(s/epoch):0.0081
# Epoch: 052, Loss:0.0285 Train: 1.0000, Val:0.7000, Test: 0.7230, Time(s/epoch):0.0080
# Epoch: 053, Loss:0.0264 Train: 1.0000, Val:0.7040, Test: 0.7250, Time(s/epoch):0.0080
# Epoch: 054, Loss:0.0283 Train: 1.0000, Val:0.7100, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 055, Loss:0.0264 Train: 1.0000, Val:0.7120, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 056, Loss:0.0209 Train: 1.0000, Val:0.7140, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 057, Loss:0.0171 Train: 1.0000, Val:0.7180, Test: 0.7030, Time(s/epoch):0.0079
# Epoch: 058, Loss:0.0221 Train: 1.0000, Val:0.7140, Test: 0.7050, Time(s/epoch):0.0080
# Epoch: 059, Loss:0.0266 Train: 1.0000, Val:0.7260, Test: 0.7100, Time(s/epoch):0.0083
# Epoch: 060, Loss:0.0221 Train: 1.0000, Val:0.7320, Test: 0.7150, Time(s/epoch):0.0082
# Epoch: 061, Loss:0.0265 Train: 1.0000, Val:0.7440, Test: 0.7190, Time(s/epoch):0.0079
# Epoch: 062, Loss:0.0279 Train: 1.0000, Val:0.7360, Test: 0.7100, Time(s/epoch):0.0080
# Epoch: 063, Loss:0.0333 Train: 1.0000, Val:0.7320, Test: 0.7100, Time(s/epoch):0.0079
# Epoch: 064, Loss:0.0304 Train: 1.0000, Val:0.7140, Test: 0.7080, Time(s/epoch):0.0082
# Epoch: 065, Loss:0.0219 Train: 1.0000, Val:0.7020, Test: 0.7100, Time(s/epoch):0.0084
# Epoch: 066, Loss:0.0206 Train: 1.0000, Val:0.7080, Test: 0.7130, Time(s/epoch):0.0082
# Epoch: 067, Loss:0.0268 Train: 1.0000, Val:0.7160, Test: 0.7220, Time(s/epoch):0.0081
# Epoch: 068, Loss:0.0244 Train: 1.0000, Val:0.7100, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 069, Loss:0.0202 Train: 1.0000, Val:0.7100, Test: 0.7160, Time(s/epoch):0.0082
# Epoch: 070, Loss:0.0251 Train: 1.0000, Val:0.7060, Test: 0.7130, Time(s/epoch):0.0078
# Epoch: 071, Loss:0.0314 Train: 1.0000, Val:0.7040, Test: 0.7080, Time(s/epoch):0.0084
# Epoch: 072, Loss:0.0210 Train: 1.0000, Val:0.7120, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 073, Loss:0.0222 Train: 1.0000, Val:0.7100, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 074, Loss:0.0321 Train: 1.0000, Val:0.7080, Test: 0.7140, Time(s/epoch):0.0079
# Epoch: 075, Loss:0.0190 Train: 1.0000, Val:0.7120, Test: 0.7250, Time(s/epoch):0.0081
# Epoch: 076, Loss:0.0290 Train: 1.0000, Val:0.7140, Test: 0.7290, Time(s/epoch):0.0079
# Epoch: 077, Loss:0.0245 Train: 1.0000, Val:0.7220, Test: 0.7230, Time(s/epoch):0.0081
# Epoch: 078, Loss:0.0229 Train: 1.0000, Val:0.7340, Test: 0.7250, Time(s/epoch):0.0081
# Epoch: 079, Loss:0.0245 Train: 1.0000, Val:0.7180, Test: 0.7170, Time(s/epoch):0.0104
# Epoch: 080, Loss:0.0246 Train: 1.0000, Val:0.7140, Test: 0.7120, Time(s/epoch):0.0086
# Epoch: 081, Loss:0.0236 Train: 1.0000, Val:0.7080, Test: 0.6960, Time(s/epoch):0.0080
# Epoch: 082, Loss:0.0246 Train: 1.0000, Val:0.7200, Test: 0.6980, Time(s/epoch):0.0080
# Epoch: 083, Loss:0.0251 Train: 1.0000, Val:0.7220, Test: 0.7010, Time(s/epoch):0.0081
# Epoch: 084, Loss:0.0212 Train: 1.0000, Val:0.7160, Test: 0.7010, Time(s/epoch):0.0079
# Epoch: 085, Loss:0.0272 Train: 1.0000, Val:0.7140, Test: 0.6990, Time(s/epoch):0.0083
# Epoch: 086, Loss:0.0272 Train: 1.0000, Val:0.7140, Test: 0.7020, Time(s/epoch):0.0079
# Epoch: 087, Loss:0.0208 Train: 1.0000, Val:0.7120, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 088, Loss:0.0230 Train: 1.0000, Val:0.7020, Test: 0.7120, Time(s/epoch):0.0083
# Epoch: 089, Loss:0.0191 Train: 1.0000, Val:0.7060, Test: 0.7150, Time(s/epoch):0.0079
# Epoch: 090, Loss:0.0233 Train: 1.0000, Val:0.7180, Test: 0.7220, Time(s/epoch):0.0080
# Epoch: 091, Loss:0.0267 Train: 1.0000, Val:0.7240, Test: 0.7190, Time(s/epoch):0.0084
# Epoch: 092, Loss:0.0228 Train: 1.0000, Val:0.7220, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 093, Loss:0.0266 Train: 1.0000, Val:0.7160, Test: 0.7090, Time(s/epoch):0.0081
# Epoch: 094, Loss:0.0232 Train: 1.0000, Val:0.7140, Test: 0.7070, Time(s/epoch):0.0079
# Epoch: 095, Loss:0.0204 Train: 1.0000, Val:0.7100, Test: 0.7130, Time(s/epoch):0.0080
# Epoch: 096, Loss:0.0275 Train: 1.0000, Val:0.7160, Test: 0.7110, Time(s/epoch):0.0081
# Epoch: 097, Loss:0.0233 Train: 1.0000, Val:0.7080, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 098, Loss:0.0243 Train: 1.0000, Val:0.7060, Test: 0.6980, Time(s/epoch):0.0080
# Epoch: 099, Loss:0.0310 Train: 1.0000, Val:0.7080, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 100, Loss:0.0290 Train: 1.0000, Val:0.7040, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 101, Loss:0.0236 Train: 1.0000, Val:0.7180, Test: 0.7160, Time(s/epoch):0.0079
# Epoch: 102, Loss:0.0301 Train: 1.0000, Val:0.7180, Test: 0.7020, Time(s/epoch):0.0078
# Epoch: 103, Loss:0.0245 Train: 1.0000, Val:0.7120, Test: 0.7020, Time(s/epoch):0.0080
# Epoch: 104, Loss:0.0238 Train: 1.0000, Val:0.6940, Test: 0.6920, Time(s/epoch):0.0079
# Epoch: 105, Loss:0.0240 Train: 1.0000, Val:0.6900, Test: 0.6990, Time(s/epoch):0.0087
# Epoch: 106, Loss:0.0299 Train: 1.0000, Val:0.7140, Test: 0.6980, Time(s/epoch):0.0082
# Epoch: 107, Loss:0.0293 Train: 1.0000, Val:0.7080, Test: 0.6970, Time(s/epoch):0.0080
# Epoch: 108, Loss:0.0219 Train: 1.0000, Val:0.7040, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 109, Loss:0.0290 Train: 1.0000, Val:0.7120, Test: 0.7120, Time(s/epoch):0.0080
# Epoch: 110, Loss:0.0241 Train: 1.0000, Val:0.7180, Test: 0.7210, Time(s/epoch):0.0084
# Epoch: 111, Loss:0.0264 Train: 1.0000, Val:0.7080, Test: 0.7340, Time(s/epoch):0.0079
# Epoch: 112, Loss:0.0266 Train: 1.0000, Val:0.7260, Test: 0.7250, Time(s/epoch):0.0079
# Epoch: 113, Loss:0.0240 Train: 1.0000, Val:0.7300, Test: 0.7200, Time(s/epoch):0.0079
# Epoch: 114, Loss:0.0164 Train: 1.0000, Val:0.7140, Test: 0.7130, Time(s/epoch):0.0080
# Epoch: 115, Loss:0.0249 Train: 1.0000, Val:0.7140, Test: 0.7080, Time(s/epoch):0.0085
# Epoch: 116, Loss:0.0197 Train: 1.0000, Val:0.7120, Test: 0.6950, Time(s/epoch):0.0081
# Epoch: 117, Loss:0.0302 Train: 1.0000, Val:0.7100, Test: 0.6930, Time(s/epoch):0.0080
# Epoch: 118, Loss:0.0248 Train: 1.0000, Val:0.7120, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 119, Loss:0.0234 Train: 1.0000, Val:0.7140, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 120, Loss:0.0175 Train: 1.0000, Val:0.7220, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 121, Loss:0.0262 Train: 1.0000, Val:0.7280, Test: 0.7140, Time(s/epoch):0.0080
# Epoch: 122, Loss:0.0284 Train: 1.0000, Val:0.6980, Test: 0.7150, Time(s/epoch):0.0080
# Epoch: 123, Loss:0.0255 Train: 1.0000, Val:0.6920, Test: 0.7090, Time(s/epoch):0.0079
# Epoch: 124, Loss:0.0246 Train: 1.0000, Val:0.6880, Test: 0.7050, Time(s/epoch):0.0078
# Epoch: 125, Loss:0.0354 Train: 1.0000, Val:0.6960, Test: 0.6920, Time(s/epoch):0.0082
# Epoch: 126, Loss:0.0187 Train: 1.0000, Val:0.6940, Test: 0.6620, Time(s/epoch):0.0081
# Epoch: 127, Loss:0.0272 Train: 1.0000, Val:0.7080, Test: 0.6800, Time(s/epoch):0.0081
# Epoch: 128, Loss:0.0279 Train: 1.0000, Val:0.7400, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 129, Loss:0.0237 Train: 1.0000, Val:0.7360, Test: 0.7140, Time(s/epoch):0.0080
# Epoch: 130, Loss:0.0246 Train: 1.0000, Val:0.7060, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 131, Loss:0.0363 Train: 1.0000, Val:0.7060, Test: 0.7200, Time(s/epoch):0.0080
# Epoch: 132, Loss:0.0235 Train: 1.0000, Val:0.7140, Test: 0.7110, Time(s/epoch):0.0085
# Epoch: 133, Loss:0.0252 Train: 1.0000, Val:0.7240, Test: 0.7020, Time(s/epoch):0.0080
# Epoch: 134, Loss:0.0248 Train: 1.0000, Val:0.7180, Test: 0.6890, Time(s/epoch):0.0081
# Epoch: 135, Loss:0.0341 Train: 1.0000, Val:0.7240, Test: 0.6870, Time(s/epoch):0.0079
# Epoch: 136, Loss:0.0177 Train: 1.0000, Val:0.7120, Test: 0.6940, Time(s/epoch):0.0080
# Epoch: 137, Loss:0.0436 Train: 1.0000, Val:0.7180, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 138, Loss:0.0234 Train: 1.0000, Val:0.7220, Test: 0.7190, Time(s/epoch):0.0078
# Epoch: 139, Loss:0.0219 Train: 1.0000, Val:0.7180, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 140, Loss:0.0255 Train: 1.0000, Val:0.7120, Test: 0.7140, Time(s/epoch):0.0081
# Epoch: 141, Loss:0.0237 Train: 1.0000, Val:0.6960, Test: 0.7120, Time(s/epoch):0.0083
# Epoch: 142, Loss:0.0237 Train: 1.0000, Val:0.7020, Test: 0.7170, Time(s/epoch):0.0081
# Epoch: 143, Loss:0.0263 Train: 1.0000, Val:0.7140, Test: 0.7230, Time(s/epoch):0.0080
# Epoch: 144, Loss:0.0190 Train: 1.0000, Val:0.7220, Test: 0.7100, Time(s/epoch):0.0084
# Epoch: 145, Loss:0.0249 Train: 1.0000, Val:0.7200, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 146, Loss:0.0292 Train: 1.0000, Val:0.7100, Test: 0.7020, Time(s/epoch):0.0080
# Epoch: 147, Loss:0.0276 Train: 1.0000, Val:0.7040, Test: 0.7000, Time(s/epoch):0.0080
# Epoch: 148, Loss:0.0228 Train: 1.0000, Val:0.7060, Test: 0.7100, Time(s/epoch):0.0080
# Epoch: 149, Loss:0.0396 Train: 1.0000, Val:0.7080, Test: 0.7230, Time(s/epoch):0.0080
# Epoch: 150, Loss:0.0217 Train: 1.0000, Val:0.7220, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 151, Loss:0.0320 Train: 1.0000, Val:0.7220, Test: 0.7050, Time(s/epoch):0.0078
# Epoch: 152, Loss:0.0219 Train: 1.0000, Val:0.7180, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 153, Loss:0.0286 Train: 1.0000, Val:0.7060, Test: 0.6960, Time(s/epoch):0.0080
# Epoch: 154, Loss:0.0253 Train: 1.0000, Val:0.7060, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 155, Loss:0.0350 Train: 1.0000, Val:0.7060, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 156, Loss:0.0231 Train: 1.0000, Val:0.7040, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 157, Loss:0.0351 Train: 1.0000, Val:0.7020, Test: 0.7100, Time(s/epoch):0.0081
# Epoch: 158, Loss:0.0292 Train: 1.0000, Val:0.6980, Test: 0.6970, Time(s/epoch):0.0081
# Epoch: 159, Loss:0.0408 Train: 1.0000, Val:0.6960, Test: 0.6860, Time(s/epoch):0.0083
# Epoch: 160, Loss:0.0310 Train: 1.0000, Val:0.7000, Test: 0.6870, Time(s/epoch):0.0080
# Epoch: 161, Loss:0.0387 Train: 1.0000, Val:0.7180, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 162, Loss:0.0288 Train: 1.0000, Val:0.7300, Test: 0.7230, Time(s/epoch):0.0081
# Epoch: 163, Loss:0.0236 Train: 1.0000, Val:0.7100, Test: 0.7210, Time(s/epoch):0.0080
# Epoch: 164, Loss:0.0271 Train: 1.0000, Val:0.7320, Test: 0.7160, Time(s/epoch):0.0082
# Epoch: 165, Loss:0.0169 Train: 1.0000, Val:0.7160, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 166, Loss:0.0246 Train: 1.0000, Val:0.6860, Test: 0.6880, Time(s/epoch):0.0082
# Epoch: 167, Loss:0.0239 Train: 1.0000, Val:0.6720, Test: 0.6740, Time(s/epoch):0.0082
# Epoch: 168, Loss:0.0349 Train: 1.0000, Val:0.6920, Test: 0.6820, Time(s/epoch):0.0080
# Epoch: 169, Loss:0.0238 Train: 1.0000, Val:0.7100, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 170, Loss:0.0270 Train: 1.0000, Val:0.7040, Test: 0.7060, Time(s/epoch):0.0079
# Epoch: 171, Loss:0.0329 Train: 1.0000, Val:0.7060, Test: 0.7140, Time(s/epoch):0.0082
# Epoch: 172, Loss:0.0263 Train: 1.0000, Val:0.7020, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 173, Loss:0.0216 Train: 1.0000, Val:0.6920, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 174, Loss:0.0227 Train: 1.0000, Val:0.6940, Test: 0.6880, Time(s/epoch):0.0081
# Epoch: 175, Loss:0.0302 Train: 1.0000, Val:0.6940, Test: 0.6840, Time(s/epoch):0.0081
# Epoch: 176, Loss:0.0296 Train: 1.0000, Val:0.7000, Test: 0.6940, Time(s/epoch):0.0081
# Epoch: 177, Loss:0.0275 Train: 1.0000, Val:0.7180, Test: 0.7160, Time(s/epoch):0.0081
# Epoch: 178, Loss:0.0191 Train: 1.0000, Val:0.7120, Test: 0.7120, Time(s/epoch):0.0082
# Epoch: 179, Loss:0.0238 Train: 1.0000, Val:0.7100, Test: 0.7140, Time(s/epoch):0.0081
# Epoch: 180, Loss:0.0350 Train: 1.0000, Val:0.7120, Test: 0.7180, Time(s/epoch):0.0080
# Epoch: 181, Loss:0.0285 Train: 1.0000, Val:0.7120, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 182, Loss:0.0263 Train: 1.0000, Val:0.7040, Test: 0.6860, Time(s/epoch):0.0080
# Epoch: 183, Loss:0.0279 Train: 1.0000, Val:0.7040, Test: 0.6840, Time(s/epoch):0.0081
# Epoch: 184, Loss:0.0194 Train: 1.0000, Val:0.7060, Test: 0.6870, Time(s/epoch):0.0081
# Epoch: 185, Loss:0.0259 Train: 1.0000, Val:0.7060, Test: 0.6880, Time(s/epoch):0.0081
# Epoch: 186, Loss:0.0221 Train: 1.0000, Val:0.7120, Test: 0.7030, Time(s/epoch):0.0083
# Epoch: 187, Loss:0.0229 Train: 1.0000, Val:0.7120, Test: 0.7020, Time(s/epoch):0.0080
# Epoch: 188, Loss:0.0302 Train: 1.0000, Val:0.7200, Test: 0.7020, Time(s/epoch):0.0080
# Epoch: 189, Loss:0.0186 Train: 1.0000, Val:0.7140, Test: 0.6930, Time(s/epoch):0.0146
# Epoch: 190, Loss:0.0437 Train: 1.0000, Val:0.7080, Test: 0.7060, Time(s/epoch):0.0137
# Epoch: 191, Loss:0.0221 Train: 1.0000, Val:0.6840, Test: 0.7190, Time(s/epoch):0.0087
# Epoch: 192, Loss:0.0345 Train: 1.0000, Val:0.7120, Test: 0.7200, Time(s/epoch):0.0082
# Epoch: 193, Loss:0.0265 Train: 1.0000, Val:0.7060, Test: 0.7080, Time(s/epoch):0.0079
# Epoch: 194, Loss:0.0296 Train: 1.0000, Val:0.6900, Test: 0.6850, Time(s/epoch):0.0083
# Epoch: 195, Loss:0.0378 Train: 1.0000, Val:0.7040, Test: 0.6950, Time(s/epoch):0.0081
# Epoch: 196, Loss:0.0203 Train: 1.0000, Val:0.7000, Test: 0.6910, Time(s/epoch):0.0080
# Epoch: 197, Loss:0.0190 Train: 1.0000, Val:0.6880, Test: 0.6880, Time(s/epoch):0.0081
# Epoch: 198, Loss:0.0202 Train: 1.0000, Val:0.6900, Test: 0.6850, Time(s/epoch):0.0081
# Epoch: 199, Loss:0.0299 Train: 1.0000, Val:0.7080, Test: 0.6880, Time(s/epoch):0.0081
# Epoch: 200, Loss:0.0253 Train: 1.0000, Val:0.7040, Test: 0.7000, Time(s/epoch):0.0081
# [Run-2 score] {'train': 1.0, 'val': 0.744, 'test': 0.719, 'loss': 0.02653409168124199}
# repeat 3/3
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# GraphSAGE(
#   (convs): ModuleList(
#     (0): SAGEConv(3703, 64)
#     (1): SAGEConv(64, 6)
#   )
# )
# auto fixed data split seed to 0, model init seed to 2
# Data(x=[3327, 3703], edge_index=[2, 14143], y=[3327], train_mask=[3327], val_mask=[3327], test_mask=[3327])
# [Dataset-CiteSeer()] train_num:120, val_num:500, test_num:1000, class_num:6
# Epoch: 001, Loss:1.7920 Train: 0.9750, Val:0.5860, Test: 0.5910, Time(s/epoch):0.0095
# Epoch: 002, Loss:1.3902 Train: 0.9917, Val:0.6800, Test: 0.6700, Time(s/epoch):0.0081
# Epoch: 003, Loss:0.8237 Train: 1.0000, Val:0.7040, Test: 0.6840, Time(s/epoch):0.0081
# Epoch: 004, Loss:0.4027 Train: 1.0000, Val:0.6960, Test: 0.6810, Time(s/epoch):0.0080
# Epoch: 005, Loss:0.1616 Train: 1.0000, Val:0.6740, Test: 0.6650, Time(s/epoch):0.0081
# Epoch: 006, Loss:0.0785 Train: 1.0000, Val:0.6800, Test: 0.6710, Time(s/epoch):0.0081
# Epoch: 007, Loss:0.0367 Train: 1.0000, Val:0.6820, Test: 0.6650, Time(s/epoch):0.0080
# Epoch: 008, Loss:0.0240 Train: 1.0000, Val:0.6820, Test: 0.6620, Time(s/epoch):0.0081
# Epoch: 009, Loss:0.0108 Train: 1.0000, Val:0.6820, Test: 0.6610, Time(s/epoch):0.0081
# Epoch: 010, Loss:0.0080 Train: 1.0000, Val:0.6820, Test: 0.6640, Time(s/epoch):0.0081
# Epoch: 011, Loss:0.0154 Train: 1.0000, Val:0.6800, Test: 0.6630, Time(s/epoch):0.0081
# Epoch: 012, Loss:0.0183 Train: 1.0000, Val:0.6840, Test: 0.6820, Time(s/epoch):0.0085
# Epoch: 013, Loss:0.0214 Train: 1.0000, Val:0.7120, Test: 0.6920, Time(s/epoch):0.0082
# Epoch: 014, Loss:0.0081 Train: 1.0000, Val:0.7140, Test: 0.7030, Time(s/epoch):0.0081
# Epoch: 015, Loss:0.0158 Train: 1.0000, Val:0.7180, Test: 0.7050, Time(s/epoch):0.0080
# Epoch: 016, Loss:0.0183 Train: 1.0000, Val:0.7220, Test: 0.7060, Time(s/epoch):0.0081
# Epoch: 017, Loss:0.0289 Train: 1.0000, Val:0.7180, Test: 0.7050, Time(s/epoch):0.0080
# Epoch: 018, Loss:0.0163 Train: 1.0000, Val:0.7180, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 019, Loss:0.0331 Train: 1.0000, Val:0.7060, Test: 0.7040, Time(s/epoch):0.0080
# Epoch: 020, Loss:0.0343 Train: 1.0000, Val:0.6980, Test: 0.7020, Time(s/epoch):0.0080
# Epoch: 021, Loss:0.0438 Train: 1.0000, Val:0.7080, Test: 0.7020, Time(s/epoch):0.0081
# Epoch: 022, Loss:0.0399 Train: 1.0000, Val:0.7100, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 023, Loss:0.0527 Train: 1.0000, Val:0.7080, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 024, Loss:0.0249 Train: 1.0000, Val:0.7100, Test: 0.7050, Time(s/epoch):0.0080
# Epoch: 025, Loss:0.0299 Train: 1.0000, Val:0.7060, Test: 0.7010, Time(s/epoch):0.0084
# Epoch: 026, Loss:0.0346 Train: 1.0000, Val:0.7120, Test: 0.6990, Time(s/epoch):0.0079
# Epoch: 027, Loss:0.0483 Train: 1.0000, Val:0.7100, Test: 0.6960, Time(s/epoch):0.0081
# Epoch: 028, Loss:0.0403 Train: 1.0000, Val:0.7020, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 029, Loss:0.0378 Train: 1.0000, Val:0.7100, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 030, Loss:0.0376 Train: 1.0000, Val:0.7160, Test: 0.6940, Time(s/epoch):0.0081
# Epoch: 031, Loss:0.0422 Train: 1.0000, Val:0.7060, Test: 0.6950, Time(s/epoch):0.0081
# Epoch: 032, Loss:0.0353 Train: 1.0000, Val:0.7040, Test: 0.6890, Time(s/epoch):0.0081
# Epoch: 033, Loss:0.0358 Train: 1.0000, Val:0.7120, Test: 0.6940, Time(s/epoch):0.0081
# Epoch: 034, Loss:0.0351 Train: 1.0000, Val:0.7060, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 035, Loss:0.0306 Train: 1.0000, Val:0.6980, Test: 0.7020, Time(s/epoch):0.0082
# Epoch: 036, Loss:0.0272 Train: 1.0000, Val:0.7100, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 037, Loss:0.0311 Train: 1.0000, Val:0.7000, Test: 0.7060, Time(s/epoch):0.0083
# Epoch: 038, Loss:0.0268 Train: 1.0000, Val:0.6960, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 039, Loss:0.0230 Train: 1.0000, Val:0.7040, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 040, Loss:0.0238 Train: 1.0000, Val:0.7040, Test: 0.7080, Time(s/epoch):0.0083
# Epoch: 041, Loss:0.0298 Train: 1.0000, Val:0.6980, Test: 0.7020, Time(s/epoch):0.0081
# Epoch: 042, Loss:0.0248 Train: 1.0000, Val:0.6920, Test: 0.6950, Time(s/epoch):0.0082
# Epoch: 043, Loss:0.0304 Train: 1.0000, Val:0.6980, Test: 0.6950, Time(s/epoch):0.0080
# Epoch: 044, Loss:0.0252 Train: 1.0000, Val:0.7060, Test: 0.6900, Time(s/epoch):0.0079
# Epoch: 045, Loss:0.0360 Train: 1.0000, Val:0.7160, Test: 0.6880, Time(s/epoch):0.0080
# Epoch: 046, Loss:0.0219 Train: 1.0000, Val:0.7120, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 047, Loss:0.0372 Train: 1.0000, Val:0.7160, Test: 0.6900, Time(s/epoch):0.0080
# Epoch: 048, Loss:0.0255 Train: 1.0000, Val:0.7120, Test: 0.6940, Time(s/epoch):0.0082
# Epoch: 049, Loss:0.0270 Train: 1.0000, Val:0.7060, Test: 0.6950, Time(s/epoch):0.0080
# Epoch: 050, Loss:0.0274 Train: 1.0000, Val:0.7040, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 051, Loss:0.0217 Train: 1.0000, Val:0.6960, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 052, Loss:0.0201 Train: 1.0000, Val:0.6960, Test: 0.7070, Time(s/epoch):0.0082
# Epoch: 053, Loss:0.0237 Train: 1.0000, Val:0.6940, Test: 0.7100, Time(s/epoch):0.0081
# Epoch: 054, Loss:0.0259 Train: 1.0000, Val:0.7020, Test: 0.7120, Time(s/epoch):0.0080
# Epoch: 055, Loss:0.0278 Train: 1.0000, Val:0.7220, Test: 0.7130, Time(s/epoch):0.0080
# Epoch: 056, Loss:0.0253 Train: 1.0000, Val:0.7320, Test: 0.7180, Time(s/epoch):0.0080
# Epoch: 057, Loss:0.0385 Train: 1.0000, Val:0.7240, Test: 0.7170, Time(s/epoch):0.0082
# Epoch: 058, Loss:0.0202 Train: 1.0000, Val:0.7200, Test: 0.7010, Time(s/epoch):0.0081
# Epoch: 059, Loss:0.0278 Train: 1.0000, Val:0.7020, Test: 0.7010, Time(s/epoch):0.0080
# Epoch: 060, Loss:0.0262 Train: 1.0000, Val:0.6860, Test: 0.6930, Time(s/epoch):0.0080
# Epoch: 061, Loss:0.0323 Train: 1.0000, Val:0.6860, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 062, Loss:0.0319 Train: 1.0000, Val:0.7060, Test: 0.6990, Time(s/epoch):0.0083
# Epoch: 063, Loss:0.0263 Train: 1.0000, Val:0.7100, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 064, Loss:0.0241 Train: 1.0000, Val:0.7160, Test: 0.7010, Time(s/epoch):0.0086
# Epoch: 065, Loss:0.0279 Train: 1.0000, Val:0.7180, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 066, Loss:0.0222 Train: 1.0000, Val:0.7160, Test: 0.7000, Time(s/epoch):0.0080
# Epoch: 067, Loss:0.0261 Train: 1.0000, Val:0.7200, Test: 0.7100, Time(s/epoch):0.0081
# Epoch: 068, Loss:0.0216 Train: 1.0000, Val:0.7040, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 069, Loss:0.0260 Train: 1.0000, Val:0.6940, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 070, Loss:0.0289 Train: 1.0000, Val:0.6980, Test: 0.7080, Time(s/epoch):0.0079
# Epoch: 071, Loss:0.0300 Train: 1.0000, Val:0.7060, Test: 0.7120, Time(s/epoch):0.0079
# Epoch: 072, Loss:0.0325 Train: 1.0000, Val:0.7120, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 073, Loss:0.0215 Train: 1.0000, Val:0.7140, Test: 0.6920, Time(s/epoch):0.0080
# Epoch: 074, Loss:0.0219 Train: 1.0000, Val:0.7140, Test: 0.6950, Time(s/epoch):0.0082
# Epoch: 075, Loss:0.0273 Train: 1.0000, Val:0.7220, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 076, Loss:0.0260 Train: 1.0000, Val:0.7200, Test: 0.7150, Time(s/epoch):0.0080
# Epoch: 077, Loss:0.0185 Train: 1.0000, Val:0.7160, Test: 0.7180, Time(s/epoch):0.0081
# Epoch: 078, Loss:0.0229 Train: 1.0000, Val:0.6980, Test: 0.7170, Time(s/epoch):0.0081
# Epoch: 079, Loss:0.0279 Train: 1.0000, Val:0.6980, Test: 0.7100, Time(s/epoch):0.0082
# Epoch: 080, Loss:0.0195 Train: 1.0000, Val:0.7060, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 081, Loss:0.0256 Train: 1.0000, Val:0.7080, Test: 0.7140, Time(s/epoch):0.0080
# Epoch: 082, Loss:0.0250 Train: 1.0000, Val:0.7060, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 083, Loss:0.0213 Train: 1.0000, Val:0.7080, Test: 0.6960, Time(s/epoch):0.0082
# Epoch: 084, Loss:0.0299 Train: 1.0000, Val:0.7120, Test: 0.6980, Time(s/epoch):0.0080
# Epoch: 085, Loss:0.0265 Train: 1.0000, Val:0.7080, Test: 0.7030, Time(s/epoch):0.0081
# Epoch: 086, Loss:0.0240 Train: 1.0000, Val:0.7120, Test: 0.6990, Time(s/epoch):0.0081
# Epoch: 087, Loss:0.0234 Train: 1.0000, Val:0.7140, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 088, Loss:0.0221 Train: 1.0000, Val:0.7120, Test: 0.7090, Time(s/epoch):0.0081
# Epoch: 089, Loss:0.0253 Train: 1.0000, Val:0.7200, Test: 0.7110, Time(s/epoch):0.0086
# Epoch: 090, Loss:0.0239 Train: 1.0000, Val:0.7140, Test: 0.7010, Time(s/epoch):0.0079
# Epoch: 091, Loss:0.0220 Train: 1.0000, Val:0.7100, Test: 0.6930, Time(s/epoch):0.0081
# Epoch: 092, Loss:0.0227 Train: 1.0000, Val:0.7180, Test: 0.7030, Time(s/epoch):0.0081
# Epoch: 093, Loss:0.0218 Train: 1.0000, Val:0.7080, Test: 0.7120, Time(s/epoch):0.0079
# Epoch: 094, Loss:0.0232 Train: 1.0000, Val:0.7040, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 095, Loss:0.0241 Train: 1.0000, Val:0.7120, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 096, Loss:0.0290 Train: 1.0000, Val:0.7140, Test: 0.7160, Time(s/epoch):0.0080
# Epoch: 097, Loss:0.0179 Train: 1.0000, Val:0.7140, Test: 0.7160, Time(s/epoch):0.0080
# Epoch: 098, Loss:0.0344 Train: 1.0000, Val:0.7280, Test: 0.7150, Time(s/epoch):0.0081
# Epoch: 099, Loss:0.0226 Train: 1.0000, Val:0.7120, Test: 0.7100, Time(s/epoch):0.0080
# Epoch: 100, Loss:0.0268 Train: 1.0000, Val:0.7060, Test: 0.7110, Time(s/epoch):0.0082
# Epoch: 101, Loss:0.0283 Train: 1.0000, Val:0.6960, Test: 0.7130, Time(s/epoch):0.0082
# Epoch: 102, Loss:0.0293 Train: 1.0000, Val:0.6960, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 103, Loss:0.0259 Train: 1.0000, Val:0.7020, Test: 0.7170, Time(s/epoch):0.0080
# Epoch: 104, Loss:0.0255 Train: 1.0000, Val:0.7140, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 105, Loss:0.0160 Train: 1.0000, Val:0.7240, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 106, Loss:0.0189 Train: 1.0000, Val:0.7300, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 107, Loss:0.0282 Train: 1.0000, Val:0.7260, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 108, Loss:0.0296 Train: 1.0000, Val:0.7160, Test: 0.7140, Time(s/epoch):0.0080
# Epoch: 109, Loss:0.0191 Train: 1.0000, Val:0.6980, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 110, Loss:0.0205 Train: 1.0000, Val:0.6960, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 111, Loss:0.0274 Train: 1.0000, Val:0.7000, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 112, Loss:0.0265 Train: 1.0000, Val:0.7140, Test: 0.7140, Time(s/epoch):0.0081
# Epoch: 113, Loss:0.0246 Train: 1.0000, Val:0.7180, Test: 0.7100, Time(s/epoch):0.0083
# Epoch: 114, Loss:0.0243 Train: 1.0000, Val:0.7300, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 115, Loss:0.0290 Train: 1.0000, Val:0.7180, Test: 0.7010, Time(s/epoch):0.0081
# Epoch: 116, Loss:0.0259 Train: 1.0000, Val:0.7040, Test: 0.6960, Time(s/epoch):0.0080
# Epoch: 117, Loss:0.0262 Train: 1.0000, Val:0.7100, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 118, Loss:0.0208 Train: 1.0000, Val:0.7160, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 119, Loss:0.0232 Train: 1.0000, Val:0.7040, Test: 0.7160, Time(s/epoch):0.0080
# Epoch: 120, Loss:0.0168 Train: 1.0000, Val:0.7100, Test: 0.7220, Time(s/epoch):0.0080
# Epoch: 121, Loss:0.0293 Train: 1.0000, Val:0.7000, Test: 0.7160, Time(s/epoch):0.0081
# Epoch: 122, Loss:0.0190 Train: 1.0000, Val:0.7060, Test: 0.7050, Time(s/epoch):0.0080
# Epoch: 123, Loss:0.0232 Train: 1.0000, Val:0.7100, Test: 0.7000, Time(s/epoch):0.0093
# Epoch: 124, Loss:0.0277 Train: 1.0000, Val:0.7040, Test: 0.6880, Time(s/epoch):0.0081
# Epoch: 125, Loss:0.0215 Train: 1.0000, Val:0.7060, Test: 0.6970, Time(s/epoch):0.0081
# Epoch: 126, Loss:0.0336 Train: 1.0000, Val:0.7180, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 127, Loss:0.0305 Train: 1.0000, Val:0.7060, Test: 0.7130, Time(s/epoch):0.0079
# Epoch: 128, Loss:0.0246 Train: 1.0000, Val:0.6940, Test: 0.7210, Time(s/epoch):0.0081
# Epoch: 129, Loss:0.0223 Train: 1.0000, Val:0.6940, Test: 0.7190, Time(s/epoch):0.0081
# Epoch: 130, Loss:0.0278 Train: 1.0000, Val:0.7040, Test: 0.7230, Time(s/epoch):0.0081
# Epoch: 131, Loss:0.0307 Train: 1.0000, Val:0.7100, Test: 0.7060, Time(s/epoch):0.0081
# Epoch: 132, Loss:0.0250 Train: 1.0000, Val:0.7020, Test: 0.6760, Time(s/epoch):0.0081
# Epoch: 133, Loss:0.0367 Train: 1.0000, Val:0.7160, Test: 0.6880, Time(s/epoch):0.0082
# Epoch: 134, Loss:0.0247 Train: 1.0000, Val:0.7160, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 135, Loss:0.0193 Train: 1.0000, Val:0.7100, Test: 0.7220, Time(s/epoch):0.0080
# Epoch: 136, Loss:0.0227 Train: 1.0000, Val:0.7060, Test: 0.7230, Time(s/epoch):0.0080
# Epoch: 137, Loss:0.0281 Train: 1.0000, Val:0.6980, Test: 0.7220, Time(s/epoch):0.0084
# Epoch: 138, Loss:0.0206 Train: 1.0000, Val:0.7040, Test: 0.7220, Time(s/epoch):0.0082
# Epoch: 139, Loss:0.0227 Train: 1.0000, Val:0.7020, Test: 0.7130, Time(s/epoch):0.0079
# Epoch: 140, Loss:0.0190 Train: 1.0000, Val:0.7040, Test: 0.7110, Time(s/epoch):0.0080
# Epoch: 141, Loss:0.0196 Train: 1.0000, Val:0.7140, Test: 0.7090, Time(s/epoch):0.0080
# Epoch: 142, Loss:0.0438 Train: 1.0000, Val:0.7160, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 143, Loss:0.0353 Train: 1.0000, Val:0.7060, Test: 0.7190, Time(s/epoch):0.0081
# Epoch: 144, Loss:0.0279 Train: 1.0000, Val:0.7020, Test: 0.7100, Time(s/epoch):0.0081
# Epoch: 145, Loss:0.0312 Train: 1.0000, Val:0.6940, Test: 0.7030, Time(s/epoch):0.0082
# Epoch: 146, Loss:0.0316 Train: 1.0000, Val:0.6940, Test: 0.6910, Time(s/epoch):0.0080
# Epoch: 147, Loss:0.0313 Train: 1.0000, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0080
# Epoch: 148, Loss:0.0220 Train: 1.0000, Val:0.7040, Test: 0.6950, Time(s/epoch):0.0083
# Epoch: 149, Loss:0.0255 Train: 1.0000, Val:0.7060, Test: 0.6940, Time(s/epoch):0.0079
# Epoch: 150, Loss:0.0434 Train: 1.0000, Val:0.6940, Test: 0.7080, Time(s/epoch):0.0082
# Epoch: 151, Loss:0.0280 Train: 1.0000, Val:0.6800, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 152, Loss:0.0247 Train: 1.0000, Val:0.6860, Test: 0.7130, Time(s/epoch):0.0080
# Epoch: 153, Loss:0.0496 Train: 1.0000, Val:0.6940, Test: 0.7010, Time(s/epoch):0.0087
# Epoch: 154, Loss:0.0281 Train: 1.0000, Val:0.7040, Test: 0.6940, Time(s/epoch):0.0081
# Epoch: 155, Loss:0.0209 Train: 1.0000, Val:0.6940, Test: 0.6670, Time(s/epoch):0.0080
# Epoch: 156, Loss:0.0246 Train: 1.0000, Val:0.6960, Test: 0.6590, Time(s/epoch):0.0081
# Epoch: 157, Loss:0.0272 Train: 1.0000, Val:0.7040, Test: 0.6690, Time(s/epoch):0.0080
# Epoch: 158, Loss:0.0239 Train: 1.0000, Val:0.7040, Test: 0.6970, Time(s/epoch):0.0080
# Epoch: 159, Loss:0.0192 Train: 1.0000, Val:0.6940, Test: 0.7030, Time(s/epoch):0.0080
# Epoch: 160, Loss:0.0474 Train: 1.0000, Val:0.6840, Test: 0.7120, Time(s/epoch):0.0080
# Epoch: 161, Loss:0.0379 Train: 1.0000, Val:0.6960, Test: 0.7080, Time(s/epoch):0.0081
# Epoch: 162, Loss:0.0416 Train: 1.0000, Val:0.6860, Test: 0.6850, Time(s/epoch):0.0084
# Epoch: 163, Loss:0.0274 Train: 1.0000, Val:0.7020, Test: 0.6760, Time(s/epoch):0.0081
# Epoch: 164, Loss:0.0275 Train: 1.0000, Val:0.7040, Test: 0.6740, Time(s/epoch):0.0081
# Epoch: 165, Loss:0.0239 Train: 1.0000, Val:0.7040, Test: 0.6810, Time(s/epoch):0.0080
# Epoch: 166, Loss:0.0321 Train: 1.0000, Val:0.7160, Test: 0.6960, Time(s/epoch):0.0081
# Epoch: 167, Loss:0.0375 Train: 1.0000, Val:0.6940, Test: 0.7060, Time(s/epoch):0.0080
# Epoch: 168, Loss:0.0345 Train: 1.0000, Val:0.6960, Test: 0.7010, Time(s/epoch):0.0083
# Epoch: 169, Loss:0.0224 Train: 1.0000, Val:0.6880, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 170, Loss:0.0236 Train: 1.0000, Val:0.6900, Test: 0.6900, Time(s/epoch):0.0082
# Epoch: 171, Loss:0.0288 Train: 1.0000, Val:0.7000, Test: 0.6880, Time(s/epoch):0.0081
# Epoch: 172, Loss:0.0251 Train: 1.0000, Val:0.7100, Test: 0.6900, Time(s/epoch):0.0083
# Epoch: 173, Loss:0.0279 Train: 1.0000, Val:0.7240, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 174, Loss:0.0245 Train: 1.0000, Val:0.7260, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 175, Loss:0.0309 Train: 1.0000, Val:0.7100, Test: 0.7120, Time(s/epoch):0.0081
# Epoch: 176, Loss:0.0233 Train: 1.0000, Val:0.7100, Test: 0.7130, Time(s/epoch):0.0081
# Epoch: 177, Loss:0.0304 Train: 1.0000, Val:0.7000, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 178, Loss:0.0283 Train: 1.0000, Val:0.7000, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 179, Loss:0.0222 Train: 1.0000, Val:0.7000, Test: 0.7000, Time(s/epoch):0.0081
# Epoch: 180, Loss:0.0204 Train: 1.0000, Val:0.7120, Test: 0.6980, Time(s/epoch):0.0081
# Epoch: 181, Loss:0.0254 Train: 1.0000, Val:0.7040, Test: 0.6920, Time(s/epoch):0.0081
# Epoch: 182, Loss:0.0221 Train: 1.0000, Val:0.7100, Test: 0.6900, Time(s/epoch):0.0080
# Epoch: 183, Loss:0.0250 Train: 1.0000, Val:0.7120, Test: 0.6910, Time(s/epoch):0.0080
# Epoch: 184, Loss:0.0195 Train: 1.0000, Val:0.7000, Test: 0.6870, Time(s/epoch):0.0081
# Epoch: 185, Loss:0.0218 Train: 1.0000, Val:0.7040, Test: 0.6980, Time(s/epoch):0.0080
# Epoch: 186, Loss:0.0320 Train: 1.0000, Val:0.7100, Test: 0.7120, Time(s/epoch):0.0080
# Epoch: 187, Loss:0.0263 Train: 1.0000, Val:0.7100, Test: 0.7120, Time(s/epoch):0.0085
# Epoch: 188, Loss:0.0210 Train: 1.0000, Val:0.7040, Test: 0.7070, Time(s/epoch):0.0080
# Epoch: 189, Loss:0.0273 Train: 1.0000, Val:0.6860, Test: 0.7030, Time(s/epoch):0.0081
# Epoch: 190, Loss:0.0239 Train: 1.0000, Val:0.6860, Test: 0.6990, Time(s/epoch):0.0080
# Epoch: 191, Loss:0.0308 Train: 1.0000, Val:0.6940, Test: 0.7050, Time(s/epoch):0.0081
# Epoch: 192, Loss:0.0257 Train: 1.0000, Val:0.6860, Test: 0.6930, Time(s/epoch):0.0081
# Epoch: 193, Loss:0.0289 Train: 1.0000, Val:0.6940, Test: 0.6960, Time(s/epoch):0.0081
# Epoch: 194, Loss:0.0358 Train: 1.0000, Val:0.7220, Test: 0.7020, Time(s/epoch):0.0081
# Epoch: 195, Loss:0.0184 Train: 1.0000, Val:0.7240, Test: 0.7070, Time(s/epoch):0.0081
# Epoch: 196, Loss:0.0256 Train: 1.0000, Val:0.7260, Test: 0.7160, Time(s/epoch):0.0080
# Epoch: 197, Loss:0.0204 Train: 1.0000, Val:0.7160, Test: 0.7110, Time(s/epoch):0.0082
# Epoch: 198, Loss:0.0222 Train: 1.0000, Val:0.7140, Test: 0.7080, Time(s/epoch):0.0080
# Epoch: 199, Loss:0.0334 Train: 1.0000, Val:0.6980, Test: 0.6940, Time(s/epoch):0.0080
# Epoch: 200, Loss:0.0231 Train: 1.0000, Val:0.6920, Test: 0.6880, Time(s/epoch):0.0080
# [Run-3 score] {'train': 1.0, 'val': 0.732, 'test': 0.718, 'loss': 0.02526204101741314}
# [Average Score] {'train': 1.0, 'val': 0.7353333333333333, 'test': 0.7133333333333333}
# [std Score] {'train': 0.0, 'val': 0.006182412330330475, 'test': 0.007318166133366723}
# [Best Score] {'train': 1.0, 'val': 0.744, 'test': 0.719, 'loss': 0.02526204101741314}
# [Best test run] 1

# %%
from models.model import *
num_layer = 2
hidden = 64
# model = MLP(dataset.num_features, dataset.num_classes, hidden=hidden)
model = GCNNet(dataset, num_layer, hidden=hidden)
# model = GATv2(in_channels=dataset.num_features, hidden_channels=hidden, out_channels=dataset.num_classes, num_layers=num_layer, heads=1, dropout=0.5, att_dropout=0.5)
# model = GAT(dataset=dataset, hidden=hidden)
# model = GraphSAGE(dataset, num_layer, hidden=hidden)
model = model.to(device)
model.load_state_dict(torch.load('../ckpt/model_best.ckpt'))
print(data)
print(model)
model.eval()
with torch.no_grad():
    # emb = model.get_emb(data)
    emb_gnn = model.get_logits(data_modi)
test(data_modi, model, dataset_name=Dataset)

# %%
# tsne
import copy
emb = emb_gnn
emb = emb.cpu().detach()
mu = emb.mean(dim=0, keepdim=True)
# std = x.std(dim=0, keepdim=True)
# std[std == 0] = 1e-8
# x_norm = (x - mu) / std
emb_norm = emb - mu

# add class center of class one vs. all other classes
# emb_final = torch.cat((emb_norm, emb_norm[data.y == 0].mean(0, keepdim=True), emb_norm[data.y != 0].mean(0, keepdim=True)), dim=0)
emb_final = copy.deepcopy(emb_norm)
for select_class in range(dataset.num_classes):
    emb_final = torch.cat((emb_final, emb_norm[data.y == select_class].mean(0, keepdim=True)), dim=0)

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, learning_rate='auto', init='random')
emb_tsne = tsne.fit_transform(emb_final)

colors = np.array(['r', 'yellow', 'g', 'b', 'orange', 'gray', 'purple'])
# center_0 = tsne.predict(x_norm[data.y == 0].mean(0))
plt.figure(figsize = (10, 8))
plt.scatter(emb_tsne[:, 0], emb_tsne[:, 1], s=[3 for _ in range(x.shape[0])] + [100] * dataset.num_classes, c=colors[data.cpu().y].tolist() + colors.tolist()[:dataset.num_classes])

# %%
# tsne
x = data.cpu().x
mu = x.mean(dim=0, keepdim=True)
std = x.std(dim=0, keepdim=True)
std[std == 0] = 1e-8
# x_norm = (x - mu) / std
x_norm = x - mu

# add class center of each class
select_class = 0
x_final = copy.deepcopy(x_norm)
for select_class in range(dataset.num_classes):
    x_final = torch.cat((x_final, x_norm[data.y == select_class].mean(0, keepdim=True)), dim=0)

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, learning_rate='auto', init='random')
x_tsne = tsne.fit_transform(x_final)

colors = np.array(['r', 'yellow', 'g', 'b', 'orange', 'gray', 'purple'])
# center_0 = tsne.predict(x_norm[data.y == 0].mean(0))
plt.figure(figsize = (10, 8))
plt.scatter(x_tsne[:, 0], x_tsne[:, 1], s=[3 for _ in range(x.shape[0])] + [100] * dataset.num_classes, c=colors[data.cpu().y].tolist() + colors.tolist()[:dataset.num_classes])

# %%
# plot graph structure by networkx
import networkx as nx
plt.figure(figsize=(10,10))
ax = plt.gca()
ax.set_title('Dataset:{} | #Edge:{} | #Node:{}'.format(Dataset, data.num_edges, data.num_nodes))
G = nx.Graph()
G.add_nodes_from(np.arange(data.num_nodes))
G.add_edges_from(data.cpu().edge_index.transpose(0, 1).tolist())
print(G.number_of_edges(), G.number_of_nodes())
colors = np.array(['r', 'yellow', 'g', 'b', 'orange', 'gray', 'purple'])

nx.draw(G, cmap = plt.get_cmap('jet'), node_color=colors[data.y], node_size=26, ax=ax)
# Out:
# 280 183

# %%
# plot graph structure by networkx
import networkx as nx
plt.figure(figsize=(10,10))
ax = plt.gca()
ax.set_title('Dataset:{} | #Edge:{} | #Node:{}'.format(Dataset, data_modi.edge_index.shape[1], data_modi.num_nodes))
G = nx.Graph()
G.add_nodes_from(np.arange(data.num_nodes))
G.add_edges_from(data_modi.cpu().edge_index.transpose(0, 1).tolist())
print(G.number_of_edges(), G.number_of_nodes())
colors = np.array(['r', 'yellow', 'g', 'b', 'orange', 'gray', 'purple'])

nx.draw(G, pos=nx.spring_layout(G), cmap = plt.get_cmap('jet'), node_color=colors[data_modi.y], node_size=26, ax=ax)
# Out:
# 2492 2708
